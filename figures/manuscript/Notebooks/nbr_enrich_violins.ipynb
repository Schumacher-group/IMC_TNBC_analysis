# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle as pkl

# %%
# import CellTable_CleanCohort/neighbours_matrix_pretreatment.pkl
# using pkl 
pkl_file = 'CellTable_CleanCohort/neighbours_matrix_pretreatment.pkl'
with open(pkl_file, 'rb') as f:
    neighbors_pretreatment = pkl.load(f)

pkl_file = 'CellTable_CleanCohort/neighbours_matrix_nonresponders.pkl'
with open(pkl_file, 'rb') as f:
    neighbors_nonresponders = pkl.load(f)

# %%
# load metadata
metadata = pd.read_csv('CellTable_CleanCohort/CleanCohort_Metadata.csv', index_col=0)

# %%
# display metadata contents for user overview
metadata
# Out:
#         Biopsy_(Core/Resection) FORCE_cycle Sample_Type_(pre/post treatment)  \
# LEAP_ID
# LEAP001                    Core       FALSE                              pre
# LEAP002               Resection       FALSE                             post
# LEAP003                    Core       FALSE                              pre
# LEAP004               Resection       FALSE                             post
# LEAP005                    Core       FALSE                              pre
# ...                         ...         ...                              ...
# LEAP146                    Core      Cycle2                         mid-late
# LEAP147                    Core     PreNACT                              pre
# LEAP148                    Core      Cycle1                        mid-early
# LEAP149                    Core     PreNACT                              pre
# LEAP150                    Core      Cycle1                        mid-early
#
#         NACT_Treatment _Group   Response_pCR  RCB_Scores  RCB_Group  \
# LEAP_ID
# LEAP001            EC-T-carbo  Non-Responder       3.750          3
# LEAP002            EC-T-carbo  Non-Responder       3.750          3
# LEAP003            EC-T-carbo  Non-Responder       3.834          3
# LEAP004            EC-T-carbo  Non-Responder       3.834          3
# LEAP005            EC-T-carbo  Non-Responder       1.865          2
# ...                       ...            ...         ...        ...
# LEAP146            EC-T-carbo            pCR       0.000          0
# LEAP147            EC-T-carbo            pCR       0.000          0
# LEAP148            EC-T-carbo            pCR       0.000          0
# LEAP149            EC-T-carbo      Responder       0.901          1
# LEAP150            EC-T-carbo      Responder       0.901          1
#
#         Tissue_Format  Extreme_NR  FORCE       Response  Patient_ID  \
# LEAP_ID
# LEAP001          FFPE       False  False  Non-Responder           1
# LEAP002          FFPE       False  False  Non-Responder           1
# LEAP003          FFPE       False  False  Non-Responder           2
# LEAP004          FFPE       False  False  Non-Responder           2
# LEAP005          FFPE       False  False  Non-Responder           3
# ...               ...         ...    ...            ...         ...
# LEAP146        FROZEN       False   True      Responder          49
# LEAP147        FROZEN       False   True      Responder          53
# LEAP148        FROZEN       False   True      Responder          53
# LEAP149        FROZEN       False   True      Responder          57
# LEAP150        FROZEN       False   True      Responder          57
#
#          Stain_Batch
# LEAP_ID
# LEAP001            1
# LEAP002            1
# LEAP003            1
# LEAP004            1
# LEAP005            1
# ...              ...
# LEAP146            7
# LEAP147            7
# LEAP148            7
# LEAP149            7
# LEAP150            7
#
# [94 rows x 13 columns]

# %%
# convert from dict to dataframe using keys as index, first column is everything before the first underscore of the key
pretreat_keys = neighbors_pretreatment.keys()
nonresp_keys = neighbors_nonresponders.keys()

pretreat_df = pd.DataFrame(pretreat_keys, columns=['Sample_ID'])
nonresp_df = pd.DataFrame(nonresp_keys, columns = ['Sample_ID'])

# %%
# strip the Sample_ID to get the first part before the underscore
pretreat_df['stripped_ID'] = pretreat_df['Sample_ID'].str.split('_').str[0]
nonresp_df['stripped_ID'] = nonresp_df['Sample_ID'].str.split('_').str[0]

# %%
# capitalize all letters in stripped_ID
pretreat_df['stripped_ID'].isin(metadata.index)
pretreat_df['stripped_ID'] = pretreat_df['stripped_ID'].str.upper()
nonresp_df['stripped_ID'].isin(metadata.index)
nonresp_df['stripped_ID'] = nonresp_df['stripped_ID'].str.upper()

# %%
# some sample_IDs have an letter appended for a different fov, so we need to correct these
pretreat_df['stripped_ID'].isin(metadata.index)
# print the ones that aren't in it - this is a naming issue resolved in the next cells
print(pretreat_df[~pretreat_df['stripped_ID'].isin(metadata.index)])
# Out:
#        Sample_ID stripped_ID
# 23   Leap084a_10    LEAP084A
# 28    Leap084a_7    LEAP084A
# 51    Leap084a_6    LEAP084A
# 202   Leap084a_1    LEAP084A
# 283   Leap084a_5    LEAP084A
# 292   Leap084a_3    LEAP084A
# 530   Leap084a_8    LEAP084A
# 533   Leap084a_4    LEAP084A
# 551  Leap084a_11    LEAP084A
# 583   Leap084a_9    LEAP084A
# 590   Leap084a_2    LEAP084A

# %%
# none of these in the nonresponders
print(nonresp_df[~nonresp_df['stripped_ID'].isin(metadata.index)])
# Out:
# Empty DataFrame
# Columns: [Sample_ID, stripped_ID]
# Index: []

# %%
# for any entry in stripped_ID that ends in A, remove the A at the end
pretreat_df['stripped_ID'] = pretreat_df['stripped_ID'].str.rstrip('A')

# %%
# now all stripped_IDs should be in metadata
print(pretreat_df[~pretreat_df['stripped_ID'].isin(metadata.index)])
# Out:
# Empty DataFrame
# Columns: [Sample_ID, stripped_ID]
# Index: []

# %%
pretreat_df
# check in metadata to confirm that all entries in stripped_ID correspond to pretreatment samples
metadata[metadata.index.isin(pretreat_df['stripped_ID'])]['Sample_Type_(pre/post treatment)'].value_counts()
# Out:
# Sample_Type_(pre/post treatment)
# pre    67
# Name: count, dtype: int64

# %%
# check in metadata to confirm that all entries in stripped_ID correspond to non-responder samples
metadata[metadata.index.isin(nonresp_df['stripped_ID'])]['Sample_Type_(pre/post treatment)'].value_counts()
# Out:
# Sample_Type_(pre/post treatment)
# pre     25
# post    21
# Name: count, dtype: int64

# %%
# print an overview of the metadata columns
metadata.columns
# Out:
# Index(['Biopsy_(Core/Resection)', 'FORCE_cycle',
#        'Sample_Type_(pre/post treatment)', 'NACT_Treatment _Group',
#        'Response_pCR', 'RCB_Scores', 'RCB_Group', 'Tissue_Format',
#        'Extreme_NR', 'FORCE', 'Response', 'Patient_ID', 'Stain_Batch'],
#       dtype='object')

# %%
# define the metadata for pretreatment and non-responders
pretreat_metadata = metadata[metadata.index.isin(pretreat_df['stripped_ID'])]
nonresp_metadata = metadata[metadata.index.isin(nonresp_df['stripped_ID'])]

# %%
# create a dictionary with the leapID as key and the corresponding ROIs as value
pretreat_dict = {}
for i in range(len(pretreat_metadata)):
    leapID = pretreat_metadata.index[i]
    rois = pretreat_df[pretreat_df['stripped_ID']==leapID]['Sample_ID'].values
    pretreat_dict[leapID] = rois

# %%
nonresp_dict = {}
for i in range(len(nonresp_metadata)):
    leapID = nonresp_metadata.index[i]
    #print(leapID)
    rois = nonresp_df[nonresp_df['stripped_ID']==leapID]['Sample_ID'].values
    nonresp_dict[leapID] = rois

# %%
# example of how to access the neighbors matrix for a specific sample
neighbors_pretreatment[pretreat_dict["LEAP011"][0]].loc['Antigen presenting cell','Cancer cell']
# Out:
# np.float64(0.421345927266283)

# %%
# function to generate pairwise information for a given celltype1 and celltype2
# this function will return a dataframe with the enrichment of celltype1 and celltype2 for each sample in the sampledict
def gen_pairwise_info(celltype1, celltype2, sampledict, neighbor_matrix_dict):
    pw_info = {}
    for key in sampledict:
        matches = 0
        total = 0
        for i in range(len(sampledict[key])):
            # check if celltype1 and celltype2 are in the columns of neighborhoods[sampledict[key][i]]

            if celltype1 in neighbor_matrix_dict[sampledict[key][i]].columns:
                if celltype2 in neighbor_matrix_dict[sampledict[key][i]].columns:
                    val = neighbor_matrix_dict[sampledict[key][i]].loc[celltype1, celltype2]
                    total += val
                    matches += 1
        if matches == 0:
            print("NULL "+celltype1+"&"+celltype2+" in "+key)
            x = 0 
        else: 
            x = total/matches
        pw_info[key] = x
    # return pw_info
    return pd.DataFrame.from_dict(pw_info, orient="index", columns = ["enrichment"])

# %%
# Example usage of the function
y = gen_pairwise_info("Neutrophil","Cancer cell",pretreat_dict, neighbors_pretreatment)
y
# Out:
#          enrichment
# LEAP001   -0.603001
# LEAP003    0.059745
# LEAP005   -0.969392
# LEAP008   -1.317487
# LEAP009   -0.650432
# ...             ...
# LEAP137   -0.818959
# LEAP142   -0.132236
# LEAP144   -0.207703
# LEAP147   -0.636165
# LEAP149    0.121522
#
# [67 rows x 1 columns]

# %%
# add the enrichment information to the pretreat_metadata dataframe
pretreat_metadata['enrichment_Neutrophil_CancerCell'] = y['enrichment']
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/3010073927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pretreat_metadata['enrichment_Neutrophil_CancerCell'] = y['enrichment']

# %%
# example violin plot split by "Response"
sns.violinplot(
    x='Response',
    y='enrichment_Neutrophil_CancerCell',
    data=pretreat_metadata,
    inner='box'  # or 'point' or None
)
# Out:
# <Axes: xlabel='Response', ylabel='enrichment_Neutrophil_CancerCell'>

# %%
# Example of a violin plot with individual data points overlayed
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Optional: load your DataFrame
# df = pd.read_csv("your_data.csv", index_col=0)
df = pretreat_metadata

# Clean column names if necessary
df.columns = df.columns.str.strip()

# Ensure 'Response' is categorical
df['Response'] = df['Response'].astype('category')

# Set plot style
sns.set(style="whitegrid")

# Create figure
plt.figure(figsize=(8, 6))

# Draw the violin plot
sns.violinplot(
    x='Response',
    y='enrichment_Neutrophil_CancerCell',
    data=df,
    inner=None,           # No inner boxplot for clarity
    palette='muted'
)

# Overlay individual data points
sns.stripplot(
    x='Response',
    y='enrichment_Neutrophil_CancerCell',
    data=df,
    color='black',
    size=5,
    jitter=True,         # Jitter helps avoid overlapping points
    alpha=0.6
)

# Add titles and axis labels
plt.title('Neutrophil/Cancer cell Enrichment by Response')
plt.xlabel('Response')
plt.ylabel('Neutrophil_CancerCell Enrichment')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/3167712339.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Response'] = df['Response'].astype('category')
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/3167712339.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
# check if Nans in any of the entries of roi
rois = pretreat_df['Sample_ID'].values
for i in range(len(rois)):
    if np.isnan(neighbors_pretreatment[rois[i]]).any().any():
        print('NAN in mm')
        print(i)
        print(rois[i])
        print('---')

# %%
np.isnan(neighbors_pretreatment[rois[0]]).any().any()
# Out:
# np.False_

# %%
# CD8 T cells and proliferative cancer cells co-locate more in non-responders
# Memory CD4 T cells and CD8 T cells co-locate more in responders 
# Cancer cells and macrophage+HLA cells co-locate more in non-responders
# B7H4 proliferative cells are closer to non-proliferative cancer cells in responders
nonresp_color = "#70221C"
resp_color = "#306E28"
palette_response = sns.color_palette([nonresp_color, resp_color])

# %%
# see that so far the metadata only has the enrichment for Neutrophil and Monocyte
pretreat_metadata
# Out:
#         Biopsy_(Core/Resection) FORCE_cycle Sample_Type_(pre/post treatment)  \
# LEAP_ID
# LEAP001                    Core       FALSE                              pre
# LEAP003                    Core       FALSE                              pre
# LEAP005                    Core       FALSE                              pre
# LEAP008                    Core       FALSE                              pre
# LEAP009                    Core       FALSE                              pre
# ...                         ...         ...                              ...
# LEAP137                    Core  Diagnostic                              pre
# LEAP142                    Core     PreNACT                              pre
# LEAP144                    Core     PreNACT                              pre
# LEAP147                    Core     PreNACT                              pre
# LEAP149                    Core     PreNACT                              pre
#
#         NACT_Treatment _Group   Response_pCR  RCB_Scores  RCB_Group  \
# LEAP_ID
# LEAP001            EC-T-carbo  Non-Responder       3.750          3
# LEAP003            EC-T-carbo  Non-Responder       3.834          3
# LEAP005            EC-T-carbo  Non-Responder       1.865          2
# LEAP008            EC-T-carbo            pCR       0.000          0
# LEAP009            EC-T-carbo            pCR       0.000          0
# ...                       ...            ...         ...        ...
# LEAP137            EC-T-carbo            pCR       0.000          0
# LEAP142            EC-T-carbo            pCR       0.000          0
# LEAP144            EC-T-carbo            pCR       0.000          0
# LEAP147            EC-T-carbo            pCR       0.000          0
# LEAP149            EC-T-carbo      Responder       0.901          1
#
#         Tissue_Format  Extreme_NR  FORCE       Response  Patient_ID  \
# LEAP_ID
# LEAP001          FFPE       False  False  Non-Responder           1
# LEAP003          FFPE       False  False  Non-Responder           2
# LEAP005          FFPE       False  False  Non-Responder           3
# LEAP008          FFPE        True  False      Responder           4
# LEAP009          FFPE       False  False      Responder           5
# ...               ...         ...    ...            ...         ...
# LEAP137          FFPE       False   True      Responder          53
# LEAP142        FROZEN       False   True      Responder          50
# LEAP144        FROZEN       False   True      Responder          49
# LEAP147        FROZEN       False   True      Responder          53
# LEAP149        FROZEN       False   True      Responder          57
#
#          Stain_Batch  enrichment_Neutrophil_CancerCell
# LEAP_ID
# LEAP001            1                         -0.603001
# LEAP003            1                          0.059745
# LEAP005            1                         -0.969392
# LEAP008            1                         -1.317487
# LEAP009            1                         -0.650432
# ...              ...                               ...
# LEAP137            6                         -0.818959
# LEAP142            7                         -0.132236
# LEAP144            7                         -0.207703
# LEAP147            7                         -0.636165
# LEAP149            7                          0.121522
#
# [67 rows x 14 columns]

# %%
# example of how to access the neighbors matrix for a specific sample
neighbors_pretreatment['Leap084a_11']
# Out:
#                          Antigen presenting cell  B7H4 Cancer cell  \
# Antigen presenting cell                11.431184         -2.160656
# B7H4 Cancer cell                       -1.907173          4.409739
# B7H4 Cancer cell Prol                  -1.404973          1.457747
# CD8 T cell                            -10.386196          0.994363
# Cancer cell                            -2.931023          2.744568
# Cancer cell Prol                       -6.700659          2.495599
# Cl Monocyte                             0.094016          1.547494
# Endothelial cell                        7.280023         -2.490661
# Fibroblast                              4.271166         -2.779631
# Int Monocyte                           -1.014924          1.034195
# Macrophage M1                          10.610272          0.122817
# Macrophage + HLA                        5.059018          0.920354
# Macrophage M2                           2.092146          0.087681
# Memory CD4 T cell                       5.530189         -1.116477
# Memory CD8 T cell                      -7.400294         -2.401902
# NonCl Monocyte                         -0.006061         -0.618412
# NK/CD8                                  4.875988         -1.332679
# Neutrophil                             -1.437963          1.325528
# Regulatory T cell                      -0.601729         -0.388728
#
#                          B7H4 Cancer cell Prol  CD8 T cell  Cancer cell  \
# Antigen presenting cell              -1.400704  -10.229226    -2.971028
# B7H4 Cancer cell                      2.154348    0.892007     2.790983
# B7H4 Cancer cell Prol                 1.290963    1.713892    -1.793550
# CD8 T cell                            1.197169   30.685680    -5.109698
# Cancer cell                          -2.040469   -5.150169     6.796185
# Cancer cell Prol                      0.606490    0.848989    10.192277
# Cl Monocyte                           3.923328    1.030153     1.586882
# Endothelial cell                     -1.077606   -9.838530    -5.891336
# Fibroblast                           -2.288170  -19.993180    -8.215350
# Int Monocyte                         -0.335098   -1.182573     5.096793
# Macrophage M1                         0.353190  -13.712743    -3.516169
# Macrophage + HLA                      0.223412   -3.911301    -2.298403
# Macrophage M2                        -0.558338   -2.032055    -1.429627
# Memory CD4 T cell                    -1.370769   -7.475867    -3.414265
# Memory CD8 T cell                     0.904943   -3.877898     7.240528
# NonCl Monocyte                       -0.310087    2.446997    -0.196090
# NK/CD8                               -1.722222   -9.650836    -4.458989
# Neutrophil                           -0.523001   -3.379859    -1.342251
# Regulatory T cell                    -0.229416    0.763839    -1.097442
#
#                          Cancer cell Prol  Cl Monocyte  Endothelial cell  \
# Antigen presenting cell         -6.359309     0.067499          6.460621
# B7H4 Cancer cell                 2.649705     1.584078         -2.479487
# B7H4 Cancer cell Prol            0.322054     3.912432         -1.079121
# CD8 T cell                       1.326884     0.830763        -10.168432
# Cancer cell                     10.128780     1.212624         -6.016187
# Cancer cell Prol                 9.744485     0.208490         -5.691449
# Cl Monocyte                      0.208162    -0.214597         -1.033488
# Endothelial cell                -5.713598    -1.049187         25.023213
# Fibroblast                     -10.718856    -0.076469          9.319820
# Int Monocyte                    -0.148993    -0.206768         -0.718463
# Macrophage M1                   -8.288324    -0.713684          1.596440
# Macrophage + HLA                -2.757062    -0.543706          0.860517
# Macrophage M2                   -1.222854    -0.377026          3.067568
# Memory CD4 T cell               -4.081065    -0.858720          8.785339
# Memory CD8 T cell                6.372443    -1.394361         -4.169969
# NonCl Monocyte                  -0.875083     4.554240         -0.734603
# NK/CD8                          -5.080791    -0.061046          3.989929
# Neutrophil                      -1.321143    -0.266207         -1.123916
# Regulatory T cell                0.292170    -0.142857         -0.427282
#
#                          Fibroblast  Int Monocyte  Macrophage M1  \
# Antigen presenting cell    4.207780     -1.018230      10.270277
# B7H4 Cancer cell          -2.032795      1.054568       0.129548
# B7H4 Cancer cell Prol     -2.294874     -0.331450       0.041246
# CD8 T cell               -20.201564     -0.895078     -13.472213
# Cancer cell               -8.028703      5.166464      -3.859115
# Cancer cell Prol         -10.503609     -0.146233      -8.131695
# Cl Monocyte               -0.496328     -0.209383      -0.730609
# Endothelial cell           9.085529     -0.721388       1.879814
# Fibroblast                32.790311     -0.644468       4.995195
# Int Monocyte              -0.044015     -0.125546       0.482543
# Macrophage M1              4.933111      0.484846      14.809609
# Macrophage + HLA           0.022120     -0.397448       5.966966
# Macrophage M2             -0.022282     -0.252646       3.891293
# Memory CD4 T cell          1.624203     -0.614832      -0.542898
# Memory CD8 T cell         -6.979286     -0.390222      -7.960359
# NonCl Monocyte            -1.228711     -0.131507      -0.180948
# NK/CD8                     3.509454     -0.730047       4.939876
# Neutrophil                 3.252822     -0.219786       0.051424
# Regulatory T cell         -1.049484     -0.083960       0.364789
#
#                          Macrophage + HLA  Macrophage M2  Memory CD4 T cell  \
# Antigen presenting cell          5.081353       2.121547           5.843583
# B7H4 Cancer cell                 0.933492       0.097265          -1.540729
# B7H4 Cancer cell Prol            0.205503      -0.557983          -1.369680
# CD8 T cell                      -3.934406      -1.937752          -7.812954
# Cancer cell                     -2.354849      -1.442736          -3.724231
# Cancer cell Prol                -2.500036      -1.213821          -3.907866
# Cl Monocyte                     -0.543706      -0.366608          -0.849643
# Endothelial cell                 0.846046       3.103433           8.472128
# Fibroblast                      -0.447437      -0.378301           1.327658
# Int Monocyte                    -0.389249      -0.254878          -0.608763
# Macrophage M1                    5.575365       3.409126          -0.540893
# Macrophage + HLA                10.532230      -0.630876           1.223395
# Macrophage M2                   -0.634660       6.996245           1.186694
# Memory CD4 T cell                0.565772       1.246511          18.113038
# Memory CD8 T cell               -2.370995      -1.584505          -1.885792
# NonCl Monocyte                  -0.367826      -0.255015          -0.573858
# NK/CD8                          -1.957213       3.005798           0.604650
# Neutrophil                      -0.556645      -0.338531           6.382098
# Regulatory T cell               -0.222797      -0.083960          -0.322229
#
#                          Memory CD8 T cell  NonCl Monocyte     NK/CD8  \
# Antigen presenting cell          -7.402469        0.000000   5.281285
# B7H4 Cancer cell                 -2.550216       -0.614623  -1.330800
# B7H4 Cancer cell Prol             1.182675       -0.314741  -1.715007
# CD8 T cell                       -2.969134        2.530936  -9.124156
# Cancer cell                       7.358327       -0.187593  -4.390520
# Cancer cell Prol                  5.829132       -0.881970  -4.692063
# Cl Monocyte                      -0.936556        4.405668  -0.064335
# Endothelial cell                 -4.005061       -0.734343   4.260623
# Fibroblast                       -6.965992       -1.239881   3.392221
# Int Monocyte                     -0.389186       -0.135388  -0.734632
# Macrophage M1                    -7.747191       -0.189519   4.941943
# Macrophage + HLA                 -2.600945       -0.366843  -1.966011
# Macrophage M2                    -1.544920       -0.259299   3.008435
# Memory CD4 T cell                -2.049117       -0.562471   0.606083
# Memory CD8 T cell                13.098513       -1.726953  -3.302380
# NonCl Monocyte                   -1.732067       -0.104274  -0.723321
# NK/CD8                           -3.312345       -0.731715  11.007257
# Neutrophil                       -1.522714       -0.222797   0.796204
# Regulatory T cell                -0.916026       -0.063372  -0.391544
#
#                          Neutrophil  Regulatory T cell
# Antigen presenting cell   -1.477709          -0.586823
# B7H4 Cancer cell           1.306469          -0.400364
# B7H4 Cancer cell Prol     -0.518430          -0.234206
# CD8 T cell                -2.394883           0.788182
# Cancer cell               -0.948081          -1.110642
# Cancer cell Prol          -1.316593           0.317197
# Cl Monocyte               -0.269625          -0.142857
# Endothelial cell          -1.120883          -0.433761
# Fibroblast                 3.271241          -1.075967
# Int Monocyte              -0.219786          -0.083960
# Macrophage M1              0.058612           0.329959
# Macrophage + HLA          -0.554342          -0.234839
# Macrophage M2             -0.339847          -0.077693
# Memory CD4 T cell          6.384261          -0.325935
# Memory CD8 T cell         -1.531003          -0.920348
# NonCl Monocyte            -0.220326          -0.054855
# NK/CD8                     0.816648          -0.391305
# Neutrophil                 8.884603          -0.105463
# Regulatory T cell         -0.114766          -0.031639

# %%
# generate pairwise information for the other cell selected types and add to the metadata
pretreat_metadata['enrichment_CD8_cancerprolif'] = gen_pairwise_info("CD8 T cell","Cancer cell Prol",pretreat_dict, neighbors_pretreatment)
pretreat_metadata['enrichment_CD4_CD8'] = gen_pairwise_info("CD8 T cell","Memory CD4 T cell",pretreat_dict, neighbors_pretreatment)
pretreat_metadata['enrichment_cancer_macroHLA'] = gen_pairwise_info("Macrophage + HLA","Cancer cell",pretreat_dict, neighbors_pretreatment)
pretreat_metadata['enrichment_b7h4_cancer'] = gen_pairwise_info("B7H4 Cancer cell","Cancer cell",pretreat_dict, neighbors_pretreatment)
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2297791384.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pretreat_metadata['enrichment_CD8_cancerprolif'] = gen_pairwise_info("CD8 T cell","Cancer cell Prol",pretreat_dict, neighbors_pretreatment)
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2297791384.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pretreat_metadata['enrichment_CD4_CD8'] = gen_pairwise_info("CD8 T cell","Memory CD4 T cell",pretreat_dict, neighbors_pretreatment)
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2297791384.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pretreat_metadata['enrichment_cancer_macroHLA'] = gen_pairwise_info("Macrophage + HLA","Cancer cell",pretreat_dict, neighbors_pretreatment)
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2297791384.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pretreat_metadata['enrichment_b7h4_cancer'] = gen_pairwise_info("B7H4 Cancer cell","Cancer cell",pretreat_dict, neighbors_pretreatment)

# %%
# now the metadata has the enrichment for more cell types we are interested in
pretreat_metadata
# Out:
#         Biopsy_(Core/Resection) FORCE_cycle Sample_Type_(pre/post treatment)  \
# LEAP_ID
# LEAP001                    Core       FALSE                              pre
# LEAP003                    Core       FALSE                              pre
# LEAP005                    Core       FALSE                              pre
# LEAP008                    Core       FALSE                              pre
# LEAP009                    Core       FALSE                              pre
# ...                         ...         ...                              ...
# LEAP137                    Core  Diagnostic                              pre
# LEAP142                    Core     PreNACT                              pre
# LEAP144                    Core     PreNACT                              pre
# LEAP147                    Core     PreNACT                              pre
# LEAP149                    Core     PreNACT                              pre
#
#         NACT_Treatment _Group   Response_pCR  RCB_Scores  RCB_Group  \
# LEAP_ID
# LEAP001            EC-T-carbo  Non-Responder       3.750          3
# LEAP003            EC-T-carbo  Non-Responder       3.834          3
# LEAP005            EC-T-carbo  Non-Responder       1.865          2
# LEAP008            EC-T-carbo            pCR       0.000          0
# LEAP009            EC-T-carbo            pCR       0.000          0
# ...                       ...            ...         ...        ...
# LEAP137            EC-T-carbo            pCR       0.000          0
# LEAP142            EC-T-carbo            pCR       0.000          0
# LEAP144            EC-T-carbo            pCR       0.000          0
# LEAP147            EC-T-carbo            pCR       0.000          0
# LEAP149            EC-T-carbo      Responder       0.901          1
#
#         Tissue_Format  Extreme_NR  FORCE       Response  Patient_ID  \
# LEAP_ID
# LEAP001          FFPE       False  False  Non-Responder           1
# LEAP003          FFPE       False  False  Non-Responder           2
# LEAP005          FFPE       False  False  Non-Responder           3
# LEAP008          FFPE        True  False      Responder           4
# LEAP009          FFPE       False  False      Responder           5
# ...               ...         ...    ...            ...         ...
# LEAP137          FFPE       False   True      Responder          53
# LEAP142        FROZEN       False   True      Responder          50
# LEAP144        FROZEN       False   True      Responder          49
# LEAP147        FROZEN       False   True      Responder          53
# LEAP149        FROZEN       False   True      Responder          57
#
#          Stain_Batch  enrichment_Neutrophil_CancerCell  \
# LEAP_ID
# LEAP001            1                         -0.603001
# LEAP003            1                          0.059745
# LEAP005            1                         -0.969392
# LEAP008            1                         -1.317487
# LEAP009            1                         -0.650432
# ...              ...                               ...
# LEAP137            6                         -0.818959
# LEAP142            7                         -0.132236
# LEAP144            7                         -0.207703
# LEAP147            7                         -0.636165
# LEAP149            7                          0.121522
#
#          enrichment_CD8_cancerprolif  enrichment_CD4_CD8  \
# LEAP_ID
# LEAP001                    -2.353984           -2.455811
# LEAP003                    -2.274765            1.829102
# LEAP005                     0.259908           -2.024902
# LEAP008                     1.996841           -1.747096
# LEAP009                    -2.737003            0.185539
# ...                              ...                 ...
# LEAP137                    -5.040633            4.491899
# LEAP142                    -3.952504            0.274563
# LEAP144                     0.799513            2.123881
# LEAP147                    -2.798067            3.187430
# LEAP149                     0.092796            1.497643
#
#          enrichment_cancer_macroHLA  enrichment_b7h4_cancer
# LEAP_ID
# LEAP001                   -1.579673                0.572945
# LEAP003                    0.202240                3.997438
# LEAP005                    0.565814                4.749028
# LEAP008                    0.203555                7.239825
# LEAP009                   -1.284077                7.018835
# ...                             ...                     ...
# LEAP137                   -0.649243               10.752549
# LEAP142                   -0.868791                3.761529
# LEAP144                   -1.702593                3.999300
# LEAP147                   -1.993847                2.584035
# LEAP149                   -0.988779                7.838408
#
# [67 rows x 18 columns]

# %%
# create violin plots for the enrichment of the different cell types

ax = sns.violinplot(
    x='Response',
    y='enrichment_CD4_CD8',
    data=pretreat_metadata,
    inner='box',  # or 'point' or None
    palette=palette_response,
    saturation = 1
)


ax.set_xlabel("Response")
ax.set_title('Neighborhood enrichment of Memory CD4 T cells and CD8 T cells')
ax.set_ylabel('Enrichment (z-score)')
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/1285519280.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# Text(0, 0.5, 'Enrichment (z-score)')

# %%
ax = sns.violinplot(
    x='Response',
    y='enrichment_CD8_cancerprolif',
    data=pretreat_metadata,
    inner='box',  # or 'point' or None
    palette=palette_response,
    saturation = 1
)


ax.set_xlabel("Response")
ax.set_title('Neighborhood enrichment of proliferative cancer cells \n and CD8 T cells')
ax.set_ylabel('Enrichment (z-score)')
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2900694341.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# Text(0, 0.5, 'Enrichment (z-score)')

# %%
sns.violinplot(
    x='Response',
    y='enrichment_cancer_macroHLA',
    data=pretreat_metadata,
    inner='box'  # or 'point' or None
)



ax = sns.violinplot(
    x='Response',
    y='enrichment_cancer_macroHLA',
    data=pretreat_metadata,
    inner='box',  # or 'point' or None
    palette=palette_response,
    saturation = 1
)


ax.set_xlabel("Response")
ax.set_title('Neighborhood enrichment of cancer cells \n and macrophages + HLA')
ax.set_ylabel('Enrichment (z-score)')
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/1470502268.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# Text(0, 0.5, 'Enrichment (z-score)')

# %%
ax = sns.violinplot(
    x='Response',
    y='enrichment_b7h4_cancer',
    data=pretreat_metadata,
    inner='box',  # or 'point' or None
    palette=palette_response,
    saturation = 1
)


ax.set_xlabel("Response")
ax.set_title('Neighborhood enrichment of B7H4 cancer cells \n and cancer cells')
ax.set_ylabel('Enrichment (z-score)')
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2594614246.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# Text(0, 0.5, 'Enrichment (z-score)')

# %%
# now we do the same for the non-responders, generating pairwise information for some pairs of cell types and adding it to the nonresp_metadata dataframe
#“Macrophage”, “Memory CD4 T cell”
#“Antigen presenting cell”, “Regulatory T cell”
#“Monocyte”, “B cell + HLA”
#“Cancer cell Prol”, “CD8 T cell”
#“Fibroblast”, “Macrophage"

nonresp_metadata['enrichment_macroM1_CD4'] = gen_pairwise_info("Macrophage M1", "Memory CD4 T cell",nonresp_dict, neighbors_nonresponders)
nonresp_metadata['enrichment_APC_Treg'] = gen_pairwise_info("Antigen presenting cell", "Regulatory T cell",nonresp_dict, neighbors_nonresponders)
# nonresp_metadata['enrichment_mono_BHLA'] = gen_pairwise_info("Monocyte", "B cell + HLA",nonresp_dict, neighbors_nonresponders)
nonresp_metadata['enrichment_cancerprol_CD8'] = gen_pairwise_info("Cancer cell Prol", "CD8 T cell",nonresp_dict, neighbors_nonresponders)
nonresp_metadata['enrichment_macroM1_fibro'] = gen_pairwise_info("Macrophage M1", "Fibroblast",nonresp_dict, neighbors_nonresponders)
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2310330307.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonresp_metadata['enrichment_macroM1_CD4'] = gen_pairwise_info("Macrophage M1", "Memory CD4 T cell",nonresp_dict, neighbors_nonresponders)
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2310330307.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonresp_metadata['enrichment_APC_Treg'] = gen_pairwise_info("Antigen presenting cell", "Regulatory T cell",nonresp_dict, neighbors_nonresponders)
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2310330307.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonresp_metadata['enrichment_cancerprol_CD8'] = gen_pairwise_info("Cancer cell Prol", "CD8 T cell",nonresp_dict, neighbors_nonresponders)
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2310330307.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonresp_metadata['enrichment_macroM1_fibro'] = gen_pairwise_info("Macrophage M1", "Fibroblast",nonresp_dict, neighbors_nonresponders)

# %%
nonresp_metadata.columns
# Out:
# Index(['Biopsy_(Core/Resection)', 'FORCE_cycle',
#        'Sample_Type_(pre/post treatment)', 'NACT_Treatment _Group',
#        'Response_pCR', 'RCB_Scores', 'RCB_Group', 'Tissue_Format',
#        'Extreme_NR', 'FORCE', 'Response', 'Patient_ID', 'Stain_Batch',
#        'enrichment_macroM1_CD4', 'enrichment_APC_Treg',
#        'enrichment_cancerprol_CD8', 'enrichment_macroM1_fibro'],
#       dtype='object')

# %%
pre_color = "#D9C454" #np.array([217, 196,84])/255
post_color = "#711F74" # np.array([113, 31,116])/255

# %%
# make a seaborn palette with these two colors
palette_prepost = sns.color_palette([pre_color, post_color])

# %%
ax = sns.violinplot(
    x='Sample_Type_(pre/post treatment)',
    y='enrichment_macroM1_CD4',
    data=nonresp_metadata,
    inner='box',  # or 'point' or None
    palette=palette_prepost,
    saturation = 1,
)

ax.set_xlabel("Sample Timepoint")
ax.set_title('Neighborhood enrichment of M1 macrophages and memory CD4 T cells')
ax.set_ylabel('Enrichment (z-score)')
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/3575776431.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# Text(0, 0.5, 'Enrichment (z-score)')

# %%
ax = sns.violinplot(
    x='Sample_Type_(pre/post treatment)',
    y='enrichment_APC_Treg',
    data=nonresp_metadata,
    inner='box',  # or 'point' or None
    palette=palette_prepost,
    saturation = 1
)


ax.set_xlabel("Sample Timepoint")
ax.set_title('Neighborhood enrichment of antigen presenting cells  \n and regulatory T cells')
ax.set_ylabel('Enrichment (z-score)')
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/1013864631.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# Text(0, 0.5, 'Enrichment (z-score)')

# %%
ax = sns.violinplot(
    x='Sample_Type_(pre/post treatment)',
    y='enrichment_cancerprol_CD8',
    data=nonresp_metadata,
    inner='box',  # or 'point' or None
    palette=palette_prepost,
    saturation = 1
)


ax.set_xlabel("Sample Timepoint")
ax.set_title('Neighborhood enrichment of proliferating cancer cells \n and CD8+ T cells')
ax.set_ylabel('Enrichment (z-score)')
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/4016252228.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# Text(0, 0.5, 'Enrichment (z-score)')

# %%
ax = sns.violinplot(
    x='Sample_Type_(pre/post treatment)',
    y='enrichment_macroM1_fibro',
    data=nonresp_metadata,
    inner='box',  # or 'point' or None
    palette=palette_prepost,
    saturation = 1
)


ax.set_xlabel("Sample Timepoint")
ax.set_title('Neighborhood enrichment of M1 macrophages and fibroblasts')
ax.set_ylabel('Enrichment (z-score)')
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/1531506093.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# Text(0, 0.5, 'Enrichment (z-score)')

# %%
# save the metadata with the enrichment information to csv files
nonresp_metadata.to_csv("nonresponder_df.csv")

# %%
pretreat_metadata.to_csv("pretreat_df.csv")

# %%
# plot violin plots for multiple pairs of cell types in a single plot
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your CSV file
df = pd.read_csv('nonresponder_df.csv')  # Make sure the file path is correct

# Melt the DataFrame for Seaborn
melted_df = df.melt(
    id_vars='Sample_Type_(pre/post treatment)',
    value_vars=[
        'enrichment_macroM1_CD4',
        'enrichment_APC_Treg',
        'enrichment_cancerprol_CD8',
        'enrichment_macroM1_fibro'
    ],
    var_name='Enrichment_Type',
    value_name='Value'
)

# Optional: Rename enrichment types for better readability
label_map = {
    'enrichment_macroM1_CD4': 'Macrophages\nCD4 T cells',
    'enrichment_APC_Treg': 'APCs\nRegulatory T cells',
    'enrichment_cancerprol_CD8': 'Cancer-prol.\nCD8 T cells',
    'enrichment_macroM1_fibro': 'Macrophages\nFibroblasts'
}

melted_df['Enrichment_Type'] = melted_df['Enrichment_Type'].map(label_map)

# Plot
plt.figure(figsize=(16, 6))
sns.violinplot(
    x='Enrichment_Type',
    y='Value',
    hue='Sample_Type_(pre/post treatment)',
    data=melted_df,
    #split=True
)

# Customize titles and labels
plt.title('Distribution of Enrichment Features by Treatment Type', fontsize=14)
plt.xlabel('Enrichment Type', fontsize=12)
plt.ylabel('Enrichment Score', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(title='Sample Type')
plt.show()

# %%
# plot violin plots for each pair of cell types, with individual data points overlayed, colored by RCB_Scores
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("nonresponder_df.csv")

# List of enrichment columns
enrichment_columns = [
    "enrichment_macroM1_CD4",
    "enrichment_APC_Treg",
    "enrichment_cancerprol_CD8",
    "enrichment_macroM1_fibro"
]

# Loop through each enrichment column and plot separately
for column in enrichment_columns:
    plt.figure(figsize=(8, 6))
    
    # Violin plot split by Sample_Type_(pre/post treatment)
    sns.violinplot(
        data=df,
        x="Sample_Type_(pre/post treatment)",
        y=column,
        inner=None,
        color="lightgray"
    )
    
    # Overlay individual data points colored by RCB_Scores
    sns.stripplot(
        data=df,
        x="Sample_Type_(pre/post treatment)",
        y=column,
        hue="RCB_Scores",
        palette="viridis",
        dodge=False,
        jitter=True,
        size=5
    )

    # Customize plot
    plt.title(f"{column} by Sample Type with RCB Scores")
    plt.xlabel("Sample Type (Pre/Post Treatment)")
    plt.ylabel("Enrichment Value")
    plt.legend(title="RCB Score", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load data
df = pd.read_csv("nonresponder_df.csv")

# Define enrichment columns
enrichment_columns = [
    "enrichment_macroM1_CD4",
    "enrichment_APC_Treg",
    "enrichment_cancerprol_CD8",
    "enrichment_macroM1_fibro"
]

# Normalize RCB scores for consistent color mapping
rcb_values = df["RCB_Scores"]
vmin, vmax = rcb_values.min(), rcb_values.max()
norm = plt.Normalize(vmin=vmin, vmax=vmax)
cmap = plt.cm.viridis

# Plot loop
for col in enrichment_columns:
    plt.figure(figsize=(8, 6))
    
    # Violin plot
    sns.violinplot(
        data=df,
        x="Sample_Type_(pre/post treatment)",
        y=col,
        inner=None,
        color="lightgray"
    )

    # Overlay colored dots manually
    x_labels = df["Sample_Type_(pre/post treatment)"].unique()
    for i, group in enumerate(x_labels):
        subset = df[df["Sample_Type_(pre/post treatment)"] == group]
        x_coords = np.random.normal(i, 0.08, size=len(subset))  # jitter
        y_coords = subset[col].values
        colors = cmap(norm(subset["RCB_Scores"].values))
        plt.scatter(x_coords, y_coords, c=colors, s=40, edgecolor="k", linewidth=0.3)

    # Colorbar (now explicitly tied to current axes)
    ax = plt.gca()
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax)
    cbar.set_label("RCB Score")

    # Final plot formatting
    plt.title(f"{col} by Sample Type with RCB Score Coloring")
    plt.xlabel("Sample Type (Pre/Post Treatment)")
    plt.ylabel("Enrichment Value")
    plt.tight_layout()
    plt.show()

# %%
# subset all pairs of cell types to only those where (R - nR) has the same sign and (pre - post), and then rank them by absolute biggest total difference |(R - nR) + (pre - post)|, 
# to give both things that are very different R vs nR and then stay the same post treat-ment, as well as things that consistently get more different post-treatment

# %%
# make a list of all cell types in any entry of neighbours_pretreatment
all_cell_types = set()
for sample in neighbors_pretreatment.values():
    all_cell_types.update(sample.columns)

# make a list of all cell types in any entry of neighbours_nonresponders
for sample in neighbors_nonresponders.values():
    all_cell_types.update(sample.columns)

# print the cell types
print(all_cell_types)
# Out:
# {'Macrophage M1', 'B cell + HLA', 'B7H4 Cancer cell', 'Cancer cell', 'Antigen presenting cell', 'Endothelial cell', 'Cancer cell Prol', 'Cl Monocyte', 'Fibroblast', 'NK/CD8', 'Regulatory T cell', 'Memory CD8 T cell', 'B7H4 Cancer cell Prol', 'Memory CD4 T cell', 'Int Monocyte', 'NonCl Monocyte', 'Macrophage + HLA', 'Neutrophil', 'CD8 T cell', 'Macrophage M2'}

# %%
# loop through all pairs of cell types and calculate the enrichment for each pair in both pretreatment and non-responders
import itertools
pairwise_enrichment = {}
for cell_type1, cell_type2 in itertools.combinations(all_cell_types,2):
    # Calculate enrichment for pretreatment
    pretreat_metadata[cell_type1 + '_' + cell_type2] = gen_pairwise_info(cell_type1, cell_type2, pretreat_dict, neighbors_pretreatment)
    # Calculate enrichment for non-responders
    nonresp_metadata[cell_type1 + "_" + cell_type2] = gen_pairwise_info(cell_type1, cell_type2, nonresp_dict, neighbors_nonresponders)
    
    # separate pretreatment into resonder and non-responder based on metadata
    pretreat_responder_enrichment = pretreat_metadata[pretreat_metadata['Response'] == 'Responder'][cell_type1 + '_' + cell_type2]
    pretreat_nonresp_enrichment = pretreat_metadata[pretreat_metadata['Response'] == 'Non-Responder'][cell_type1 + '_' + cell_type2]

    # seperate nonresp_enrichment into pre and post treatment based on nonresp_metadata
    nonresp_pretreat_enrichment = nonresp_metadata[nonresp_metadata['Sample_Type_(pre/post treatment)'] == 'pre'][cell_type1 + '_' + cell_type2]
    nonresp_posttreat_enrichment = nonresp_metadata[nonresp_metadata['Sample_Type_(pre/post treatment)'] == 'post'][cell_type1 + '_' + cell_type2]

    # Calculate the difference between responder and non-responders in pretreatment
    respnonresp_diff = pretreat_responder_enrichment.mean() - pretreat_nonresp_enrichment.mean()
    # calculate the difference between pre and post treatment samples in non-responders 'Sample_Type_(pre/post treatment)'
    prepost_diff = nonresp_pretreat_enrichment.mean() - nonresp_posttreat_enrichment.mean()

    # Calculate the absolute difference
    total_diff = respnonresp_diff + prepost_diff # if r-nr and pre-post have the same sign, the absolute difference will be larger, if they have different signs, the absolute difference will be smaller
    
    # Store the results
    pairwise_enrichment[(cell_type1, cell_type2)] = {
        # 'pretreat_responder_enrichment': pretreat_responder_enrichment,
        # 'pretreat_nonresp_enrichment': pretreat_nonresp_enrichment,
        # 'nonresp_pretreat_enrichment': nonresp_pretreat_enrichment,
        # 'nonresp_posttreat_enrichment': nonresp_posttreat_enrichment,
        'respnonresp_diff': respnonresp_diff,
        'prepost_diff': prepost_diff,
        'total_diff': total_diff,
    }
# Out:
# NULL Macrophage M1&B cell + HLA in LEAP001
# NULL Macrophage M1&B cell + HLA in LEAP075
# NULL Macrophage M1&B cell + HLA in LEAP001
# NULL Macrophage M1&Int Monocyte in LEAP043
# NULL Macrophage M1&Int Monocyte in LEAP046
# NULL Macrophage M1&Int Monocyte in LEAP092
# NULL Macrophage M1&Int Monocyte in LEAP045
# NULL Macrophage M1&Int Monocyte in LEAP046
# NULL Macrophage M1&NonCl Monocyte in LEAP092
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/4135405244.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pretreat_metadata[cell_type1 + '_' + cell_type2] = gen_pairwise_info(cell_type1, cell_type2, pretreat_dict, neighbors_pretreatment)
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/4135405244.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonresp_metadata[cell_type1 + "_" + cell_type2] = gen_pairwise_info(cell_type1, cell_type2, nonresp_dict, neighbors_nonresponders)
# NULL Macrophage M1&Macrophage M2 in LEAP024
# NULL Macrophage M1&Macrophage M2 in LEAP024
# NULL B cell + HLA&B7H4 Cancer cell in LEAP001
# NULL B cell + HLA&B7H4 Cancer cell in LEAP075
# NULL B cell + HLA&B7H4 Cancer cell in LEAP001
# NULL B cell + HLA&Cancer cell in LEAP001
# NULL B cell + HLA&Cancer cell in LEAP075
# NULL B cell + HLA&Cancer cell in LEAP001
# NULL B cell + HLA&Antigen presenting cell in LEAP001
# NULL B cell + HLA&Antigen presenting cell in LEAP075
# NULL B cell + HLA&Antigen presenting cell in LEAP001
# NULL B cell + HLA&Endothelial cell in LEAP001
# NULL B cell + HLA&Endothelial cell in LEAP075
# NULL B cell + HLA&Endothelial cell in LEAP001
# NULL B cell + HLA&Cancer cell Prol in LEAP001
# NULL B cell + HLA&Cancer cell Prol in LEAP075
# NULL B cell + HLA&Cancer cell Prol in LEAP001
# NULL B cell + HLA&Cl Monocyte in LEAP001
# NULL B cell + HLA&Cl Monocyte in LEAP075
# NULL B cell + HLA&Cl Monocyte in LEAP001
# NULL B cell + HLA&Cl Monocyte in LEAP033
# NULL B cell + HLA&Cl Monocyte in LEAP035
# NULL B cell + HLA&Fibroblast in LEAP001
# NULL B cell + HLA&Fibroblast in LEAP075
# NULL B cell + HLA&Fibroblast in LEAP001
# NULL B cell + HLA&NK/CD8 in LEAP001
# NULL B cell + HLA&NK/CD8 in LEAP075
# NULL B cell + HLA&NK/CD8 in LEAP001
# NULL B cell + HLA&Regulatory T cell in LEAP001
# NULL B cell + HLA&Regulatory T cell in LEAP075
# NULL B cell + HLA&Regulatory T cell in LEAP001
# NULL B cell + HLA&Memory CD8 T cell in LEAP001
# NULL B cell + HLA&Memory CD8 T cell in LEAP011
# NULL B cell + HLA&Memory CD8 T cell in LEAP075
# NULL B cell + HLA&Memory CD8 T cell in LEAP001
# NULL B cell + HLA&B7H4 Cancer cell Prol in LEAP001
# NULL B cell + HLA&B7H4 Cancer cell Prol in LEAP075
# NULL B cell + HLA&B7H4 Cancer cell Prol in LEAP001
# NULL B cell + HLA&Memory CD4 T cell in LEAP001
# NULL B cell + HLA&Memory CD4 T cell in LEAP075
# NULL B cell + HLA&Memory CD4 T cell in LEAP001
# NULL B cell + HLA&Int Monocyte in LEAP001
# NULL B cell + HLA&Int Monocyte in LEAP026
# NULL B cell + HLA&Int Monocyte in LEAP032
# NULL B cell + HLA&Int Monocyte in LEAP043
# NULL B cell + HLA&Int Monocyte in LEAP046
# NULL B cell + HLA&Int Monocyte in LEAP068
# NULL B cell + HLA&Int Monocyte in LEAP075
# NULL B cell + HLA&Int Monocyte in LEAP092
# NULL B cell + HLA&Int Monocyte in LEAP001
# NULL B cell + HLA&Int Monocyte in LEAP016
# NULL B cell + HLA&Int Monocyte in LEAP032
# NULL B cell + HLA&Int Monocyte in LEAP033
# NULL B cell + HLA&Int Monocyte in LEAP040
# NULL B cell + HLA&Int Monocyte in LEAP045
# NULL B cell + HLA&Int Monocyte in LEAP046
# NULL B cell + HLA&Int Monocyte in LEAP068
# NULL B cell + HLA&Int Monocyte in LEAP074
# NULL B cell + HLA&NonCl Monocyte in LEAP001
# NULL B cell + HLA&NonCl Monocyte in LEAP075
# NULL B cell + HLA&NonCl Monocyte in LEAP092
# NULL B cell + HLA&NonCl Monocyte in LEAP001
# NULL B cell + HLA&Macrophage + HLA in LEAP001
# NULL B cell + HLA&Macrophage + HLA in LEAP075
# NULL B cell + HLA&Macrophage + HLA in LEAP001
# NULL B cell + HLA&Neutrophil in LEAP001
# NULL B cell + HLA&Neutrophil in LEAP075
# NULL B cell + HLA&Neutrophil in LEAP001
# NULL B cell + HLA&CD8 T cell in LEAP001
# NULL B cell + HLA&CD8 T cell in LEAP075
# NULL B cell + HLA&CD8 T cell in LEAP001
# NULL B cell + HLA&Macrophage M2 in LEAP001
# NULL B cell + HLA&Macrophage M2 in LEAP024
# NULL B cell + HLA&Macrophage M2 in LEAP075
# NULL B cell + HLA&Macrophage M2 in LEAP001
# NULL B cell + HLA&Macrophage M2 in LEAP024
# NULL B7H4 Cancer cell&Int Monocyte in LEAP043
# NULL B7H4 Cancer cell&Int Monocyte in LEAP046
# NULL B7H4 Cancer cell&Int Monocyte in LEAP092
# NULL B7H4 Cancer cell&Int Monocyte in LEAP045
# NULL B7H4 Cancer cell&Int Monocyte in LEAP046
# NULL B7H4 Cancer cell&NonCl Monocyte in LEAP092
# NULL B7H4 Cancer cell&Macrophage M2 in LEAP024
# NULL B7H4 Cancer cell&Macrophage M2 in LEAP024
# NULL Cancer cell&Int Monocyte in LEAP043
# NULL Cancer cell&Int Monocyte in LEAP046
# NULL Cancer cell&Int Monocyte in LEAP092
# NULL Cancer cell&Int Monocyte in LEAP045
# NULL Cancer cell&Int Monocyte in LEAP046
# NULL Cancer cell&NonCl Monocyte in LEAP092
# NULL Cancer cell&Macrophage M2 in LEAP024
# NULL Cancer cell&Macrophage M2 in LEAP024
# NULL Antigen presenting cell&Int Monocyte in LEAP043
# NULL Antigen presenting cell&Int Monocyte in LEAP046
# NULL Antigen presenting cell&Int Monocyte in LEAP092
# NULL Antigen presenting cell&Int Monocyte in LEAP045
# NULL Antigen presenting cell&Int Monocyte in LEAP046
# NULL Antigen presenting cell&NonCl Monocyte in LEAP092
# NULL Antigen presenting cell&Macrophage M2 in LEAP024
# NULL Antigen presenting cell&Macrophage M2 in LEAP024
# NULL Endothelial cell&Int Monocyte in LEAP043
# NULL Endothelial cell&Int Monocyte in LEAP046
# NULL Endothelial cell&Int Monocyte in LEAP092
# NULL Endothelial cell&Int Monocyte in LEAP045
# NULL Endothelial cell&Int Monocyte in LEAP046
# NULL Endothelial cell&NonCl Monocyte in LEAP092
# NULL Endothelial cell&Macrophage M2 in LEAP024
# NULL Endothelial cell&Macrophage M2 in LEAP024
# NULL Cancer cell Prol&Int Monocyte in LEAP043
# NULL Cancer cell Prol&Int Monocyte in LEAP046
# NULL Cancer cell Prol&Int Monocyte in LEAP092
# NULL Cancer cell Prol&Int Monocyte in LEAP045
# NULL Cancer cell Prol&Int Monocyte in LEAP046
# NULL Cancer cell Prol&NonCl Monocyte in LEAP092
# NULL Cancer cell Prol&Macrophage M2 in LEAP024
# NULL Cancer cell Prol&Macrophage M2 in LEAP024
# NULL Cl Monocyte&Int Monocyte in LEAP042
# NULL Cl Monocyte&Int Monocyte in LEAP043
# NULL Cl Monocyte&Int Monocyte in LEAP046
# NULL Cl Monocyte&Int Monocyte in LEAP048
# NULL Cl Monocyte&Int Monocyte in LEAP064
# NULL Cl Monocyte&Int Monocyte in LEAP092
# NULL Cl Monocyte&Int Monocyte in LEAP040
# NULL Cl Monocyte&Int Monocyte in LEAP045
# NULL Cl Monocyte&Int Monocyte in LEAP046
# NULL Cl Monocyte&Int Monocyte in LEAP048
# NULL Cl Monocyte&Int Monocyte in LEAP064
# NULL Cl Monocyte&NonCl Monocyte in LEAP092
# NULL Cl Monocyte&Macrophage M2 in LEAP024
# NULL Cl Monocyte&Macrophage M2 in LEAP024
# NULL Fibroblast&Int Monocyte in LEAP043
# NULL Fibroblast&Int Monocyte in LEAP046
# NULL Fibroblast&Int Monocyte in LEAP092
# NULL Fibroblast&Int Monocyte in LEAP045
# NULL Fibroblast&Int Monocyte in LEAP046
# NULL Fibroblast&NonCl Monocyte in LEAP092
# NULL Fibroblast&Macrophage M2 in LEAP024
# NULL Fibroblast&Macrophage M2 in LEAP024
# NULL NK/CD8&Int Monocyte in LEAP043
# NULL NK/CD8&Int Monocyte in LEAP046
# NULL NK/CD8&Int Monocyte in LEAP092
# NULL NK/CD8&Int Monocyte in LEAP045
# NULL NK/CD8&Int Monocyte in LEAP046
# NULL NK/CD8&NonCl Monocyte in LEAP092
# NULL NK/CD8&Macrophage M2 in LEAP024
# NULL NK/CD8&Macrophage M2 in LEAP024
# NULL Regulatory T cell&Int Monocyte in LEAP043
# NULL Regulatory T cell&Int Monocyte in LEAP046
# NULL Regulatory T cell&Int Monocyte in LEAP092
# NULL Regulatory T cell&Int Monocyte in LEAP045
# NULL Regulatory T cell&Int Monocyte in LEAP046
# NULL Regulatory T cell&NonCl Monocyte in LEAP092
# NULL Regulatory T cell&Macrophage M2 in LEAP024
# NULL Regulatory T cell&Macrophage M2 in LEAP024
# NULL Memory CD8 T cell&Int Monocyte in LEAP043
# NULL Memory CD8 T cell&Int Monocyte in LEAP046
# NULL Memory CD8 T cell&Int Monocyte in LEAP092
# NULL Memory CD8 T cell&Int Monocyte in LEAP040
# NULL Memory CD8 T cell&Int Monocyte in LEAP045
# NULL Memory CD8 T cell&Int Monocyte in LEAP046
# NULL Memory CD8 T cell&Int Monocyte in LEAP074
# NULL Memory CD8 T cell&NonCl Monocyte in LEAP092
# NULL Memory CD8 T cell&Macrophage M2 in LEAP024
# NULL Memory CD8 T cell&Macrophage M2 in LEAP024
# NULL B7H4 Cancer cell Prol&Int Monocyte in LEAP043
# NULL B7H4 Cancer cell Prol&Int Monocyte in LEAP046
# NULL B7H4 Cancer cell Prol&Int Monocyte in LEAP092
# NULL B7H4 Cancer cell Prol&Int Monocyte in LEAP045
# NULL B7H4 Cancer cell Prol&Int Monocyte in LEAP046
# NULL B7H4 Cancer cell Prol&NonCl Monocyte in LEAP092
# NULL B7H4 Cancer cell Prol&Macrophage M2 in LEAP024
# NULL B7H4 Cancer cell Prol&Macrophage M2 in LEAP024
# NULL Memory CD4 T cell&Int Monocyte in LEAP043
# NULL Memory CD4 T cell&Int Monocyte in LEAP046
# NULL Memory CD4 T cell&Int Monocyte in LEAP092
# NULL Memory CD4 T cell&Int Monocyte in LEAP045
# NULL Memory CD4 T cell&Int Monocyte in LEAP046
# NULL Memory CD4 T cell&NonCl Monocyte in LEAP092
# NULL Memory CD4 T cell&Macrophage M2 in LEAP024
# NULL Memory CD4 T cell&Macrophage M2 in LEAP024
# NULL Int Monocyte&NonCl Monocyte in LEAP043
# NULL Int Monocyte&NonCl Monocyte in LEAP046
# NULL Int Monocyte&NonCl Monocyte in LEAP064
# NULL Int Monocyte&NonCl Monocyte in LEAP092
# NULL Int Monocyte&NonCl Monocyte in LEAP045
# NULL Int Monocyte&NonCl Monocyte in LEAP046
# NULL Int Monocyte&NonCl Monocyte in LEAP064
# NULL Int Monocyte&Macrophage + HLA in LEAP043
# NULL Int Monocyte&Macrophage + HLA in LEAP046
# NULL Int Monocyte&Macrophage + HLA in LEAP075
# NULL Int Monocyte&Macrophage + HLA in LEAP092
# NULL Int Monocyte&Macrophage + HLA in LEAP045
# NULL Int Monocyte&Macrophage + HLA in LEAP046
# NULL Int Monocyte&Neutrophil in LEAP043
# NULL Int Monocyte&Neutrophil in LEAP046
# NULL Int Monocyte&Neutrophil in LEAP092
# NULL Int Monocyte&Neutrophil in LEAP045
# NULL Int Monocyte&Neutrophil in LEAP046
# NULL Int Monocyte&CD8 T cell in LEAP043
# NULL Int Monocyte&CD8 T cell in LEAP046
# NULL Int Monocyte&CD8 T cell in LEAP092
# NULL Int Monocyte&CD8 T cell in LEAP045
# NULL Int Monocyte&CD8 T cell in LEAP046
# NULL Int Monocyte&Macrophage M2 in LEAP024
# NULL Int Monocyte&Macrophage M2 in LEAP043
# NULL Int Monocyte&Macrophage M2 in LEAP046
# NULL Int Monocyte&Macrophage M2 in LEAP068
# NULL Int Monocyte&Macrophage M2 in LEAP075
# NULL Int Monocyte&Macrophage M2 in LEAP092
# NULL Int Monocyte&Macrophage M2 in LEAP024
# NULL Int Monocyte&Macrophage M2 in LEAP045
# NULL Int Monocyte&Macrophage M2 in LEAP046
# NULL Int Monocyte&Macrophage M2 in LEAP068
# NULL NonCl Monocyte&Macrophage + HLA in LEAP092
# NULL NonCl Monocyte&Neutrophil in LEAP092
# NULL NonCl Monocyte&CD8 T cell in LEAP092
# NULL NonCl Monocyte&Macrophage M2 in LEAP024
# NULL NonCl Monocyte&Macrophage M2 in LEAP092
# NULL NonCl Monocyte&Macrophage M2 in LEAP024
# NULL Macrophage + HLA&Macrophage M2 in LEAP024
# NULL Macrophage + HLA&Macrophage M2 in LEAP024
# NULL Neutrophil&Macrophage M2 in LEAP024
# NULL Neutrophil&Macrophage M2 in LEAP024
# NULL CD8 T cell&Macrophage M2 in LEAP024
# NULL CD8 T cell&Macrophage M2 in LEAP024

# %%
# sort the cell pairs in pairwise_enrichment by the absolute value of total_diff
sorted_pairs = sorted(pairwise_enrichment.items(), key=lambda x: abs(x[1]['total_diff']), reverse=True)

# %%
sorted_pairs
# Out:
# [(('B7H4 Cancer cell', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(1.2020621914868244),
#    'prepost_diff': np.float64(2.8105742591664713),
#    'total_diff': np.float64(4.012636450653296)}),
#  (('Macrophage M1', 'Fibroblast'),
#   {'respnonresp_diff': np.float64(-1.727370710764752),
#    'prepost_diff': np.float64(-2.0368245922265187),
#    'total_diff': np.float64(-3.7641953029912707)}),
#  (('Antigen presenting cell', 'Fibroblast'),
#   {'respnonresp_diff': np.float64(-1.803192993290088),
#    'prepost_diff': np.float64(-1.8345026822303334),
#    'total_diff': np.float64(-3.6376956755204217)}),
#  (('Endothelial cell', 'Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-1.049355915859536),
#    'prepost_diff': np.float64(-1.8707749549748627),
#    'total_diff': np.float64(-2.9201308708343987)}),
#  (('Cancer cell', 'Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(2.9765854909161025),
#    'prepost_diff': np.float64(-0.09002870902931281),
#    'total_diff': np.float64(2.8865567818867897)}),
#  (('Cancer cell Prol', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(0.8966615500161019),
#    'prepost_diff': np.float64(1.9026685095170466),
#    'total_diff': np.float64(2.7993300595331485)}),
#  (('Macrophage M1', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(2.6599124977669653),
#    'prepost_diff': np.float64(0.09666228101246688),
#    'total_diff': np.float64(2.756574778779432)}),
#  (('Memory CD4 T cell', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(3.0339670019939815),
#    'prepost_diff': np.float64(-0.3290221088234606),
#    'total_diff': np.float64(2.704944893170521)}),
#  (('Macrophage M1', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(-0.6367290800850034),
#    'prepost_diff': np.float64(-1.7900438562496424),
#    'total_diff': np.float64(-2.426772936334646)}),
#  (('B7H4 Cancer cell', 'Endothelial cell'),
#   {'respnonresp_diff': np.float64(-0.20218164654609083),
#    'prepost_diff': np.float64(-2.1940390141269637),
#    'total_diff': np.float64(-2.3962206606730545)}),
#  (('Antigen presenting cell', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-0.5274531277750953),
#    'prepost_diff': np.float64(-1.7175522126803324),
#    'total_diff': np.float64(-2.2450053404554278)}),
#  (('Endothelial cell', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-0.7500664419493184),
#    'prepost_diff': np.float64(-1.457066254856791),
#    'total_diff': np.float64(-2.2071326968061094)}),
#  (('B7H4 Cancer cell', 'Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(1.126694282273351),
#    'prepost_diff': np.float64(0.9873727499129097),
#    'total_diff': np.float64(2.1140670321862607)}),
#  (('Fibroblast', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-0.035050526382785385),
#    'prepost_diff': np.float64(-2.0494855219825525),
#    'total_diff': np.float64(-2.084536048365338)}),
#  (('Cancer cell Prol', 'Fibroblast'),
#   {'respnonresp_diff': np.float64(-0.508095760704558),
#    'prepost_diff': np.float64(-1.485632675491333),
#    'total_diff': np.float64(-1.993728436195891)}),
#  (('B7H4 Cancer cell', 'Antigen presenting cell'),
#   {'respnonresp_diff': np.float64(-0.8963262860408729),
#    'prepost_diff': np.float64(-1.0514209028546597),
#    'total_diff': np.float64(-1.9477471888955327)}),
#  (('B7H4 Cancer cell', 'Cancer cell'),
#   {'respnonresp_diff': np.float64(1.373177854620768),
#    'prepost_diff': np.float64(0.5490895708838934),
#    'total_diff': np.float64(1.9222674255046615)}),
#  (('Cancer cell', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(1.6786155613597207),
#    'prepost_diff': np.float64(0.20169200269102835),
#    'total_diff': np.float64(1.880307564050749)}),
#  (('NK/CD8', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(1.3393580992450635),
#    'prepost_diff': np.float64(0.38241373819026414),
#    'total_diff': np.float64(1.7217718374353277)}),
#  (('Antigen presenting cell', 'Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-1.1902992242548525),
#    'prepost_diff': np.float64(-0.5240641307114791),
#    'total_diff': np.float64(-1.7143633549663315)}),
#  (('Fibroblast', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.47361444255292673),
#    'prepost_diff': np.float64(-1.175843665428569),
#    'total_diff': np.float64(-1.6494581079814958)}),
#  (('Antigen presenting cell', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(2.2413770701132956),
#    'prepost_diff': np.float64(-0.6050113068750118),
#    'total_diff': np.float64(1.6363657632382838)}),
#  (('Regulatory T cell', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-0.3075845817342504),
#    'prepost_diff': np.float64(1.9412329324428677),
#    'total_diff': np.float64(1.6336483507086172)}),
#  (('Cancer cell', 'Endothelial cell'),
#   {'respnonresp_diff': np.float64(-0.6142864860255042),
#    'prepost_diff': np.float64(-0.999210233193172),
#    'total_diff': np.float64(-1.6134967192186762)}),
#  (('Cancer cell', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(-2.0033899825536627),
#    'prepost_diff': np.float64(3.610646951859609),
#    'total_diff': np.float64(1.6072569693059462)}),
#  (('Antigen presenting cell', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(0.3488386496444744),
#    'prepost_diff': np.float64(-1.817904507002082),
#    'total_diff': np.float64(-1.4690658573576076)}),
#  (('Fibroblast', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(-0.9658326520657975),
#    'prepost_diff': np.float64(-0.4889754122992757),
#    'total_diff': np.float64(-1.4548080643650732)}),
#  (('Macrophage M1', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-0.38532055610146543),
#    'prepost_diff': np.float64(-1.0098909588841871),
#    'total_diff': np.float64(-1.3952115149856525)}),
#  (('Cancer cell Prol', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(1.1827759922276673),
#    'prepost_diff': np.float64(0.20973903140811573),
#    'total_diff': np.float64(1.392515023635783)}),
#  (('Antigen presenting cell', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(0.48513253575802395),
#    'prepost_diff': np.float64(-1.7800870364663843),
#    'total_diff': np.float64(-1.2949545007083603)}),
#  (('Macrophage M1', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(0.7954818617042783),
#    'prepost_diff': np.float64(0.49581428630853885),
#    'total_diff': np.float64(1.2912961480128171)}),
#  (('B7H4 Cancer cell Prol', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(-0.7537355170185749),
#    'prepost_diff': np.float64(-0.5238849039582658),
#    'total_diff': np.float64(-1.2776204209768407)}),
#  (('Fibroblast', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(-0.31049612577683816),
#    'prepost_diff': np.float64(-0.955086644507997),
#    'total_diff': np.float64(-1.2655827702848352)}),
#  (('Macrophage M1', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(-0.4974437417387776),
#    'prepost_diff': np.float64(-0.7126293047599466),
#    'total_diff': np.float64(-1.2100730464987242)}),
#  (('Fibroblast', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.2919651598504227),
#    'prepost_diff': np.float64(-0.89814681432499),
#    'total_diff': np.float64(-1.1901119741754127)}),
#  (('Macrophage + HLA', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(1.3933685255377766),
#    'prepost_diff': np.float64(-0.2593805151077817),
#    'total_diff': np.float64(1.1339880104299949)}),
#  (('Int Monocyte', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(0.2490006212001914),
#    'prepost_diff': np.float64(-1.3779601178487448),
#    'total_diff': np.float64(-1.1289594966485534)}),
#  (('Fibroblast', 'NK/CD8'),
#   {'respnonresp_diff': np.float64(-0.248442771101675),
#    'prepost_diff': np.float64(-0.8690616885622038),
#    'total_diff': np.float64(-1.1175044596638788)}),
#  (('Fibroblast', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(-0.581688246700188),
#    'prepost_diff': np.float64(-0.5355084404321706),
#    'total_diff': np.float64(-1.1171966871323586)}),
#  (('Macrophage M1', 'Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-1.0459394135855336),
#    'prepost_diff': np.float64(-0.07029572786069593),
#    'total_diff': np.float64(-1.1162351414462295)}),
#  (('Macrophage M1', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(0.29199514640857016),
#    'prepost_diff': np.float64(-1.407300890286852),
#    'total_diff': np.float64(-1.1153057438782819)}),
#  (('B7H4 Cancer cell', 'Fibroblast'),
#   {'respnonresp_diff': np.float64(0.3479149554494194),
#    'prepost_diff': np.float64(-1.4614943838160377),
#    'total_diff': np.float64(-1.1135794283666183)}),
#  (('Neutrophil', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(0.9261875698495278),
#    'prepost_diff': np.float64(0.16436881511749757),
#    'total_diff': np.float64(1.0905563849670252)}),
#  (('Endothelial cell', 'Fibroblast'),
#   {'respnonresp_diff': np.float64(-2.653130062779396),
#    'prepost_diff': np.float64(1.5704098765345207),
#    'total_diff': np.float64(-1.0827201862448752)}),
#  (('Fibroblast', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(0.11744145803374284),
#    'prepost_diff': np.float64(-1.1924216192880772),
#    'total_diff': np.float64(-1.0749801612543344)}),
#  (('Endothelial cell', 'NK/CD8'),
#   {'respnonresp_diff': np.float64(1.2267699504848286),
#    'prepost_diff': np.float64(-0.16945195110561118),
#    'total_diff': np.float64(1.0573179993792174)}),
#  (('Macrophage M1', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(-1.0911560833110485),
#    'prepost_diff': np.float64(0.034784491407315155),
#    'total_diff': np.float64(-1.0563715919037333)}),
#  (('Cancer cell Prol', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(-0.8723457872853122),
#    'prepost_diff': np.float64(-0.10572137983841134),
#    'total_diff': np.float64(-0.9780671671237235)}),
#  (('Cancer cell Prol', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(-0.47453462084854214),
#    'prepost_diff': np.float64(1.4423714233794591),
#    'total_diff': np.float64(0.967836802530917)}),
#  (('Antigen presenting cell', 'Cl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.7269052184123957),
#    'prepost_diff': np.float64(-0.23749771264815758),
#    'total_diff': np.float64(-0.9644029310605533)}),
#  (('NK/CD8', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(-0.6633603539586695),
#    'prepost_diff': np.float64(-0.29256391373902435),
#    'total_diff': np.float64(-0.9559242676976939)}),
#  (('Fibroblast', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.6257312741026091),
#    'prepost_diff': np.float64(-0.3075386453596908),
#    'total_diff': np.float64(-0.9332699194622999)}),
#  (('Macrophage M1', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(-0.1191314887602235),
#    'prepost_diff': np.float64(-0.8112282563304147),
#    'total_diff': np.float64(-0.9303597450906382)}),
#  (('Macrophage M1', 'Cancer cell'),
#   {'respnonresp_diff': np.float64(-2.1771445108256087),
#    'prepost_diff': np.float64(3.1073278163815985),
#    'total_diff': np.float64(0.9301833055559898)}),
#  (('NK/CD8', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.2996728783908045),
#    'prepost_diff': np.float64(0.6138500833501128),
#    'total_diff': np.float64(0.9135229617409173)}),
#  (('Antigen presenting cell', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(-0.6683355359351151),
#    'prepost_diff': np.float64(-0.20457956220248652),
#    'total_diff': np.float64(-0.8729150981376016)}),
#  (('Antigen presenting cell', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.94428106832379),
#    'prepost_diff': np.float64(0.07193398495054275),
#    'total_diff': np.float64(-0.8723470833732473)}),
#  (('Cancer cell Prol', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(0.48558614534698175),
#    'prepost_diff': np.float64(0.3359696515651472),
#    'total_diff': np.float64(0.821555796912129)}),
#  (('Endothelial cell', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(-0.4400198028320557),
#    'prepost_diff': np.float64(1.2590448053378132),
#    'total_diff': np.float64(0.8190250025057575)}),
#  (('Macrophage M1', 'Cl Monocyte'),
#   {'respnonresp_diff': np.float64(-1.060011070241564),
#    'prepost_diff': np.float64(0.2636835451748125),
#    'total_diff': np.float64(-0.7963275250667514)}),
#  (('Cancer cell', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(-1.6673559347355935),
#    'prepost_diff': np.float64(2.4622658173915433),
#    'total_diff': np.float64(0.7949098826559498)}),
#  (('B7H4 Cancer cell', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(-1.2087497016343178),
#    'prepost_diff': np.float64(0.42187765462711635),
#    'total_diff': np.float64(-0.7868720470072015)}),
#  (('Macrophage M1', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(0.18369207249240294),
#    'prepost_diff': np.float64(0.5791588526372089),
#    'total_diff': np.float64(0.7628509251296118)}),
#  (('Macrophage M1', 'B7H4 Cancer cell'),
#   {'respnonresp_diff': np.float64(-1.0253389052427933),
#    'prepost_diff': np.float64(0.2642627821831991),
#    'total_diff': np.float64(-0.7610761230595942)}),
#  (('Cancer cell', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(1.4275336171158512),
#    'prepost_diff': np.float64(-0.676473885289768),
#    'total_diff': np.float64(0.7510597318260832)}),
#  (('Macrophage M1', 'NK/CD8'),
#   {'respnonresp_diff': np.float64(0.035875152612960814),
#    'prepost_diff': np.float64(0.709359114208727),
#    'total_diff': np.float64(0.7452342668216878)}),
#  (('NK/CD8', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(-0.29599421510020496),
#    'prepost_diff': np.float64(1.0404059136752573),
#    'total_diff': np.float64(0.7444116985750523)}),
#  (('Cancer cell', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.8966838545446021),
#    'prepost_diff': np.float64(-0.15771321029224383),
#    'total_diff': np.float64(0.7389706442523583)}),
#  (('Endothelial cell', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(0.697352995193244),
#    'prepost_diff': np.float64(-1.4269079858396645),
#    'total_diff': np.float64(-0.7295549906464205)}),
#  (('Cancer cell Prol', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.36319783308014464),
#    'prepost_diff': np.float64(-0.36488882683494095),
#    'total_diff': np.float64(-0.7280866599150856)}),
#  (('B7H4 Cancer cell Prol', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(0.6496526802889901),
#    'prepost_diff': np.float64(0.05414310217575091),
#    'total_diff': np.float64(0.7037957824647411)}),
#  (('Memory CD4 T cell', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.15651613988415192),
#    'prepost_diff': np.float64(-0.5430985126522871),
#    'total_diff': np.float64(-0.6996146525364391)}),
#  (('Antigen presenting cell', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(0.7191899158523722),
#    'prepost_diff': np.float64(-1.4101525561733474),
#    'total_diff': np.float64(-0.6909626403209752)}),
#  (('Int Monocyte', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.12915004319440165),
#    'prepost_diff': np.float64(0.5522485485674014),
#    'total_diff': np.float64(0.6813985917618031)}),
#  (('Cancer cell', 'Cl Monocyte'),
#   {'respnonresp_diff': np.float64(0.12745662746099617),
#    'prepost_diff': np.float64(0.5498732087667106),
#    'total_diff': np.float64(0.6773298362277068)}),
#  (('Endothelial cell', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(-0.22142468210857424),
#    'prepost_diff': np.float64(-0.44046083832339306),
#    'total_diff': np.float64(-0.6618855204319674)}),
#  (('Fibroblast', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(2.095670933420328),
#    'prepost_diff': np.float64(-1.4375587371538021),
#    'total_diff': np.float64(0.6581121962665257)}),
#  (('CD8 T cell', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(0.7748689363921861),
#    'prepost_diff': np.float64(-0.13388605076811166),
#    'total_diff': np.float64(0.6409828856240745)}),
#  (('Cl Monocyte', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(1.247489238444617),
#    'prepost_diff': np.float64(-0.6210423791517085),
#    'total_diff': np.float64(0.6264468592929086)}),
#  (('Endothelial cell', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(0.5699793334296416),
#    'prepost_diff': np.float64(-1.1950580506815498),
#    'total_diff': np.float64(-0.6250787172519082)}),
#  (('Memory CD4 T cell', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.3870494362615576),
#    'prepost_diff': np.float64(-0.22273218944331427),
#    'total_diff': np.float64(-0.6097816257048718)}),
#  (('NK/CD8', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(0.19666346686669756),
#    'prepost_diff': np.float64(0.37061086573509633),
#    'total_diff': np.float64(0.5672743326017939)}),
#  (('Endothelial cell', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.47087461052646273),
#    'prepost_diff': np.float64(-0.09556675291350625),
#    'total_diff': np.float64(-0.566441363439969)}),
#  (('Memory CD8 T cell', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(-0.09009723857333898),
#    'prepost_diff': np.float64(-0.4606655701011967),
#    'total_diff': np.float64(-0.5507628086745356)}),
#  (('B7H4 Cancer cell', 'Cl Monocyte'),
#   {'respnonresp_diff': np.float64(0.6081409256689307),
#    'prepost_diff': np.float64(-0.07344087048598175),
#    'total_diff': np.float64(0.534700055182949)}),
#  (('Cl Monocyte', 'Fibroblast'),
#   {'respnonresp_diff': np.float64(-0.6251047789716687),
#    'prepost_diff': np.float64(0.1083252427687329),
#    'total_diff': np.float64(-0.5167795362029358)}),
#  (('Macrophage M1', 'Endothelial cell'),
#   {'respnonresp_diff': np.float64(-0.29262514044507293),
#    'prepost_diff': np.float64(0.8042706181933867),
#    'total_diff': np.float64(0.5116454777483138)}),
#  (('Cancer cell', 'NK/CD8'),
#   {'respnonresp_diff': np.float64(-0.44140241086583565),
#    'prepost_diff': np.float64(0.9473397904230998),
#    'total_diff': np.float64(0.5059373795572641)}),
#  (('Antigen presenting cell', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(-0.15761361021131953),
#    'prepost_diff': np.float64(-0.3394092357392091),
#    'total_diff': np.float64(-0.49702284595052865)}),
#  (('B cell + HLA', 'Fibroblast'),
#   {'respnonresp_diff': np.float64(-0.3033785740185404),
#    'prepost_diff': np.float64(-0.16784015439032285),
#    'total_diff': np.float64(-0.47121872840886325)}),
#  (('Cancer cell', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(0.39009609825996927),
#    'prepost_diff': np.float64(0.07750884918505674),
#    'total_diff': np.float64(0.467604947445026)}),
#  (('Cancer cell Prol', 'Cl Monocyte'),
#   {'respnonresp_diff': np.float64(0.3743315258884923),
#    'prepost_diff': np.float64(0.08430113524282001),
#    'total_diff': np.float64(0.4586326611313123)}),
#  (('B cell + HLA', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(0.13868826796245814),
#    'prepost_diff': np.float64(0.3059369799730964),
#    'total_diff': np.float64(0.4446252479355545)}),
#  (('NK/CD8', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(0.020502934951973195),
#    'prepost_diff': np.float64(-0.4636948716136081),
#    'total_diff': np.float64(-0.4431919366616349)}),
#  (('Regulatory T cell', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(0.9871096286500258),
#    'prepost_diff': np.float64(-1.412314179700748),
#    'total_diff': np.float64(-0.4252045510507221)}),
#  (('B cell + HLA', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.08847180040517677),
#    'prepost_diff': np.float64(-0.3292538198916444),
#    'total_diff': np.float64(-0.41772562029682114)}),
#  (('NK/CD8', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.1275029951653534),
#    'prepost_diff': np.float64(0.5372861542098706),
#    'total_diff': np.float64(0.4097831590445172)}),
#  (('B cell + HLA', 'Cancer cell'),
#   {'respnonresp_diff': np.float64(-0.403982454722642),
#    'prepost_diff': np.float64(0.8126076057849024),
#    'total_diff': np.float64(0.40862515106226044)}),
#  (('Macrophage M1', 'B cell + HLA'),
#   {'respnonresp_diff': np.float64(-0.29012100530366336),
#    'prepost_diff': np.float64(-0.11706861342565289),
#    'total_diff': np.float64(-0.40718961872931625)}),
#  (('B7H4 Cancer cell', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(-1.02567502492613),
#    'prepost_diff': np.float64(1.4051549272686663),
#    'total_diff': np.float64(0.37947990234253637)}),
#  (('Endothelial cell', 'Cl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.589565386624151),
#    'prepost_diff': np.float64(0.21459803958656765),
#    'total_diff': np.float64(-0.3749673470375834)}),
#  (('Cancer cell', 'Antigen presenting cell'),
#   {'respnonresp_diff': np.float64(-1.8580401287313766),
#    'prepost_diff': np.float64(2.2282442939637197),
#    'total_diff': np.float64(0.3702041652323431)}),
#  (('NonCl Monocyte', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.40046719986718765),
#    'prepost_diff': np.float64(0.03275519335783256),
#    'total_diff': np.float64(-0.3677120065093551)}),
#  (('Cl Monocyte', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(-0.862192056023533),
#    'prepost_diff': np.float64(0.4969366614134827),
#    'total_diff': np.float64(-0.3652553946100503)}),
#  (('Cl Monocyte', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(-0.3875624434801845),
#    'prepost_diff': np.float64(0.023351545321571687),
#    'total_diff': np.float64(-0.3642108981586128)}),
#  (('Regulatory T cell', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(0.1015202504350044),
#    'prepost_diff': np.float64(-0.4650125464811336),
#    'total_diff': np.float64(-0.3634922960461292)}),
#  (('Macrophage + HLA', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.15886689179163982),
#    'prepost_diff': np.float64(0.5210740627593786),
#    'total_diff': np.float64(0.3622071709677388)}),
#  (('NK/CD8', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-0.0716805590319951),
#    'prepost_diff': np.float64(-0.2881140059645544),
#    'total_diff': np.float64(-0.3597945649965495)}),
#  (('Regulatory T cell', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(-0.20157833534585767),
#    'prepost_diff': np.float64(0.5608970355831102),
#    'total_diff': np.float64(0.35931870023725254)}),
#  (('Memory CD4 T cell', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.48526015037280057),
#    'prepost_diff': np.float64(-0.8287995362725926),
#    'total_diff': np.float64(-0.34353938589979205)}),
#  (('Memory CD8 T cell', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(0.2192535864822739),
#    'prepost_diff': np.float64(-0.5622570450598396),
#    'total_diff': np.float64(-0.34300345857756576)}),
#  (('Memory CD8 T cell', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(0.28325205051175295),
#    'prepost_diff': np.float64(-0.6114506786008139),
#    'total_diff': np.float64(-0.328198628089061)}),
#  (('B cell + HLA', 'Antigen presenting cell'),
#   {'respnonresp_diff': np.float64(0.4693752476858726),
#    'prepost_diff': np.float64(-0.7855887896068172),
#    'total_diff': np.float64(-0.31621354192094464)}),
#  (('Endothelial cell', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(1.6773837866359513),
#    'prepost_diff': np.float64(-1.9917313894533626),
#    'total_diff': np.float64(-0.31434760281741125)}),
#  (('Macrophage + HLA', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(-0.0214223293509464),
#    'prepost_diff': np.float64(-0.2920115072811081),
#    'total_diff': np.float64(-0.3134338366320545)}),
#  (('Cancer cell Prol', 'NK/CD8'),
#   {'respnonresp_diff': np.float64(-0.4666660109232432),
#    'prepost_diff': np.float64(0.1584880228192347),
#    'total_diff': np.float64(-0.30817798810400854)}),
#  (('NonCl Monocyte', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(-0.3277484624452276),
#    'prepost_diff': np.float64(0.019809112666836437),
#    'total_diff': np.float64(-0.30793934977839116)}),
#  (('NonCl Monocyte', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.3920483303501718),
#    'prepost_diff': np.float64(0.08608188625349256),
#    'total_diff': np.float64(-0.3059664440966792)}),
#  (('Endothelial cell', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(0.06613077450511758),
#    'prepost_diff': np.float64(-0.368911777792341),
#    'total_diff': np.float64(-0.30278100328722346)}),
#  (('Cancer cell Prol', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(-2.464330112600635),
#    'prepost_diff': np.float64(2.17817690975334),
#    'total_diff': np.float64(-0.28615320284729506)}),
#  (('B7H4 Cancer cell Prol', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.14673612625542765),
#    'prepost_diff': np.float64(-0.13793695713051868),
#    'total_diff': np.float64(-0.2846730833859463)}),
#  (('Cl Monocyte', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(0.5055194563610895),
#    'prepost_diff': np.float64(-0.22207932100912994),
#    'total_diff': np.float64(0.28344013535195955)}),
#  (('B cell + HLA', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(0.513306232644523),
#    'prepost_diff': np.float64(-0.2378727595867278),
#    'total_diff': np.float64(0.2754334730577952)}),
#  (('B cell + HLA', 'B7H4 Cancer cell'),
#   {'respnonresp_diff': np.float64(-0.0058634453249051255),
#    'prepost_diff': np.float64(-0.2660700937498292),
#    'total_diff': np.float64(-0.27193353907473433)}),
#  (('Memory CD4 T cell', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.2647644941913042),
#    'prepost_diff': np.float64(-0.0013130650743917727),
#    'total_diff': np.float64(-0.266077559265696)}),
#  (('B cell + HLA', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(0.14191966382904797),
#    'prepost_diff': np.float64(-0.4072926373641721),
#    'total_diff': np.float64(-0.2653729735351241)}),
#  (('B cell + HLA', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(0.20537242273856177),
#    'prepost_diff': np.float64(-0.4544870410655247),
#    'total_diff': np.float64(-0.2491146183269629)}),
#  (('Cl Monocyte', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(1.3364631831650533),
#    'prepost_diff': np.float64(-1.5799595211632933),
#    'total_diff': np.float64(-0.24349633799824)}),
#  (('NK/CD8', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(0.1272519641787344),
#    'prepost_diff': np.float64(-0.36911337329715543),
#    'total_diff': np.float64(-0.24186140911842102)}),
#  (('Cancer cell', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(-0.3290165812600404),
#    'prepost_diff': np.float64(0.5578463858624825),
#    'total_diff': np.float64(0.22882980460244207)}),
#  (('B7H4 Cancer cell', 'NK/CD8'),
#   {'respnonresp_diff': np.float64(0.1882123112398708),
#    'prepost_diff': np.float64(-0.4161244527685124),
#    'total_diff': np.float64(-0.2279121415286416)}),
#  (('Memory CD8 T cell', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(0.018387225796434703),
#    'prepost_diff': np.float64(-0.2270533356879601),
#    'total_diff': np.float64(-0.2086661098915254)}),
#  (('Macrophage M1', 'Antigen presenting cell'),
#   {'respnonresp_diff': np.float64(1.6608564027319668),
#    'prepost_diff': np.float64(-1.4522666210094792),
#    'total_diff': np.float64(0.20858978172248754)}),
#  (('Cl Monocyte', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.24515577152474788),
#    'prepost_diff': np.float64(0.04295656573786327),
#    'total_diff': np.float64(-0.2021992057868846)}),
#  (('Endothelial cell', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(-0.20669360910609452),
#    'prepost_diff': np.float64(0.4083140553531176),
#    'total_diff': np.float64(0.20162044624702308)}),
#  (('B7H4 Cancer cell Prol', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.5944355481936752),
#    'prepost_diff': np.float64(-0.7948336210978783),
#    'total_diff': np.float64(-0.20039807290420308)}),
#  (('Endothelial cell', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.3281521269462944),
#    'prepost_diff': np.float64(0.12917670689384345),
#    'total_diff': np.float64(-0.19897542005245097)}),
#  (('Regulatory T cell', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(0.033451254199563685),
#    'prepost_diff': np.float64(-0.23062006088270362),
#    'total_diff': np.float64(-0.19716880668313994)}),
#  (('Memory CD8 T cell', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(-0.011903157620154148),
#    'prepost_diff': np.float64(0.20239728825053566),
#    'total_diff': np.float64(0.1904941306303815)}),
#  (('B cell + HLA', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.2886529418409929),
#    'prepost_diff': np.float64(0.09820349250730093),
#    'total_diff': np.float64(-0.19044944933369196)}),
#  (('B7H4 Cancer cell', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(0.7335513247242628),
#    'prepost_diff': np.float64(-0.547617076792486),
#    'total_diff': np.float64(0.18593424793177682)}),
#  (('Cancer cell', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(-0.15709098874101105),
#    'prepost_diff': np.float64(-0.028041729798487125),
#    'total_diff': np.float64(-0.18513271853949817)}),
#  (('Cancer cell', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.282681362603881),
#    'prepost_diff': np.float64(0.4584794030830224),
#    'total_diff': np.float64(0.17579804047914138)}),
#  (('Regulatory T cell', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.14486345339551882),
#    'prepost_diff': np.float64(-0.030101667233149387),
#    'total_diff': np.float64(-0.1749651206286682)}),
#  (('B7H4 Cancer cell', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.6735632740554873),
#    'prepost_diff': np.float64(-0.84838442016798),
#    'total_diff': np.float64(-0.17482114611249266)}),
#  (('Fibroblast', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(-0.23118062095986924),
#    'prepost_diff': np.float64(0.05828787520717571),
#    'total_diff': np.float64(-0.17289274575269353)}),
#  (('B7H4 Cancer cell', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(0.6515696023270684),
#    'prepost_diff': np.float64(-0.48244636698777965),
#    'total_diff': np.float64(0.16912323533928875)}),
#  (('Int Monocyte', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(-0.19131536995332943),
#    'prepost_diff': np.float64(0.02377906379358985),
#    'total_diff': np.float64(-0.16753630615973958)}),
#  (('Regulatory T cell', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.3410255708111001),
#    'prepost_diff': np.float64(-0.5042635060879823),
#    'total_diff': np.float64(-0.16323793527688224)}),
#  (('Antigen presenting cell', 'NK/CD8'),
#   {'respnonresp_diff': np.float64(0.2807428075777364),
#    'prepost_diff': np.float64(-0.4385446799207637),
#    'total_diff': np.float64(-0.15780187234302728)}),
#  (('NK/CD8', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.1961002028296034),
#    'prepost_diff': np.float64(0.04779185159837834),
#    'total_diff': np.float64(-0.14830835123122504)}),
#  (('Cancer cell Prol', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.08034912723912613),
#    'prepost_diff': np.float64(-0.06749281230996806),
#    'total_diff': np.float64(-0.1478419395490942)}),
#  (('Macrophage M1', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(-0.3937704603534276),
#    'prepost_diff': np.float64(0.5379282228309712),
#    'total_diff': np.float64(0.14415776247754358)}),
#  (('Memory CD8 T cell', 'Memory CD4 T cell'),
#   {'respnonresp_diff': np.float64(-0.39077778829133697),
#    'prepost_diff': np.float64(0.25143828160879395),
#    'total_diff': np.float64(-0.13933950668254302)}),
#  (('B7H4 Cancer cell', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(-0.7440585056859752),
#    'prepost_diff': np.float64(0.8827548415091473),
#    'total_diff': np.float64(0.1386963358231721)}),
#  (('NonCl Monocyte', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.26311925672019326),
#    'prepost_diff': np.float64(-0.12546225175036593),
#    'total_diff': np.float64(0.13765700496982733)}),
#  (('Cl Monocyte', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.12425366998666071),
#    'prepost_diff': np.float64(-0.0038362653626163312),
#    'total_diff': np.float64(0.12041740462404438)}),
#  (('B7H4 Cancer cell', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(0.03031439801968011),
#    'prepost_diff': np.float64(0.08705411612401887),
#    'total_diff': np.float64(0.11736851414369898)}),
#  (('Antigen presenting cell', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(0.23302473564404425),
#    'prepost_diff': np.float64(-0.11873620250537109),
#    'total_diff': np.float64(0.11428853313867315)}),
#  (('Memory CD8 T cell', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(0.21679347464045884),
#    'prepost_diff': np.float64(-0.3277212224459911),
#    'total_diff': np.float64(-0.11092774780553227)}),
#  (('B7H4 Cancer cell Prol', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(0.17335612872719736),
#    'prepost_diff': np.float64(-0.27970690780816754),
#    'total_diff': np.float64(-0.10635077908097018)}),
#  (('Cl Monocyte', 'NK/CD8'),
#   {'respnonresp_diff': np.float64(-0.3290865162168255),
#    'prepost_diff': np.float64(0.2247564107462221),
#    'total_diff': np.float64(-0.1043301054706034)}),
#  (('Cl Monocyte', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(0.058952986728052076),
#    'prepost_diff': np.float64(0.040201104692575484),
#    'total_diff': np.float64(0.09915409142062756)}),
#  (('Cl Monocyte', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.07990649303268657),
#    'prepost_diff': np.float64(-0.016446218828877174),
#    'total_diff': np.float64(-0.09635271186156374)}),
#  (('Cancer cell Prol', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(0.24534472048176081),
#    'prepost_diff': np.float64(-0.15441136348218393),
#    'total_diff': np.float64(0.09093335699957689)}),
#  (('Regulatory T cell', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(0.21600417985824885),
#    'prepost_diff': np.float64(-0.1324183978125772),
#    'total_diff': np.float64(0.08358578204567166)}),
#  (('B7H4 Cancer cell Prol', 'CD8 T cell'),
#   {'respnonresp_diff': np.float64(-1.7303465312526871),
#    'prepost_diff': np.float64(1.6554001780847203),
#    'total_diff': np.float64(-0.07494635316796683)}),
#  (('B cell + HLA', 'Memory CD8 T cell'),
#   {'respnonresp_diff': np.float64(-0.16747830099216895),
#    'prepost_diff': np.float64(0.22635991766904684),
#    'total_diff': np.float64(0.058881616676877885)}),
#  (('Cancer cell Prol', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(0.40742005929770775),
#    'prepost_diff': np.float64(-0.4634875046821296),
#    'total_diff': np.float64(-0.05606744538442188)}),
#  (('B cell + HLA', 'NK/CD8'),
#   {'respnonresp_diff': np.float64(0.20752863264581076),
#    'prepost_diff': np.float64(-0.15199223972838444),
#    'total_diff': np.float64(0.05553639291742632)}),
#  (('Cancer cell', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.9492923697301375),
#    'prepost_diff': np.float64(0.8991791965833427),
#    'total_diff': np.float64(-0.050113173146794865)}),
#  (('Int Monocyte', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(-0.1869088507414354),
#    'prepost_diff': np.float64(0.2363823650052288),
#    'total_diff': np.float64(0.0494735142637934)}),
#  (('Int Monocyte', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.22168401572081403),
#    'prepost_diff': np.float64(0.2686342683575651),
#    'total_diff': np.float64(0.046950252636751066)}),
#  (('Cl Monocyte', 'Regulatory T cell'),
#   {'respnonresp_diff': np.float64(-0.09470370903736654),
#    'prepost_diff': np.float64(0.14031417329240456),
#    'total_diff': np.float64(0.04561046425503802)}),
#  (('B cell + HLA', 'Endothelial cell'),
#   {'respnonresp_diff': np.float64(0.3772994497502513),
#    'prepost_diff': np.float64(-0.42130096140345863),
#    'total_diff': np.float64(-0.044001511653207315)}),
#  (('B cell + HLA', 'B7H4 Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(0.10624014973488838),
#    'prepost_diff': np.float64(-0.14757023721464357),
#    'total_diff': np.float64(-0.041330087479755195)}),
#  (('B cell + HLA', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.10840261017491104),
#    'prepost_diff': np.float64(0.0748334234721452),
#    'total_diff': np.float64(-0.033569186702765846)}),
#  (('Neutrophil', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(0.07758082762604246),
#    'prepost_diff': np.float64(-0.11096513737099088),
#    'total_diff': np.float64(-0.03338430974494842)}),
#  (('Antigen presenting cell', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(-0.2511492850049555),
#    'prepost_diff': np.float64(0.2819215135334393),
#    'total_diff': np.float64(0.030772228528483825)}),
#  (('B7H4 Cancer cell Prol', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(0.059509187177420264),
#    'prepost_diff': np.float64(-0.03452858862631919),
#    'total_diff': np.float64(0.024980598551101074)}),
#  (('B7H4 Cancer cell', 'NonCl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.03104516613640132),
#    'prepost_diff': np.float64(0.008099624722626625),
#    'total_diff': np.float64(-0.022945541413774695)}),
#  (('Regulatory T cell', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(-0.19857567190685854),
#    'prepost_diff': np.float64(0.17708337985153544),
#    'total_diff': np.float64(-0.021492292055323103)}),
#  (('B cell + HLA', 'Neutrophil'),
#   {'respnonresp_diff': np.float64(-0.09930231855283264),
#    'prepost_diff': np.float64(0.12022403648072177),
#    'total_diff': np.float64(0.020921717927889133)}),
#  (('B cell + HLA', 'Cl Monocyte'),
#   {'respnonresp_diff': np.float64(-0.0662229143325875),
#    'prepost_diff': np.float64(0.04578067247586906),
#    'total_diff': np.float64(-0.020442241856718446)}),
#  (('Memory CD8 T cell', 'Macrophage M2'),
#   {'respnonresp_diff': np.float64(0.05437781020859345),
#    'prepost_diff': np.float64(-0.0712089575255036),
#    'total_diff': np.float64(-0.016831147316910156)}),
#  (('B cell + HLA', 'Cancer cell Prol'),
#   {'respnonresp_diff': np.float64(-0.08842696220923962),
#    'prepost_diff': np.float64(0.07999487475326572),
#    'total_diff': np.float64(-0.008432087455973902)}),
#  (('Memory CD4 T cell', 'Int Monocyte'),
#   {'respnonresp_diff': np.float64(-0.14360195688720934),
#    'prepost_diff': np.float64(0.14993061521806927),
#    'total_diff': np.float64(0.0063286583308599376)}),
#  (('Cancer cell', 'Fibroblast'),
#   {'respnonresp_diff': np.float64(-0.3111399418435923),
#    'prepost_diff': np.float64(0.31716100143149717),
#    'total_diff': np.float64(0.006021059587904887)}),
#  (('B7H4 Cancer cell', 'Macrophage + HLA'),
#   {'respnonresp_diff': np.float64(-0.48697442212884645),
#    'prepost_diff': np.float64(0.48175984997018806),
#    'total_diff': np.float64(-0.005214572158658393)}),
#  (('Antigen presenting cell', 'Endothelial cell'),
#   {'respnonresp_diff': np.float64(0.5619574610336601),
#    'prepost_diff': np.float64(-0.5610718106484356),
#    'total_diff': np.float64(0.000885650385224479)})]

# %%
# create a table with the top 10 pairs of cell types and their differences
top_pairs = sorted_pairs[:8]
top_pairs_df = pd.DataFrame(top_pairs, columns=['Cell Type Pairs', 'Differences'])
top_pairs_df['ΔNE R_pre-nR_pre'] = top_pairs_df['Differences'].apply(lambda x: x['respnonresp_diff'])
top_pairs_df['ΔNE nR_pre-nR_post'] = top_pairs_df['Differences'].apply(lambda x: x['prepost_diff'])
top_pairs_df['Total ΔNE'] = top_pairs_df['Differences'].apply(lambda x: x['total_diff'])
top_pairs_df = top_pairs_df.drop(columns=['Differences'])
# drop the parantheses from the cell type pairs
top_pairs_df['Cell Type Pairs'] = top_pairs_df['Cell Type Pairs'].apply(lambda x: f"{x[0]} - {x[1]}")

from IPython.display import display

# Round all numeric columns to 3 decimal places
display(top_pairs_df.round(2))
# Out:
#                             Cell Type Pairs  ΔNE R_pre-nR_post  \
# 0  B7H4 Cancer cell - B7H4 Cancer cell Prol               1.20
# 1                Macrophage M1 - Fibroblast              -1.73
# 2      Antigen presenting cell - Fibroblast              -1.80
# 3       Endothelial cell - Cancer cell Prol              -1.05
# 4            Cancer cell - Cancer cell Prol               2.98
# 5  Cancer cell Prol - B7H4 Cancer cell Prol               0.90
# 6                Macrophage M1 - CD8 T cell               2.66
# 7            Memory CD4 T cell - CD8 T cell               3.03
#
#    ΔNE nR_pre-nR_post  Total ΔNE
# 0                2.81       4.01
# 1               -2.04      -3.76
# 2               -1.83      -3.64
# 3               -1.87      -2.92
# 4               -0.09       2.89
# 5                1.90       2.80
# 6                0.10       2.76
# 7               -0.33       2.70

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(16, 20))
axes = axes.flatten()

nonresp_color = "#70221C"
resp_color = "#306E28"
pre_color = "#D9C454" #np.array([217, 196,84])/255
post_color = "#711F74" # np.array([113, 31,116])/255
palette_response = sns.color_palette([nonresp_color, resp_color, post_color])

for i, (cell_pair, diffs) in enumerate(top_pairs):
    cell_type1, cell_type2 = cell_pair
    colname = cell_type1 + '_' + cell_type2

    # Prepare data for all groups
    df_resp = pretreat_metadata[pretreat_metadata['Response'] == 'Responder'][[colname]].copy()
    df_resp['Group'] = 'Responder (pre)'
    df_nonresp_pre = pretreat_metadata[pretreat_metadata['Response'] == 'Non-Responder'][[colname]].copy()
    df_nonresp_pre['Group'] = 'Non-Responder (pre)'
    df_nonresp_post = nonresp_metadata[nonresp_metadata['Sample_Type_(pre/post treatment)'] == 'post'][[colname]].copy()
    df_nonresp_post['Group'] = 'Non-Responder (post)'

    plot_df = pd.concat([df_resp, df_nonresp_pre, df_nonresp_post], axis=0)
    plot_df = plot_df.rename(columns={colname: 'Enrichment'})

    ax = axes[i]
    sns.boxplot(
        x='Group', y='Enrichment', data=plot_df, ax=ax,
        width=0.3, showcaps=False, boxprops={'facecolor':'none'}, showfliers=False, whiskerprops={'linewidth':0}
    )
    # Use palette_response for stripplot
    group_order = ['Non-Responder (pre)', 'Responder (pre)', 'Non-Responder (post)']
    palette_dict = dict(zip(group_order, palette_response))
    sns.stripplot(
        x='Group', y='Enrichment', data=plot_df, ax=ax,
        size=6, jitter=True, alpha=0.7,
        palette=palette_dict, order=group_order
    )
    ax.set_title(f"{cell_type1} - {cell_type2}")
    ax.set_ylabel('Neighbor Enrichment (z-score)')
    ax.set_xlabel('')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

plt.tight_layout()
# save figure
plt.savefig("figures/manuscript/top_cell_pairs_enrichment_across_treatment.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(
# /var/folders/92/tvn4jggs62qb78rd70twcy7w0000gn/T/ipykernel_87972/2890468564.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
