# %%
from sklearnex import patch_sklearn
import sys
import pandas as pd
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt
sys.path.append( '../../phenotyping/')
from phenotyping_utils import generate_anndata_from_ark_analysis,umap,normalise_by_group
import random
import sklearn
from xgboost import XGBClassifier
import numpy as np
import multiprocessing
from imblearn.under_sampling import RandomUnderSampler

# %%
# !ls ../../phenotyping/
# Out:
# __pycache__  create_adata.py  phenograph  phenotyping_utils.py	pixie

# %%
reload = True
file_name = '../../phenotyping/pixie/data/sc_protein_by_patient.h5ad'
if reload:
    adata = sc.read_h5ad(file_name)
else:
    base_dir = '../../../'
    cell_table_path=base_dir+'segmentation/cell_table_Denoised/cell_table_size_normalized_cell_labels.csv'
    biosamples_path=base_dir+'IMC_data/ExtraDocs/processed_response_enR.csv'
    
    adata = generate_anndata_from_ark_analysis(cell_table_path=cell_table_path,biosamples_path=biosamples_path,normalise_key='Patient')
    #consider whether to overwrite passing save = True
    #adata.write(file_name)
#adata = adata[adata.obs.qc_pass==True]
adata = normalise_by_group(adata,group_key='Leap_ID',inplace=True,force_normalisation=True)
core = adata[adata.obs['SAMPLE_TYPE_(CORE/RESECTION)']=='CORE',~adata.var.index.isin(['Carboplatin','DNA1','DNA2'])]

#X = core.layers['normalised'].copy() #adata.obsm['X_pca']
# Out:
# data seem already normalised
# Normalising anyway

# %%
def normalise_by_group(adata,group_key,quantile = 0.95,inplace = True,force_normalisation = False):
    '''Normalise cell marker by group_key'''
    if isinstance(adata, sc.AnnData):
        if np.all(adata.X<=1):
            logger.warning('data seem already normalised')
            if force_normalisation:
                logger.warning('Normalising anyway')
            else:
                logger.warning('Skipping normalisation. Select force_normalisation =True if you want to normalise anyway')
                return adata

    else:
        raise ValueError('Need adata object')

    #create a dictionary that maps adata.obs.index to indices of adata.X
    dic = {ind:i for i,ind in enumerate(adata.obs.index)}
    dic = np.vectorize(dic.__getitem__)
    out = np.zeros_like(adata.X)#vector where the normalised values are stored
    for _, index_labels in adata.obs.groupby('Patient').groups.items():
        data = adata.raw.X[dic(index_labels)]
        q = np.nanquantile(data,q = quantile,axis = 0)
        data = sklearn.preprocessing.StandardScaler().fit_transform(data)
        out[dic(index_labels)] = data
    
    if inplace:
        adata.X = out
        return adata
    else:
        return out

# %%
X = core.raw.X[:,~adata.var.index.isin(['Carboplatin','DNA1','DNA2'])]
#X = np.arcsinh(X)
adata_asinh = sc.AnnData(X)
adata_asinh.obs = core.obs
adata_asinh.var = core.var
adata_asinh.raw = adata_asinh
normalise_by_group(adata_asinh,group_key='Leap_ID',inplace=True,force_normalisation=True)
# Out:
# AnnData object with n_obs × n_vars = 2545779 × 35
#     obs: 'Pixie', 'acquisition_ID', 'Leap_ID', 'SLIDE_NUMBER', 'BIOBANK_ID', 'SAMPLE_TYPE_(CORE/RESECTION)', 'FORMAT_(FFPE/FROZEN)', 'DATE_SECTIONED', 'ST_NOTES', 'Response', 'COMMENTS', 'new_Response', 'Patient', 'qc_pass'

# %%
X[:,3]
# Out:
# array([-1.38235673,  0.69745084,         nan, ...,  0.04159348,
#                nan, -0.2175013 ])

# %%
X = core.raw.X[:,~adata.var.index.isin(['Carboplatin','DNA1','DNA2'])]
X = np.arcsinh(X)#np.log1p(X)
X = sklearn.preprocessing.StandardScaler().fit_transform(X)

y =  core.obs.Response.map({'Non-Responder':0,'pCR':1}).values

patients = core.obs.Patient.drop_duplicates()
#sample 30 percent of the Responder and non responder group
def stratify_sampling(df,key,frac = 0.2):
    n_samples = int(len(df)*frac)
    return df.drop_duplicates().groupby(by =key,observed = True).apply(
    lambda x: x.sample(n = int(n_samples/2))#n_samples/2 because half to responder and half to non responder
    )
def train_test_split(X,y,core):
    patients_test = stratify_sampling(core.obs[['Patient','Response']].drop_duplicates(),key = 'Response').Patient    
    
    cond = core.obs.Patient.isin(patients_test)
    '''
    #split train/tesgt according to acquisition_Ids 
    test_acq_ids = random.sample(core.obs.acquisition_ID.drop_duplicates().to_list(),int(len(core.obs.acquisition_ID.drop_duplicates())*0.33))
    cond = core.obs.acquisition_ID.isin(test_acq_ids)
    '''
    X_train,y_train = X[~cond],y[~cond]
    X_test,y_test = X[cond],y[cond]
    return X_train,y_train,X_test,y_test,cond
X_train,y_train,X_test,y_test,cond = train_test_split(X,y,core) 
balance = pd.Series(y_train).value_counts(normalize = True)
len(patients)
# Out:
# /tmp/ipykernel_1782948/2899701441.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.drop_duplicates().groupby(by =key,observed = True).apply(
# 58

# %%
len(adata_asinh[~cond].obs.Patient.drop_duplicates()),len(adata_asinh[cond].obs.Patient.drop_duplicates())
# Out:
# (48, 10)

# %%
patients
plt.figure(figsize = (4,3))
pd.Series(y_train.map({0:'Non-Responder',1:'pCR'})).value_counts(normalize = True).sort_index().plot(kind = 'bar',label = 'Train')
pd.Series(y_test.map({0:'Non-Responder',1:'pCR'})).value_counts(normalize = True).sort_index().plot(kind = 'bar',color = 'orange',alpha = 0.7,label = 'Test')
plt.legend()
plt.ylabel('Fraction of ROIs')
plt.xticks(rotation = 0,ha = 'center')
pd.Series(y_train).value_counts(normalize = True)[1],pd.Series(y_test).value_counts(normalize = True)[1]
balance = pd.Series(y_train).value_counts(normalize = True)
balance[0]/balance[1]
plt.tight_layout()
#plt.savefig('train_test_split.png')
# Out:
# /tmp/ipykernel_1782948/4175206983.py:3: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   pd.Series(y_train.map({0:'Non-Responder',1:'pCR'})).value_counts(normalize = True).sort_index().plot(kind = 'bar',label = 'Train')
# /tmp/ipykernel_1782948/4175206983.py:4: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   pd.Series(y_test.map({0:'Non-Responder',1:'pCR'})).value_counts(normalize = True).sort_index().plot(kind = 'bar',color = 'orange',alpha = 0.7,label = 'Test')

# %%
sns.barplot(adata_asinh.obs[['Patient','Response']].drop_duplicates()['Response'].value_counts(normalize = True).sort_index())
plt.xticks(rotation = 0,ha = 'center')
# Out:
# ([0, 1], [Text(0, 0, 'Non-Responder'), Text(1, 0, 'pCR')])

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score, roc_auc_score,  f1_score,precision_score,recall_score
def compute_scores_train(y_train, y_pred_train, y_test, y_pred_test,y_prob_train,y_prob_test):
	"""
	Computes various evaluation scores for both training and test sets.

	Args:
		y_train (list or numpy.ndarray): True labels for training set.
		y_pred_train (list or numpy.ndarray): Predicted labels for training set.
		y_test (list or numpy.ndarray): True labels for test set.
		y_pred_test (list or numpy.ndarray): Predicted labels for test set.

	Returns:
		metrics (dict): Dictionary containing evaluation metrics for both sets.
	"""
	accuracy_train = accuracy_score(y_train, y_pred_train)
	balanced_accuracy_train = balanced_accuracy_score(y_train, y_pred_train,adjusted=False)
	auc_train = roc_auc_score(y_train, y_prob_train)
	f1_train = f1_score(y_train, y_pred_train)

	accuracy_test = accuracy_score(y_test, y_pred_test)
	balanced_accuracy_test = balanced_accuracy_score(y_test, y_pred_test,adjusted=False)
	auc_test = roc_auc_score(y_test, y_prob_test)
	f1_test = f1_score(y_test, y_pred_test)
	metrics = {
			'Accuracy':{ 'Train': accuracy_train,'Test': accuracy_test},
			'Balanced_Accuracy':{'Train': balanced_accuracy_train,'Test': balanced_accuracy_test},
            'Precision': {'Train':precision_score(y_train,y_pred_train),'Test': precision_score(y_test,y_pred_test)},
            'Recall':{'Train': recall_score(y_train,y_pred_train),'Test': recall_score(y_test,y_pred_test)},
			'AUC':{ 'Train': auc_train,'Test': auc_test},
			'F1 Score':{ 'Train': f1_train,'Test': f1_test},
	}
	return metrics
def compute_scores_leaveout(y_train, y_pred_train, y_test, y_pred_test,y_prob_train,y_prob_test):
	"""
	Computes various evaluation scores for both training and test sets.

	Args:
		y_train (list or numpy.ndarray): True labels for training set.
		y_pred_train (list or numpy.ndarray): Predicted labels for training set.
		y_test (list or numpy.ndarray): True labels for test set.
		y_pred_test (list or numpy.ndarray): Predicted labels for test set.

	Returns:
		metrics (dict): Dictionary containing evaluation metrics for both sets.
	"""
	accuracy_test = accuracy_score(y_test, y_pred_test)
	return accuracy_test

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(sampling_strategy = 1 ,k_neighbors = 5,n_jobs=-1)  
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
# Out:
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/imblearn/over_sampling/_smote/base.py:345: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(

# %%
balance_ratio =balance[0]/balance[1]
boosting = XGBClassifier(n_estimators=100, max_depth=5, learning_rate=.01, objective='binary:logistic', device="cuda",min_split_loss = 1,reg_lambda = 1,alpha = 0,sampling_method = 'gradient_based',subsample = 0.5,scale_pos_weight=balance_ratio)
boosting.fit(X_train_res,y_train_res)
# Out:
# XGBClassifier(alpha=0, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, min_split_loss=1, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, ...)

# %%
scores = compute_scores_train(y_train = y_train, y_pred_train=boosting.predict(X_train), y_test=y_test, y_pred_test=boosting.predict(X_test),y_prob_train=boosting.predict_proba(X_train)[:,1],y_prob_test=boosting.predict_proba(X_test)[:,1])
pd.DataFrame(scores)
# Out:
#        Accuracy  Balanced_Accuracy  Precision    Recall       AUC  F1 Score
# Train  0.786378           0.784680   0.825562  0.796137  0.877698  0.810582
# Test   0.519846           0.582221   0.778823  0.405878  0.563074  0.533649

# %%
(boosting.predict(X_test) == y_test)[y_test == 1].mean(),(boosting.predict(X_test) == y_test)[y_test == 0].mean()
# Out:
# (0.405877960357042, 0.7585642388829007)

# %%
#scale_pos_weight = None
scores = compute_scores_train(y_train, boosting.predict(X_train), y_test, boosting.predict(X_test),y_prob_train=boosting.predict_proba(X_train)[:,1],y_prob_test=boosting.predict_proba(X_test)[:,1])
pd.DataFrame(scores)
# Out:
#        Accuracy  Balanced_Accuracy  Precision    Recall       AUC  F1 Score
# Train  0.786378           0.784680   0.825562  0.796137  0.877698  0.810582
# Test   0.519846           0.582221   0.778823  0.405878  0.563074  0.533649

# %%
def aggregate_logratio(p,acq_ids):
    #logratio = pd.DataFrame(np.log(p/(1-p)),columns = ['logratio'])
    logratio = pd.DataFrame(p,columns = ['logratio'])
    logratio['acquisition_ID'] = acq_ids
    #logratio['Patient'] = core.obs.loc[~cond].Patient.to_numpy()
    logratio= logratio[['logratio','acquisition_ID']].groupby(by = 'acquisition_ID',group_keys=False).median()
    return logratio#.map(lambda x:1/(1+np.exp(-x)))
def aggregate_prediction(model,X_train,X_test,y_train,y_test,cond):

    p = boosting.predict_proba(X_train)[:,1]
    logratio_train = aggregate_logratio(p,acq_ids = core.obs.loc[~cond].acquisition_ID.to_numpy())
    y_hat_train = logratio_train#.map(lambda x:1/(1+np.exp(-x)))
    p = boosting.predict_proba(X_test)[:,1]
    logratio_test = aggregate_logratio(p,acq_ids = core.obs.loc[cond].acquisition_ID.to_numpy())
    y_hat_test = logratio_test
    #now aggregate the target values per acquisition
    y = pd.DataFrame(y_train,columns = ['label'])
    y['acquisition_ID'] = core.obs.loc[~cond].acquisition_ID.to_numpy()
    y_train = y[['label','acquisition_ID']].drop_duplicates()['label']
    y = pd.DataFrame(y_test,columns = ['label'])
    y['acquisition_ID'] = core.obs.loc[cond].acquisition_ID.to_numpy()
    y_test = y[['label','acquisition_ID']].drop_duplicates()['label']
    return compute_scores_train(y_train=y_train,y_pred_train=y_hat_train>0.5,y_pred_test=y_hat_test>0.5,y_test=y_test,y_prob_train=y_hat_train,y_prob_test=y_hat_test)

pd.DataFrame(aggregate_prediction(boosting,X_train,X_test,y_train,y_test,cond))
# Out:
#        Accuracy  Balanced_Accuracy  Precision    Recall       AUC  F1 Score
# Train  0.850416           0.854557   0.904255  0.825243  0.945381  0.862944
# Test   0.619718           0.617388   0.575758  0.593750  0.614583  0.584615

# %%
#leave one approach
data_leaveout =[]
patients = adata_asinh.obs.Patient.unique()
def leaveone_prediction(patient):
    cond = adata_asinh.obs.Patient.isin([patient])
    X_train,y_train = X[~cond],y[~cond]
    X_test,y_test = X[cond],y[cond]
    balance = pd.Series(y_train).value_counts(normalize = True)
    balance_ratio =balance[0]/balance[1]
    boosting = XGBClassifier(n_estimators=1000, max_depth=7, learning_rate=.01, objective='binary:logistic', device="cuda",min_split_loss = 1,reg_lambda = 1,alpha = 0,sampling_method = 'gradient_based',subsample = 0.1,scale_pos_weight=balance_ratio)
    boosting.fit(X_train,y_train)
    return compute_scores_leaveout(y_train = y_train, y_pred_train=boosting.predict(X_train), y_test=y_test, y_pred_test=boosting.predict(X_test),y_prob_train=boosting.predict_proba(X_train)[:,1],y_prob_test=boosting.predict_proba(X_test)[:,1])
from tqdm import tqdm
for patient in tqdm(patients):
    data_leaveout+=[leaveone_prediction(patient)]



#pool = multiprocessing.Pool()
#data_leaveout = pool.map(leaveone_prediction,patients)
# Out:
#  60%|█████████████████████████▉                 | 35/58 [11:56<07:49, 20.43s/it]

# %%
sns.histplot(data_leaveout,bins = 20)
# Out:
# <Axes: ylabel='Count'>

# %%
plt.figure(figsize= (4,3))
d = pd.concat(data_leaveout).reset_index(names = 'experiment')
sns.barplot(d[d.experiment == 'Test'])
plt.xticks(rotation = 20,ha = 'right')
plt.axhline(0.5,c ='k',ls = '--')
plt.ylabel('Performance',fontsize = 13)
plt.tight_layout()

# %%
data = []
for _ in range(10):
    X_train,y_train,X_test,y_test,cond = train_test_split(X,y,core) 
    balance = pd.Series(y_train).value_counts(normalize = True)
    balance_ratio =balance[0]/balance[1]
    boosting = XGBClassifier(n_estimators=1000, max_depth=7, learning_rate=.01, objective='binary:logistic', device="cuda",min_split_loss = 1,reg_lambda = 1,alpha = 0,sampling_method = 'gradient_based',subsample = 0.1,scale_pos_weight=balance_ratio)
    boosting.fit(X_train,y_train)
    data+=[pd.DataFrame(aggregate_prediction(boosting,X_train,X_test,y_train,y_test,cond))]
# Out:
# /tmp/ipykernel_1593805/2030062471.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.drop_duplicates().groupby(by =key,observed = True).apply(
# /tmp/ipykernel_1593805/2030062471.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.drop_duplicates().groupby(by =key,observed = True).apply(
# ...

# %%
plt.figure(figsize= (4,3))
d = pd.concat(data).reset_index(names = 'experiment')
sns.barplot(d[d.experiment == 'Test'])
plt.xticks(rotation = 20,ha = 'right')
plt.axhline(0.5,c ='k',ls = '--')
plt.ylabel('Performance',fontsize = 13)
plt.tight_layout()
#plt.savefig('../../figures/prediction/performance_cell_predictor_train.png')
# Out:
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.figure(figsize= (4,3))
d = pd.concat(data).reset_index(names = 'experiment')
sns.barplot(d[d.experiment == 'Train'])
plt.xticks(rotation = 20,ha = 'right')
plt.axhline(0.5,c ='k',ls = '--')
plt.ylabel('Performance',fontsize = 13)
plt.tight_layout()
#plt.savefig('../../figures/prediction/performance_cell_predictor_test.png')
# Out:
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
p = boosting.predict_proba(X_train)[:,1]
logratio_train = aggregate_logratio(p,acq_ids = core.obs.loc[~cond].acquisition_ID.to_numpy())
logratio_train.logratio.hist(density = True,bins = 20)
plt.hist(p,density = True,alpha = 0.8,bins = 20)
# Out:
# (array([0.18713989, 0.23675723, 0.13337618, 0.17973253, 0.18923412,
#         0.64477129, 1.013204  , 1.46324376, 4.25257816, 4.74824468,
#         8.23071527, 5.47929467, 2.46305389, 0.58650967, 0.36781425,
#         0.31509065, 0.78185828, 0.34996262, 0.03467585, 0.04618762]),
#  array([0.18377993, 0.21532224, 0.24686454, 0.27840686, 0.30994916,
#         0.34149149, 0.37303379, 0.40457609, 0.43611842, 0.46766073,
#         0.49920303, 0.53074533, 0.56228769, 0.59382999, 0.62537229,
#         0.65691459, 0.68845689, 0.71999919, 0.75154155, 0.78308386,
#         0.81462616]),
#  <BarContainer object of 20 artists>)

# %%
p = boosting.predict_proba(X_test)[:,1]
logratio_test = aggregate_logratio(p,acq_ids = core.obs.loc[cond].acquisition_ID.to_numpy())

logratio_test.logratio.hist(density = True)
logratio_test.logratio
plt.hist(p,density = True,alpha = 0.8)
# Out:
# (array([0.0586091 , 0.1879764 , 0.45724164, 1.58264001, 2.9721462 ,
#         3.10049927, 1.76632159, 0.40443747, 0.06687392, 0.00658166]),
#  array([0.01669056, 0.11100057, 0.20531058, 0.2996206 , 0.39393061,
#         0.48824063, 0.58255064, 0.67686069, 0.77117068, 0.86548072,
#         0.95979071]),
#  <BarContainer object of 10 artists>)

# %%
data[-1]
# Out:
#        Accuracy  Balanced_Accuracy  Precision    Recall       AUC  F1 Score
# Train  0.861272           0.859466   0.853403  0.890710  0.934460  0.871658
# Test   0.511628           0.561877   0.724138  0.381818  0.646921  0.500000

# %%
X_train.shape
# Out:
# (1748441, 35)

# %%
sns.histplot(boosting.predict_proba(X_train)[:,0])
p = boosting.predict_proba(X_train)
np.mean(np.log(p/(1-p)),axis = 0)
# Out:
# array([-0.3531494,  0.3531494], dtype=float32)

# %%
from importlib import reload  
import shap
shap = reload(shap)

# %%
explainer = shap.GPUTreeExplainer(boosting,X_train,feature_names= core.var.index)
shap_values = explainer(X_train)

# %%
shap.plots.bar(shap_values,max_display=10)

# %%
explainer.expected_value
len(shap_values[0].feature_names)
# Out:
# 35

# %%
shap.sample(shap_values,1000).values.shape,len(shap_values.feature_names)
shap.summary_plot(shap_values,show=False)

# %%
shap.plots.scatter(shap_values[:, "CD8a"], color=shap_values,show=False)
plt.tight_layout()
#plt.savefig('../../figures/prediction/shap.png')

# %%
shap.plots.scatter?
shap.plots.scatter?
# Out:
# Signature:
# shap.plots.scatter(
#     shap_values,
#     color='#1E88E5',
#     hist=True,
#     axis_color='#333333',
#     cmap=<matplotlib.colors.LinearSegmentedColormap object at 0x7f334dbdca30>,
#     dot_size=16,
#     x_jitter='auto',
#     alpha=1,
#     title=None,
#     xmin=None,
#     xmax=None,
#     ymin=None,
#     ymax=None,
#     overlay=None,
#     ax=None,
#     ylabel='SHAP value',
#     show=True,
# )
# Docstring:
# Create a SHAP dependence scatter plot, colored by an interaction feature.
#
# Plots the value of the feature on the x-axis and the SHAP value of the same feature
# on the y-axis. This shows how the model depends on the given feature, and is like a
# richer extension of classical partial dependence plots. Vertical dispersion of the
# data points represents interaction effects. Grey ticks along the y-axis are data
# points where the feature's value was NaN.
#
# Note that if you want to change the data being displayed, you can update the
# ...

# %%
shap.summary_plot?
# Out:
# Signature:
# shap.summary_plot(
#     shap_values,
#     features=None,
#     feature_names=None,
#     max_display=None,
#     plot_type=None,
#     color=None,
#     axis_color='#333333',
#     title=None,
#     alpha=1,
#     show=True,
#     sort=True,
#     color_bar=True,
#     plot_size='auto',
#     layered_violin_max_num_bins=20,
#     class_names=None,
#     class_inds=None,
#     color_bar_label='Feature value',
#     cmap=<matplotlib.colors.LinearSegmentedColormap object at 0x7f3a2e46faf0>,
#     show_values_in_legend=False,
#     auto_size_plot=None,
#     use_log_scale=False,
# )
# Docstring:
# Create a SHAP beeswarm plot, colored by feature values when they are provided.
#
# Parameters
# ----------
# shap_values : numpy.array
#     For single output explanations this is a matrix of SHAP values (# samples x # features).
#     For multi-output explanations this is a list of such matrices of SHAP values.
#
# features : numpy.array or pandas.DataFrame or list
# ...

# %%
shap.plots.heatmap(shap_values[-1000:])

# %%
shap.plots.waterfall(shap_values[1], max_display=14)

# %%
p = boosting.predict_proba(X_train)
np.mean(np.log(p/(1-p)),axis = 0)
# Out:
# array([-0.8215882 ,  0.82158816], dtype=float32)

# %%
t = np.linspace(0,1,100)
plt.plot(t,np.log(t/(1-t)))
# Out:
# /tmp/ipykernel_1082734/2459609185.py:2: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(t,np.log(t/(1-t)))
# /tmp/ipykernel_1082734/2459609185.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.plot(t,np.log(t/(1-t)))

# %%
sns.heatmap(adata.X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.heatmap(adata.X)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:340, in _HeatMapper.plot(self, ax, cax, kws)
#     337 plt.setp(ytl, va="center")  # GH2484
#     339 # Possibly rotate them if they overlap
# --> 340 _draw_figure(ax.figure)
#     342 if axis_ticklabels_overlap(xtl):
#     343     plt.setp(xtl, rotation="vertical")
#
# ...

# %%
plt.figure(figsize = (4,3))
v = pd.DataFrame({'Xgboost':[0.701],'Random forest':[0.695],'Logistic reg.':[0.625]})
sns.barplot(v)
plt.ylabel('Test accuracy')
plt.tight_layout()
#plt.savefig('../fig_4_pres.png')
# Out:
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/giuseppe/anaconda3/lib/python3.9/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
#X = core.raw.X[:,~adata.var.index.isin(['Carboplatin','DNA1','DNA2'])]
a = pd.DataFrame({k:core[indices].X.mean(axis = 0) for k, indices in core.obs.groupby(by = 'acquisition_ID').groups.items()},index = core.var.index).T
a = a.merge(core.obs[['Patient','acquisition_ID','Response']].drop_duplicates(),left_index=True,right_on='acquisition_ID').drop(['acquisition_ID'],axis = 1)
a['Response'] = a.Response.map({'Non-Responder':0,'pCR':1}).values
# Out:
# /tmp/ipykernel_1593805/2822710152.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   a = pd.DataFrame({k:core[indices].X.mean(axis = 0) for k, indices in core.obs.groupby(by = 'acquisition_ID').groups.items()},index = core.var.index).T

# %%
train_patient = random.sample(list(a.Patient.unique()),int(0.7*(a.Patient.nunique())))
cond = a.Patient.isin(train_patient)
X_train = a[cond].drop(['Patient','Response'],axis = 1).values
y_train = a[cond].Response
X_test = a[~cond].drop(['Patient','Response'],axis = 1).values
y_test = a[~cond].Response

# %%
boosting = XGBClassifier(n_estimators=100, max_depth=5, learning_rate=.01, objective='binary:logistic', device="cuda",min_split_loss = 1,reg_lambda = 1,alpha = 0,sampling_method = 'gradient_based',subsample = 0.5,scale_pos_weight=balance_ratio)
boosting.fit(X_train,y_train)
scores = compute_scores_train(y_train, boosting.predict(X_train), y_test, boosting.predict(X_test),y_prob_train=boosting.predict_proba(X_train)[:,1],y_prob_test=boosting.predict_proba(X_test)[:,1])
pd.DataFrame(scores)
# Out:
#        Accuracy  Balanced_Accuracy  Precision    Recall       AUC  F1 Score
# Train  0.989547           0.990385   1.000000  0.980769  1.000000  0.990291
# Test   0.544828           0.577333   0.710526  0.329268  0.663957  0.450000

# %%
a.Patient.value_counts()
b = adata.obs[adata.obs['SAMPLE_TYPE_(CORE/RESECTION)']=='CORE'].acquisition_ID.str.split('_').str[0].drop_duplicates()
b[~b.str.upper().isin(a.Leap_ID)]
# Out:
# index
# 2577550    Leap084a
# 2850458    Leap088a
# 2927684    Leap088b
# Name: acquisition_ID, dtype: object

# %%
plt.plot(np.log1p(np.linspace(0,50,100)))
plt.plot(np.arcsinh(np.linspace(0,50,100)))

# %%
adata.obs[['Leap_ID','new_Response']].drop_duplicates().new_Response.value_counts()
# Out:
# new_Response
# nR     39
# enR    26
# pCR    26
# Name: count, dtype: int64

# %%
cond = adata[adata.obs.Response == 'pCR'].obs[['Leap_ID','Response','new_Response']].drop_duplicates()
cond
# Out:
#          Leap_ID Response new_Response
# index
# 149764   LEAP008      pCR          enR
# 198436   LEAP009      pCR          pCR
# 230701   LEAP010      pCR          pCR
# 233711   LEAP012      pCR          pCR
# 256221   LEAP013      pCR          pCR
# 303431   LEAP014      pCR          pCR
# 554187   LEAP021      pCR          pCR
# 595050   LEAP022      pCR          pCR
# 903804   LEAP036      pCR          pCR
# 994804   LEAP037      pCR          pCR
# 1059148  LEAP038      pCR          pCR
# 1202213  LEAP041      pCR          pCR
# 1279452  LEAP042      pCR          pCR
# 1342920  LEAP043      pCR          pCR
# 1822888  LEAP066      pCR          pCR
# 2134174  LEAP075      pCR          enR
# 2177514  LEAP077      pCR          pCR
# 2385602  LEAP082      pCR          pCR
# 2514473  LEAP084      pCR          pCR
# 2659970  LEAP085      pCR          pCR
# 2715141  LEAP086      pCR          pCR
# 2775906  LEAP087      pCR          pCR
# 3026590  LEAP090      pCR          pCR
# ...

# %%
adata.obs['Response']
# Out:
# index
# 0          Non-Responder
# 1          Non-Responder
# 2          Non-Responder
# 3          Non-Responder
# 4          Non-Responder
#                ...
# 3589920              pCR
# 3589921              pCR
# 3589922              pCR
# 3589923              pCR
# 3589924              pCR
# Name: Response, Length: 3556860, dtype: category
# Categories (2, object): ['Non-Responder', 'pCR']
