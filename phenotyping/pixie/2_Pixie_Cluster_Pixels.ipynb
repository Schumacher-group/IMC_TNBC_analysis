# %% [markdown]
# # Pixie: pixel clustering notebook

# %%
# import required packages
import json
import os
from datetime import datetime as dt
import pandas as pd

import matplotlib.pyplot as plt
from alpineer import io_utils, load_utils
from matplotlib import rc_file_defaults

from ark.phenotyping import (pixel_cluster_utils, pixel_meta_clustering,
                             pixel_som_clustering, pixie_preprocessing)
from ark.utils import data_utils, example_dataset, plot_utils
from ark.utils.metacluster_remap_gui import (MetaClusterGui,
                                             colormap_helper,
                                             metaclusterdata_from_files)

# %%
# !which python
# Out:
# /home/giuseppe/anaconda3/bin/python

# %% [markdown]
# ## 0: Set root directory and download the example dataset
#
# Here we are using the example data located in `data/example_dataset`. To use your own data, change `base_dir` to point to your own sub-directory within the data folder.
#
# * `base_dir`: the path to all of your imaging data. This directory will also store all of the directories/files created during pixel clustering.

# %%
base_dir = "../../../"

# %% [markdown]
# If you would like to test the features in ark with an example dataset, run the cell below. It will download a dataset consisting of 11 FOVs with 22 channels. You may find more information about the example dataset in the [README](../README.md#example-dataset).
#
# If you are using your own data, skip the cell below.
#
# * `overwrite_existing`: If set to `False`, it will not overwrite existing data in `data/example_dataset`. Recommended setting to `False` if you are running Notebooks 1,2,3 and 4 in succession. Set to `True` if you are just running Notebook 2.

# %%
#example_dataset.get_example_dataset(dataset="cluster_pixels", save_dir = base_dir, overwrite_existing = False)

# %% [markdown]
# ## 1: Set file paths and parameters

# %% [markdown]
# * `tiff_dir`: path to the directory containing your imaging data. Images should be single-channel TIFFs.
# * `img_sub_folder`: if `tiff_dir` contains an additional subfolder structure, override `None` with the appropriate folder name
# * `segmentation_dir`: path to the directory containing your segmentations (which can be generated using `1_Segment_Image_Data.ipynb`). Set this argument to `None` if you do not have segmentation labels or wish to run pixel clustering without them (they are required for cell clustering)
# * `seg_suffix`: the suffix plus the file extension of the segmented images for each FOV. Note that these should be the same for all FOVs. This argument will be ignored if `segmentation_dir` is set to `None`
# * `pixie_seg_dir`: the created path from the `segmentation_dir`. Is `None` if `segmentation_dir` is `None`.

# %%
# tiff_dir = os.path.join(base_dir, "split_channels")
# img_sub_folder = None
# segmentation_dir = os.path.join("segmentation", "deepcell_output")
# seg_suffix = '_whole_cell.tiff'

# if segmentation_dir is not None:
#     pixie_seg_dir = os.path.join(base_dir, segmentation_dir)
# else:
#     pixie_seg_dir = None

# %%
#Paths to the denoised images
tiff_dir = os.path.join(base_dir, "Img_Denoised")
img_sub_folder = None
segmentation_dir = os.path.join("segmentation", "deepcell_output_Denoised")
seg_suffix = '_whole_cell.tiff'

if segmentation_dir is not None:
    pixie_seg_dir = os.path.join(base_dir, segmentation_dir)
else:
    pixie_seg_dir = None

# %% [markdown]
# * `fovs` (optional): set a specific set of fovs to load, default loads all the fovs in `tiff_dir`

# %%
# either get all fovs in the folder...
fovs = io_utils.list_folders(tiff_dir)

# some of the images was not possible to process with Mesmer, so consider only the images that have a valid segmentation
Leap_ID_segmented = pd.read_csv( os.path.join(base_dir, 'segmentation/LeapID_segmented.csv'))
fovs = [*set(Leap_ID_segmented.Leap_ID)&set(fovs)]

# %%
len(io_utils.list_folders(tiff_dir)),Leap_ID_segmented.Leap_ID.nunique(),len(fovs)
# Out:
# (879, 871, 871)

# %% [markdown]
# ### Define multiprocessing parameters

# %% [markdown]
# Turning on multiprocessing provides a speed boost; however, it is not always cross-platform compatible. If you receive errors such as hanging cells without progress updates, try setting `multiprocess` back to `False`.

# %%
# set to True to turn on multiprocessing
multiprocess = True

# define the number of FOVs to process in parallel, ignored if multiprocessing is set to False
batch_size = 5

# %% [markdown]
# The following data directories/files will be created with names prefixed by `pixel_cluster_prefix`:
#
# * `pixel_output_dir`: directory name where the pixel clustering outputs are stored
# * `preprocessed_dir`: directory name where the preprocessed pixel data are stored
# * `subsetted_dir`: directory name where the subsetted pixel data are stored
# * `norm_vals_name`: file name where the values used to normalize each channel are stored

# %%
# explicitly set pixel_cluster_prefix to override datetime default
pixel_cluster_prefix = "all"

if pixel_cluster_prefix is None:
    pixel_cluster_prefix = dt.now().strftime('%Y-%m-%dT%H:%M:%S')

# %%
# define the output directory using the specified pixel cluster prefix
pixel_output_dir = os.path.join("pixie", "%s_pixel_output_dir" % pixel_cluster_prefix)
if not os.path.exists(os.path.join(base_dir, pixel_output_dir)):
    os.makedirs(os.path.join(base_dir, pixel_output_dir))

# define the preprocessed pixel data folders
pixel_data_dir = os.path.join(pixel_output_dir, 'pixel_mat_data')
pixel_subset_dir = os.path.join(pixel_output_dir, 'pixel_mat_subset')
norm_vals_name = os.path.join(pixel_output_dir, 'channel_norm_post_rownorm.feather')

# %% [markdown]
# For certain channels, such as membraneous tumor markers, the subcellular localization of the marker isn't important. Instead, what matters is that cells which are positive for the marker show up as positive. In these cases, we have sometimes found it useful to add additional blurring to these markers before clustering. This ensures that more of the pixels within the cell are positive for the marker, instead of only a few pixels at the border, especially for cells which are under-segmented. However, higher blur levels will also cause more of the pixels in neighboring cells to show up as positive. Therefore, this works best when you have other, robust markers (like CD45) which you can use to determine which cells are false positives for the blurred channel. If you have markers in your panel which fit this description, you can add them in the cell below. Then, when specifying the list of markers to include for clustering, make sure to add `{marker_name}_smoothed`, as that is what the TIFF will be called.
#
# Skip this cell if you don't want to add an additional blur.

# %%
# set an optional list of markers for additional blurring
blurred_channels = ["ECAD"]
smooth_vals = 6

pixel_cluster_utils.smooth_channels(
    fovs=fovs,
    tiff_dir=tiff_dir,
    img_sub_folder=img_sub_folder,
    channels=blurred_channels,
    smooth_vals=smooth_vals,
)

# %% [markdown]
# Sometimes, markers will have background staining that you'll want to filter out for the clustering process. Define the name of the marker you want to filter using `filter_channel`. If the marker is only present in the nucleus, set `exclude = False` to filter it out from the membrane. Conversely, if the marker is only present in the membrane, set `exclude = True` to filter it out from the nucleus.
#
# When specifying the list of markers to include for clustering, make sure to add `{marker_name}_nuc_exclude` or `{marker_name}_nuc_include` depending on what type of signal was filtered out.
#
# Skip this cell if you don't want to run marker filtering.

# %%
filter_channel = 'CD163'
nuclear_exclude = True

pixel_cluster_utils.filter_with_nuclear_mask(
    fovs=fovs,
    tiff_dir=tiff_dir,
    seg_dir=os.path.join(base_dir, segmentation_dir),
    channel=filter_channel,
    nuc_seg_suffix="_nuclear.tiff",
    img_sub_folder=img_sub_folder,
    exclude=nuclear_exclude
)

# %% [markdown]
# Set the following arguments:
#
# * `channels`: channels to run pixel clustering on
# * `blur_factor`: sigma (standard deviation) for the Gaussian blur. Higher values are more aggressive in smoothing signal.
# * `subset_proportion`: the fraction of pixels to take from each FOV for training. Sampling is random.

# %%
channels = ['CD38', 'CD14', 'Tbet', 'CD163', 'CD4', 'CD16',
       'Pan-keratin', 'CD11b', 'CD107a', 'CD45', 'CD44', 'CD366',
       'FOXP3', 'E-Cadherin', 'CD68', 'HLA-DR-DQ-DP', 'CD20',
       'CD8a', 'Beta-Catenin', 'B7-H4', 'Granzyme-B',
       'CD3', 'CD27', 'CD45RO',
       'Alpha-SMA', 'Vimentin', 'CD31' ]
blur_factor = 1
subset_proportion = 0.1

# %% [markdown]
# During pixel preprocessing, the following is done for each FOV:
#
# * Gaussian blur each channel separately
# * Remove empty pixels
# * For the remaining pixels, normalize each pixel by the sum of all the channels
# * Subset a `subset_proportion` fraction of non-empty, normalized pixels. This creates the subsetted dataset for training
#
# Note: if you get integer overflow errors loading in your data, try changing the `dtype` argument to a larger type.

# %%
# run pixel data preprocessing
pixie_preprocessing.create_pixel_matrix(
    fovs,
    channels,
    base_dir,
    tiff_dir,
    pixie_seg_dir,
    img_sub_folder=img_sub_folder,
    seg_suffix=seg_suffix,
    pixel_output_dir=pixel_output_dir,
    data_dir=pixel_data_dir,
    subset_dir=pixel_subset_dir,
    norm_vals_name_post_rownorm=norm_vals_name,
    blur_factor=blur_factor,
    subset_proportion=subset_proportion,
    multiprocess=multiprocess,
    batch_size=batch_size
)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/giuseppe/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/giuseppe/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/giuseppe/anaconda3/lib/python3.9/site-packages/ark/phenotyping/pixie_preprocessing.py", line 172, in preprocess_fov
#     feather.write_dataframe(pixel_mat,
#   File "/home/giuseppe/anaconda3/lib/python3.9/site-packages/pyarrow/feather.py", line 187, in write_feather
#     _feather.write_feather(table, dest, compression=compression,
#   File "pyarrow/_feather.pyx", line 41, in pyarrow._feather.write_feather
#   File "pyarrow/io.pxi", line 2003, in pyarrow.lib.get_writer
#   File "pyarrow/io.pxi", line 1096, in pyarrow.lib.OSFile.__cinit__
#   File "pyarrow/io.pxi", line 1111, in pyarrow.lib.OSFile._open_writable
#   File "pyarrow/error.pxi", line 144, in pyarrow.lib.pyarrow_internal_check_status
#   File "pyarrow/error.pxi", line 113, in pyarrow.lib.check_status
# PermissionError: [Errno 13] Failed to open local file '../../../pixie/all_pixel_output_dir/pixel_mat_data/Leap054_11.feather'. Detail: [errno 13] Permission denied
# """
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[27], line 2
#       1 # run pixel data preprocessing
# ----> 2 pixie_preprocessing.create_pixel_matrix(
#       3     fovs,
#       4     channels,
#       5     base_dir,
#       6     tiff_dir,
#       7     pixie_seg_dir,
#       8     img_sub_folder=img_sub_folder,
#       9     seg_suffix=seg_suffix,
#      10     pixel_output_dir=pixel_output_dir,
#      11     data_dir=pixel_data_dir,
#      12     subset_dir=pixel_subset_dir,
#      13     norm_vals_name_post_rownorm=norm_vals_name,
#      14     blur_factor=blur_factor,
#      15     subset_proportion=subset_proportion,
#      16     multiprocess=multiprocess,
#      17     batch_size=batch_size
#      18 )
#
# File ~/anaconda3/lib/python3.9/site-packages/ark/phenotyping/pixie_preprocessing.py:396, in create_pixel_matrix(fovs, channels, base_dir, tiff_dir, seg_dir, img_sub_folder, seg_suffix, pixel_output_dir, data_dir, subset_dir, norm_vals_name_pre_rownorm, norm_vals_name_post_rownorm, pixel_thresh_name, channel_percentile_pre_rownorm, channel_percentile_post_rownorm, is_mibitiff, blur_factor, subset_proportion, seed, multiprocess, batch_size)
#     391 with multiprocessing.get_context('spawn').Pool(batch_size) as fov_data_pool:
#     392     # asynchronously generate and save the pixel matrices per FOV
#     393     # NOTE: fov_data_pool should NOT operate on quant_dat since that is a shared resource
#     394     for fov_batch in [fovs_list[i:(i + batch_size)]
#     395                       for i in range(0, len(fovs_list), batch_size)]:
# --> 396         fov_data_batch = fov_data_pool.map(fov_data_func, fov_batch)
#     398         # compute the 99.9% quantile values for each FOV
#     399         for pixel_mat_data in fov_data_batch:
#     400             # retrieve the FOV name, note that there will only be one per FOV DataFrame
#
# File ~/anaconda3/lib/python3.9/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/anaconda3/lib/python3.9/multiprocessing/pool.py:771, in ApplyResult.get(self, timeout)
#     769     return self._value
#     770 else:
# --> 771     raise self._value
#
# File ~/anaconda3/lib/python3.9/multiprocessing/pool.py:125, in worker()
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~/anaconda3/lib/python3.9/multiprocessing/pool.py:48, in mapstar()
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#
# File ~/anaconda3/lib/python3.9/site-packages/ark/phenotyping/pixie_preprocessing.py:172, in preprocess_fov()
#     165 pixel_mat, pixel_mat_subset = create_fov_pixel_data(
#     166     fov=fov, channels=channels, img_data=img_data, seg_labels=seg_labels,
#     167     pixel_thresh_val=pixel_thresh_val, blur_factor=blur_factor,
#     168     subset_proportion=subset_proportion
#     169 )
#     171 # write complete dataset to feather, needed for cluster assignment
# --> 172 feather.write_dataframe(pixel_mat,
#     173                         os.path.join(base_dir,
#     174                                      data_dir,
#     175                                      fov + ".feather"),
#     176                         compression='uncompressed')
#     178 # write subsetted dataset to feather, needed for training
#     179 feather.write_dataframe(pixel_mat_subset,
#     180                         os.path.join(base_dir,
#     181                                      subset_dir,
#     182                                      fov + ".feather"),
#     183                         compression='uncompressed')
#
# File ~/anaconda3/lib/python3.9/site-packages/pyarrow/feather.py:187, in write_feather()
#     182         raise ValueError('compression="{}" not supported, must be '
#     183                          'one of {}'.format(compression,
#     184                                             _FEATHER_SUPPORTED_CODECS))
#     186 try:
# --> 187     _feather.write_feather(table, dest, compression=compression,
#     188                            compression_level=compression_level,
#     189                            chunksize=chunksize, version=version)
#     190 except Exception:
#     191     if isinstance(dest, str):
#
# File ~/anaconda3/lib/python3.9/site-packages/pyarrow/_feather.pyx:41, in pyarrow._feather.write_feather()
#      39               compression_level=None, chunksize=None, version=2):
#      40 cdef shared_ptr[COutputStream] sink
# ---> 41 get_writer(dest, &sink)
#      42
#      43 cdef CFeatherProperties properties
#
# File ~/anaconda3/lib/python3.9/site-packages/pyarrow/io.pxi:2003, in pyarrow.lib.get_writer()
#    2001         source = PythonFile(source, mode='w')
#    2002 else:
# -> 2003     source = OSFile(source_path, mode='w')
#    2004
#    2005 if isinstance(source, NativeFile):
#
# File ~/anaconda3/lib/python3.9/site-packages/pyarrow/io.pxi:1096, in pyarrow.lib.OSFile.__cinit__()
#    1094     self._open_readable(c_path, maybe_unbox_memory_pool(memory_pool))
#    1095 elif mode in ('w', 'wb'):
# -> 1096     self._open_writable(c_path)
#    1097 else:
#    1098     raise ValueError('Invalid file mode: {0}'.format(mode))
#
# File ~/anaconda3/lib/python3.9/site-packages/pyarrow/io.pxi:1111, in pyarrow.lib.OSFile._open_writable()
#    1109 cdef _open_writable(self, c_string path):
#    1110     with nogil:
# -> 1111         self.output_stream = GetResultValue(FileOutputStream.Open(path))
#    1112     self.is_writable = True
#    1113
#
# File ~/anaconda3/lib/python3.9/site-packages/pyarrow/error.pxi:144, in pyarrow.lib.pyarrow_internal_check_status()
#     142 cdef api int pyarrow_internal_check_status(const CStatus& status) \
#     143         except -1 nogil:
# --> 144     return check_status(status)
#     145
#     146
#
# File ~/anaconda3/lib/python3.9/site-packages/pyarrow/error.pxi:113, in pyarrow.lib.check_status()
#     111     raise IOError(errno, message, None, winerror)
#     112 elif errno != 0:
# --> 113     raise IOError(errno, message)
#     114 else:
#     115     raise IOError(message)
#
# PermissionError: [Errno 13] Failed to open local file '../../../pixie/all_pixel_output_dir/pixel_mat_data/Leap054_11.feather'. Detail: [errno 13] Permission denied

# %% [markdown]
# ## 3: Pixel clustering

# %% [markdown]
# ### 3.1: Train pixel SOM

# %% [markdown]
# Train the pixel SOM using the subsetted data. Training is done using a self-organizing map (SOM).
#
# The following data directories/files will be created for pixel clustering:
#
# * `pixel_som_weights_name`: file name to store the pixel SOM weights
# * `pc_chan_avg_som_cluster_name`: file name to store the average channel expression across all pixel SOM clusters
# * `pc_chan_avg_meta_cluster_name`: same as above for pixel meta clusters
# * `pixel_meta_cluster_remap_name`: file name to store the SOM cluster to meta cluster manual mappings created using the GUI below

# %%
pixel_som_weights_name = os.path.join(pixel_output_dir, 'pixel_som_weights.feather')
pc_chan_avg_som_cluster_name = os.path.join(pixel_output_dir, 'pixel_channel_avg_som_cluster.csv')
pc_chan_avg_meta_cluster_name = os.path.join(pixel_output_dir, 'pixel_channel_avg_meta_cluster.csv')
pixel_meta_cluster_remap_name = os.path.join(pixel_output_dir, 'pixel_meta_cluster_mapping.csv')

# %% [markdown]
# Each channel is normalized by their 99.9% value across the entire dataset before training. These values get saved to `norm_vals_name`.
#
# For a full set of parameters you can customize for `train_pixel_som`, please consult <a href=https://ark-analysis.readthedocs.io/en/latest/_markdown/ark.phenotyping.html#ark.phenotyping.pixel_cluster_utils.train_pixel_som>pixel training docs</a>.

# %%
# create the pixel SOM weights
pixel_pysom = pixel_som_clustering.train_pixel_som(
    fovs,
    channels,
    base_dir,
    subset_dir=pixel_subset_dir,
    norm_vals_name=norm_vals_name,
    som_weights_name=pixel_som_weights_name,
    num_passes=1,
    seed=42
)
# Out:
# Training SOM

# %% [markdown]
# ### 3.2: Assign pixel SOM clusters

# %% [markdown]
# Use the SOM weights learned from `train_pixel_som` to assign pixel clusters to the full preprocessed dataset.
#
# Note that each channel is normalized by the respective value stored in `norm_vals_name` (computed in `train_pixel_som`) prior to cluster assignment.
#
# `generate_som_avg_files` will compute the average channel expression across all pixel SOM clusters, as well as the number of pixels in each pixel SOM cluster (the data in `pc_chan_avg_som_cluster_name`). This is needed for consensus clustering.

# %%
new_fovs = list(pd.Series(list(os.walk('../../../pixie/all_pixel_output_dir/pixel_mat_data/'))[0][2]).str.rstrip('.feather'))
#pd.Series(new_fovs).str.split('_',n = 1).str[0].unique()

# %%
import feather
a = feather.read_dataframe(
                os.path.join(base_dir, pixel_data_dir, fovs[0] + '.feather')
)
a.columns
len(fovs)-351
# Out:
# 520

# %%
# !ls ../../../pixie/all_pixel_output_dir/
# Out:
# cell_clustering_params.json	    pixel_masks
# channel_norm_post_rownorm.feather   pixel_mat_data
# channel_norm_pre_rownorm.feather    pixel_mat_subset
# pixel_channel_avg_meta_cluster.csv  pixel_meta_cluster_mapping.csv
# pixel_channel_avg_som_cluster.csv   pixel_som_weights.feather
# pixel_mask_colored		    pixel_thresh.feather

# %% [markdown]
# #### use pixel SOM weights to assign pixel clusters

# %%
#for CRM workstation, limit the batch_size to 5
# set to True to turn on multiprocessing
multiprocess = True

# define the number of FOVs to process in parallel, ignored if multiprocessing is set to False
batch_size = 5

pixel_som_clustering.cluster_pixels(
    fovs,
    channels,
    base_dir,
    pixel_pysom,
    data_dir=pixel_data_dir,
    multiprocess=multiprocess,
    batch_size=batch_size
)

# generate the SOM cluster summary files
pixel_som_clustering.generate_som_avg_files(
    fovs,
    channels,
    base_dir,
    pixel_pysom,
    data_dir=pixel_data_dir,
    pc_chan_avg_som_cluster_name=pc_chan_avg_som_cluster_name,
    overwrite=True
    
)
# Out:
# Mapping pixel data to SOM cluster labels
# Processed 5 fovs
# Processed 10 fovs
# Processed 15 fovs
# Processed 20 fovs
# Processed 25 fovs
# Processed 30 fovs
# Processed 35 fovs
# Processed 40 fovs
# Processed 45 fovs
# Processed 50 fovs
# Processed 55 fovs
# Processed 60 fovs
# Processed 65 fovs
# Processed 70 fovs
# Processed 75 fovs
# Processed 80 fovs
# Processed 85 fovs
# Processed 90 fovs
# Processed 95 fovs
# Processed 100 fovs
# Processed 105 fovs
# Processed 110 fovs
# Processed 115 fovs
# Processed 120 fovs
# Processed 125 fovs
# Processed 130 fovs
# Processed 135 fovs
# Processed 140 fovs
# Processed 145 fovs
# Processed 150 fovs
# Processed 155 fovs
# Processed 160 fovs
# Processed 165 fovs
# Processed 170 fovs
# Processed 175 fovs
# Processed 180 fovs
# Processed 185 fovs
# Processed 190 fovs
# Processed 195 fovs
# Processed 200 fovs
# Processed 205 fovs
# Processed 210 fovs
# Processed 215 fovs
# Processed 220 fovs
# Processed 225 fovs
# Processed 230 fovs
# Processed 235 fovs
# Processed 240 fovs
# Processed 245 fovs
# Processed 250 fovs
# Processed 255 fovs
# Processed 260 fovs
# Processed 265 fovs
# Processed 270 fovs
# Processed 275 fovs
# Processed 280 fovs
# Processed 285 fovs
# Processed 290 fovs
# Processed 295 fovs
# Processed 300 fovs
# Processed 305 fovs
# Processed 310 fovs
# Processed 315 fovs
# Processed 320 fovs
# Processed 325 fovs
# Processed 330 fovs
# Processed 335 fovs
# Processed 340 fovs
# Processed 345 fovs
# Processed 350 fovs
# Processed 355 fovs
# Processed 360 fovs
# Processed 365 fovs
# Processed 370 fovs
# Processed 375 fovs
# Processed 380 fovs
# Processed 385 fovs
# Processed 390 fovs
# Processed 395 fovs
# Processed 400 fovs
# Processed 405 fovs
# Processed 410 fovs
# Processed 415 fovs
# Processed 420 fovs
# Processed 425 fovs
# Processed 430 fovs
# Processed 435 fovs
# Processed 440 fovs
# Processed 445 fovs
# Processed 450 fovs
# Processed 455 fovs
# Processed 460 fovs
# Processed 465 fovs
# Processed 470 fovs
# Processed 475 fovs
# Processed 480 fovs
# Processed 485 fovs
# Processed 490 fovs
# Processed 495 fovs
# Processed 500 fovs
# Processed 505 fovs
# Processed 510 fovs
# Processed 515 fovs
# Processed 520 fovs
# Processed 525 fovs
# Processed 530 fovs
# Processed 535 fovs
# Processed 540 fovs
# Processed 545 fovs
# Processed 550 fovs
# Processed 555 fovs
# Processed 560 fovs
# Processed 565 fovs
# Processed 570 fovs
# Processed 575 fovs
# Processed 580 fovs
# Processed 585 fovs
# Processed 590 fovs
# Processed 595 fovs
# Processed 600 fovs
# Processed 605 fovs
# Processed 610 fovs
# Processed 615 fovs
# Processed 620 fovs
# Processed 625 fovs
# Processed 630 fovs
# Processed 635 fovs
# Processed 640 fovs
# Processed 645 fovs
# Processed 650 fovs
# Processed 655 fovs
# Processed 660 fovs
# Processed 665 fovs
# Processed 670 fovs
# Processed 675 fovs
# Processed 680 fovs
# Processed 685 fovs
# Processed 690 fovs
# Processed 695 fovs
# Processed 700 fovs
# Processed 705 fovs
# Processed 710 fovs
# Processed 715 fovs
# Processed 720 fovs
# Processed 725 fovs
# Processed 730 fovs
# Processed 735 fovs
# Processed 740 fovs
# Processed 745 fovs
# Processed 750 fovs
# Processed 755 fovs
# Processed 760 fovs
# Processed 765 fovs
# Processed 770 fovs
# Processed 775 fovs
# Processed 780 fovs
# Processed 785 fovs
# Processed 790 fovs
# Processed 795 fovs
# Processed 800 fovs
# Processed 805 fovs
# Processed 810 fovs
# Processed 815 fovs
# Processed 820 fovs
# Processed 825 fovs
# Processed 830 fovs
# Processed 835 fovs
# Processed 840 fovs
# Processed 845 fovs
# Processed 850 fovs
# Processed 855 fovs
# Processed 860 fovs
# Processed 865 fovs
# Processed 870 fovs
# Processed 871 fovs
# Computing average channel expression across pixel SOM clusters

# %% [markdown]
# ### 3.3: Run pixel consensus clustering

# %% [markdown]
# Use consensus hierarchical clustering to cluster pixel SOM clusters into a user-defined number of meta clusters. The consensus clusters are trained on the average channel expression across all pixel SOM clusters (the data stored in `pc_chan_avg_som_cluster_name`). These values are z-scored and capped at the value specified in the `cap` argument prior to consensus clustering. This helps improve meta clustering performance.
#
# After consensus clustering, the following are computed by `generate_meta_avg_files`:
#
# * The average channel expression across all pixel meta clusters, and the number of pixels per meta cluster (the data in `pc_chan_avg_meta_cluster_name`)
# * The meta cluster mapping for each pixel SOM cluster in `pc_chan_avg_som_cluster_name` (data is resaved, same data except with an associated meta cluster column)
#
# For a full set of parameters you can customize for `pixel_consensus_cluster`, please consult <a href=https://ark-analysis.readthedocs.io/en/latest/_markdown/ark.phenotyping.html#ark.phenotyping.pixel_cluster_utils.pixel_consensus_cluster>pixel consensus clustering docs</a>

# %% [markdown]
# * `max_k`: the number of consensus clusters desired
# * `cap`: used to clip z-scored values prior to consensus clustering (in the range `[-cap, cap]`)

# %%
overwrite = False# if one changes any of the below, overwrite to be set to True
max_k = 30
cap = 3
import time
batch_size = 20
start = time.time()

# run hierarchical clustering using average pixel SOM cluster expression
pixel_cc = pixel_meta_clustering.pixel_consensus_cluster(
    fovs,
    channels,
    base_dir,
    max_k=max_k,
    cap=cap,
    data_dir=pixel_data_dir,
    pc_chan_avg_som_cluster_name=pc_chan_avg_som_cluster_name,
    multiprocess=multiprocess,
    batch_size=batch_size,
    overwrite = overwrite
)
end = time.time()
print('Elapsed time:', end - start)
start = time.time()
# generate the meta cluster summary files
pixel_meta_clustering.generate_meta_avg_files(
    fovs,
    channels,
    base_dir,
    pixel_cc,
    data_dir=pixel_data_dir,
    pc_chan_avg_som_cluster_name=pc_chan_avg_som_cluster_name,
    pc_chan_avg_meta_cluster_name=pc_chan_avg_meta_cluster_name,
    overwrite = overwrite)
end = time.time()
print('Elapsed time:', end - start)
# Out:
# Overwrite flag set, reassigning meta cluster labels to all FOVs
# z-score scaling and capping data
# Running consensus clustering
# Mapping pixel data to consensus cluster labels
# Processed 20 fovs
# Processed 40 fovs
# Processed 60 fovs
# Processed 80 fovs
# Processed 100 fovs
# Processed 120 fovs
# Processed 140 fovs
# Processed 160 fovs
# Processed 180 fovs
# Processed 200 fovs
# Processed 220 fovs
# Processed 240 fovs
# Processed 260 fovs
# Processed 280 fovs
# Processed 300 fovs
# Processed 320 fovs
# Processed 340 fovs
# Processed 360 fovs
# Processed 380 fovs
# Processed 400 fovs
# Processed 420 fovs
# Processed 440 fovs
# Processed 460 fovs
# Processed 480 fovs
# Processed 500 fovs
# Processed 520 fovs
# Processed 540 fovs
# Processed 560 fovs
# Processed 580 fovs
# Processed 600 fovs
# Processed 620 fovs
# Processed 640 fovs
# Processed 660 fovs
# Processed 680 fovs
# Processed 700 fovs
# Processed 720 fovs
# Processed 740 fovs
# Processed 760 fovs
# Processed 780 fovs
# Processed 800 fovs
# Processed 820 fovs
# Processed 840 fovs
# Processed 860 fovs
# Processed 871 fovs
# Elapsed time: 1895.4079043865204
# Computing average channel expression across pixel meta clusters
# Mapping meta cluster values onto average channel expression across pixel SOM clusters
# Elapsed time: 255.8373899459839

# %% [markdown]
# ## 4: Visualize results

# %% [markdown]
# ### 4.1: Interactive adjustments to relabel pixel meta clusters

# %% [markdown]
# The visualization shows the z-scored average channel expression per pixel SOM and meta cluster. The heatmaps are faceted by pixel SOM clusters on the left and pixel meta clusters on the right.
#
# ## Usage
#
# ### Quickstart
# - **Select**: Left Click
# - **Remap**: **New metacluster** button or Right Click
# - **Edit Metacluster Name**: Textbox at bottom right of the heatmaps.
#
# ### Selection and remapping details
# - To select a SOM cluster, click on its respective position in the **selected** bar. Click on it again to deselect.
# - To select a meta cluster, click on its corresponding color in the **metacluster** bar. Click on it again to deselect.
# - To remap the selected clusters, click the **New metacluster** button (alternatively, right click anywhere). Note that remapping an entire metacluster deletes it.
# - To clear the selected SOM/meta clusters, use the **Clear Selection** button.
# - **After remapping a meta cluster, make sure to deselect the newly created one to prevent unwanted combinations.**
#
# ### Other features and notes
# - You will likely need to zoom out to see the entire visualization. To toggle Zoom, use Ctrl -/Ctrl + on Windows or ⌘ +/⌘ - on Mac.
# - The bars at the top show the number of pixels in each SOM cluster.
# - The text box at the bottom right allows you to rename a particular meta cluster. This can be useful as remapping may cause inconsistent numbering. **You cannot use the same name for different meta clusters; doing so will cause the next step to fail.**
# - Adjust the z-score limit using the slider on the bottom left to adjust your dynamic range.
# - When meta clusters are combined or a meta cluster is renamed, the change is immediately saved to `pixel_meta_cluster_remap_name`.
# - You won't be able to advance in the notebook until you've clicked `New metacluster` or renamed a meta cluster at least once. If you don't want to make changes, just click `New metacluster` to trigger a save before continuing.

# %%
# %matplotlib widget
rc_file_defaults()
plt.ion()

pixel_mcd = metaclusterdata_from_files(
    os.path.join(base_dir, pc_chan_avg_som_cluster_name),
    cluster_type='pixel'
)
pixel_mcd.output_mapping_filename = os.path.join(base_dir, pixel_meta_cluster_remap_name)
pixel_mcg = MetaClusterGui(pixel_mcd, width=10)
# Out:
# VBox(children=(Output(), HBox(children=(HBox(children=(FloatSlider(value=3.0, description='Max Zscore:', max=1…

# %% [markdown]
# Relabel the pixel meta clusters using the mapping, and recompute the meta cluster average files with the new meta cluster names.

# %%
overwrite = True# if one changes any of the below, overwrite to be set to True
batch_size = 20
# rename the meta cluster values in the pixel dataset
pixel_meta_clustering.apply_pixel_meta_cluster_remapping(
    fovs,
    channels,
    base_dir,
    pixel_data_dir,
    pixel_meta_cluster_remap_name,
    multiprocess=multiprocess,
    batch_size=batch_size,
)

# recompute the mean channel expression per meta cluster and apply these new names to the SOM cluster average data
pixel_meta_clustering.generate_remap_avg_files(
    fovs,
    channels,
    base_dir,
    pixel_data_dir,
    pixel_meta_cluster_remap_name,
    pc_chan_avg_som_cluster_name,
    pc_chan_avg_meta_cluster_name,
)
# Out:
# Using re-mapping scheme to re-label pixel meta clusters
# Processed 20 fovs
# Processed 40 fovs
# Processed 60 fovs
# Processed 80 fovs
# Processed 100 fovs
# Processed 120 fovs
# Processed 140 fovs
# The data for FOV Leap009_3 has been corrupted, skipping
# Processed 159 fovs
# Processed 179 fovs
# Processed 199 fovs
# Processed 219 fovs
# Processed 239 fovs
# Processed 259 fovs
# Processed 279 fovs
# Processed 299 fovs
# Processed 319 fovs
# Processed 339 fovs
# Processed 359 fovs
# Processed 379 fovs
# Processed 399 fovs
# Processed 419 fovs
# Processed 439 fovs
# Processed 459 fovs
# Processed 479 fovs
# Processed 499 fovs
# Processed 519 fovs
# Processed 539 fovs
# Processed 559 fovs
# Processed 579 fovs
# Processed 599 fovs
# Processed 619 fovs
# Processed 639 fovs
# Processed 659 fovs
# Processed 679 fovs
# Processed 699 fovs
# Processed 719 fovs
# Processed 739 fovs
# Processed 759 fovs
# Processed 779 fovs
# Processed 799 fovs
# Processed 819 fovs
# Processed 839 fovs
# Processed 859 fovs
# Processed 870 fovs
# Re-computing average channel expression across pixel meta clusters
# Re-assigning meta cluster column in pixel SOM cluster average channel expression table

# %%
len(fovs)
pixel_cluster_utils.find_fovs_missing_col(   base_dir, pixel_data_dir, 'pixel_meta_cluster_rename')
# Out:
# []

# %% [markdown]
# Generate the color scheme returned by the interactive reclustering process. This will be for visualizing the pixel phenotype maps.

# %%
raw_cmap, _ = colormap_helper.generate_meta_cluster_colormap_dict(
    pixel_mcd.output_mapping_filename,
    pixel_mcg.im_cl.cmap
)

# %% [markdown]
# ### 4.2: Generate pixel phenotype maps
#
# Generate pixel phenotype maps, in which each pixel in the image corresponds to its pixel meta cluster. Select a small subset of your FOVs to view within this notebook. Or if you wish to generate and save a significant amount of FOVs, the masks will be created and saved in batches.
#
# Files will be written as `{fov_name}_pixel_mask.tiff` in `pixel_output_dir`

# %%
# select fovs to display
subset_pixel_fovs = ['Leap001_8']

# %%
# define the path to the channel file
if img_sub_folder is None:
    chan_file = os.path.join(
        io_utils.list_files(os.path.join(tiff_dir, fovs[0]), substrs=['.tiff'])[0]
    )
else:
    chan_file = os.path.join(
        img_sub_folder, io_utils.list_files(os.path.join(tiff_dir, fovs[0], img_sub_folder), substrs=['.tiff'])[0]
    )

# generate and save the pixel cluster masks for each fov in subset_pixel_fovs
data_utils.generate_and_save_pixel_cluster_masks(
    fovs=subset_pixel_fovs,
    base_dir=base_dir,
    save_dir=os.path.join(base_dir, pixel_output_dir),
    tiff_dir=tiff_dir,
    chan_file=chan_file,
    pixel_data_dir=pixel_data_dir,
    pixel_cluster_col='pixel_meta_cluster',
    sub_dir='pixel_masks',
    name_suffix='_pixel_mask',
)
# Out:
# Pixel Cluster Mask Generation:   0%|          | 0/1 [00:00<?, ?FOVs/s]

# %% [markdown]
# Save the colored pixel masks for each FOV in `subset_pixel_fovs`.

# %%
plot_utils.save_colored_masks(
    fovs=subset_pixel_fovs,
    mask_dir=os.path.join(base_dir, pixel_output_dir, "pixel_masks"),
    save_dir=os.path.join(base_dir, pixel_output_dir, "pixel_mask_colored"),
    cluster_id_to_name_path=os.path.join(base_dir, pixel_meta_cluster_remap_name),
    metacluster_colors=raw_cmap,
    cluster_type="pixel"
)
# Out:
# Saving colored masks: 100%|███████████████████████| 1/1 [00:00<00:00, 10.17FOVs/s, FOV=Leap001_8]

# %% [markdown]
# Load a subset of the pixel cluster masks that you would like to preview.

# %%
for pixel_fov in subset_pixel_fovs:
    pixel_cluster_mask = load_utils.load_imgs_from_dir(
        data_dir=os.path.join(base_dir, pixel_output_dir, "pixel_masks"),
        files=[pixel_fov + "_pixel_mask.tiff"],
        trim_suffix="_pixel_mask",
        match_substring="_pixel_mask",
        xr_dim_name="pixel_mask",
        xr_channel_names=None,
    )

    plot_utils.plot_pixel_cell_cluster_overlay(
        pixel_cluster_mask,
        [pixel_fov],
        os.path.join(base_dir, pixel_meta_cluster_remap_name),
        metacluster_colors=raw_cmap
    )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 5: Save parameters for use in cell clustering

# %% [markdown]
# The following parameters are saved:
#
# * `fovs`: fovs in `pixel_data_dir`
# * `channels`: channels used for clustering
# * `segmentation_dir`: path to the directory containing your segmentated images for each FOV (can be generated using `1_Segment_Image_Data.ipynb`)
# * `seg_suffix`: suffix plus the file extension of the segmented images for each FOV
# * `pixel_data_dir`: name of the directory containing the full pixel data with the pixel SOM and meta cluster assignments
# * `pc_chan_avg_som_cluster_name`: name of the file containing the average channel expression per pixel SOM cluster
# * `pc_chan_avg_meta_cluster_name`: same as above for pixel meta clusters
#
# The file will be saved to `{pixel_cluster_prefix}_cell_clustering_params.json` and will be placed in `pixel_output_dir`. Note that the `pixel_output_dir` you use in `2_Pixie_Cluster_Pixels.ipynb` should be the same as in `3_Pixie_Cluster_Cells.ipynb`.

# %%
io_utils.remove_file_extensions(io_utils.list_files(os.path.join(base_dir, pixel_data_dir), substrs='.feather'))
# Out:
# ['Leap045_6',
#  'Leap032_9',
#  'Leap017_6',
#  'Leap095_8',
#  'Leap035_11',
#  'Leap064_1',
#  'Leap045_13',
#  'Leap058_2',
#  'Leap009_16',
#  'Leap035_1',
#  'Leap005_12',
#  'Leap031_3',
#  'Leap057_6',
#  'Leap070_4',
#  'Leap013_6',
#  'Leap055_11',
#  'Leap005_1',
#  'Leap056_4',
#  'Leap036_6',
#  'Leap031_5',
#  'Leap094_8',
#  'Leap081_15',
#  'Leap084_10',
#  'Leap015_4',
#  'Leap009_19',
#  'Leap066_12',
#  'Leap066_14',
#  'Leap018_16',
#  'Leap064_5',
#  'Leap016_1',
#  'Leap092_5',
#  'Leap071_5',
#  'Leap059_4',
#  'Leap031_2',
#  'Leap036_4',
#  'Leap020_5',
#  'Leap023_3',
#  'Leap094_5',
#  'Leap092_1',
#  'Leap056_1',
#  'Leap002_4',
#  'Leap009_9',
#  'Leap018_3',
#  'Leap068_6',
#  'Leap021_2',
#  'Leap092_7',
#  'Leap062_1',
#  'Leap017_4',
#  'Leap081_7',
#  'Leap013_1',
#  'Leap016_2',
#  'Leap014_18',
#  'Leap077_8',
#  'Leap084_17',
#  'Leap081_5',
#  'Leap067_11',
#  'Leap077_2',
#  'Leap041_16',
#  'Leap011_7',
#  'Leap017_8',
#  'Leap010_10',
#  'Leap039_3',
#  'Leap032_10',
#  'Leap019_12',
#  'Leap037_17',
#  'Leap041_9',
#  'Leap005_6',
#  'Leap082_5',
#  'Leap036_7',
#  'Leap081_1',
#  'Leap009_4',
#  'Leap004_6',
#  'Leap062_4',
#  'Leap066_11',
#  'Leap011_3',
#  'Leap052_6',
#  'Leap024_7',
#  'Leap005_2',
#  'Leap084_15',
#  'Leap073_14',
#  'Leap073_5',
#  'Leap057_14',
#  'Leap010_17',
#  'Leap041_5',
#  'Leap017_13',
#  'Leap090_2',
#  'Leap068_11',
#  'Leap086_2',
#  'Leap002_7',
#  'Leap001_8',
#  'Leap083_1',
#  'Leap075_3',
#  'Leap090_4',
#  'Leap050_4',
#  'Leap023_6',
#  'Leap084_11',
#  'Leap089_4',
#  'Leap009_1',
#  'Leap055_3',
#  'Leap057_2',
#  'Leap057_12',
#  'Leap080_4',
#  'Leap019_11',
#  'Leap009_7',
#  'Leap009_11',
#  'Leap021_3',
#  'Leap066_1',
#  'Leap068_5',
#  'Leap045_11',
#  'Leap035_9',
#  'Leap041_2',
#  'Leap061_6',
#  'Leap042_2',
#  'Leap018_19',
#  'Leap009_5',
#  'Leap018_5',
#  'Leap028_14',
#  'Leap015_6',
#  'Leap087_8',
#  'Leap017_12',
#  'Leap061_5',
#  'Leap050_6',
#  'Leap089_11',
#  'Leap088_7',
#  'Leap052_5',
#  'Leap066_2',
#  'Leap053_1',
#  'Leap053_10',
#  'Leap037_11',
#  'Leap079_8',
#  'Leap051_20',
#  'Leap094_15',
#  'Leap017_14',
#  'Leap011_18',
#  'Leap061_3',
#  'Leap071_6',
#  'Leap092_3',
#  'Leap059_1',
#  'Leap090_1',
#  'Leap048_2',
#  'Leap058_9',
#  'Leap057_10',
#  'Leap054_10',
#  'Leap066_4',
#  'Leap046_3',
#  'Leap078_2',
#  'Leap086_4',
#  'Leap054_7',
#  'Leap064_9',
#  'Leap069_4',
#  'Leap029_3',
#  'Leap019_14',
#  'Leap034_10',
#  'Leap070_5',
#  'Leap064_3',
#  'Leap014_16',
#  'Leap084_19',
#  'Leap043_6',
#  'Leap086_8',
#  'Leap077_4',
#  'Leap056_13',
#  'Leap096_1',
#  'Leap034_11',
#  'Leap039_5',
#  'Leap065_1',
#  'Leap012_22',
#  'Leap051_22',
#  'Leap076_1',
#  'Leap023_4',
#  'Leap094_11',
#  'Leap014_14',
#  'Leap034_5',
#  'Leap019_13',
#  'Leap089_9',
#  'Leap011_2',
#  'Leap055_2',
#  'Leap036_8',
#  'Leap031_7',
#  'Leap073_1',
#  'Leap083_10',
#  'Leap014_20',
#  'Leap067_5',
#  'Leap014_13',
#  'Leap013_3',
#  'Leap066_9',
#  'Leap077_6',
#  'Leap085_8',
#  'Leap048_4',
#  'Leap008_3',
#  'Leap042_6',
#  'Leap014_15',
#  'Leap026_1',
#  'Leap081_3',
#  'Leap065_4',
#  'Leap041_17',
#  'Leap011_11',
#  'Leap070_7',
#  'Leap093_10',
#  'Leap034_9',
#  'Leap053_2',
#  'Leap050_2',
#  'Leap051_18',
#  'Leap040_4',
#  'Leap033_4',
#  'Leap028_13',
#  'Leap059_5',
#  'Leap017_9',
#  'Leap089_5',
#  'Leap017_24',
#  'Leap094_3',
#  'Leap082_8',
#  'Leap019_10',
#  'Leap035_6',
#  'Leap087_4',
#  'Leap052_11',
#  'Leap073_7',
#  'Leap056_6',
#  'Leap052_1',
#  'Leap010_8',
#  'Leap074_2',
#  'Leap061_8',
#  'Leap066_6',
#  'Leap094_19',
#  'Leap062_9',
#  'Leap018_29',
#  'Leap011_4',
#  'Leap034_4',
#  'Leap004_10',
#  'Leap050_8',
#  'Leap074_1',
#  'Leap009_12',
#  'Leap012_23',
#  'Leap009_6',
#  'Leap065_5',
#  'Leap066_10',
#  'Leap024_1',
#  'Leap059_7',
#  'Leap011_10',
#  'Leap021_4',
#  'Leap018_22',
#  'Leap096_3',
#  'Leap011_17',
#  'Leap075_2',
#  'Leap030_13',
#  'Leap053_13',
#  'Leap062_10',
#  'Leap017_19',
#  'Leap056_9',
#  'Leap017_3',
#  'Leap053_5',
#  'Leap054_2',
#  'Leap077_1',
#  'Leap015_5',
#  'Leap012_24',
#  'Leap058_1',
#  'Leap079_3',
#  'Leap033_9',
#  'Leap028_10',
#  'Leap019_7',
#  'Leap025_4',
#  'Leap081_17',
#  'Leap096_8',
#  'Leap010_15',
#  'Leap017_22',
#  'Leap045_8',
#  'Leap035_7',
#  'Leap094_22',
#  'Leap041_1',
#  'Leap095_10',
#  'Leap005_7',
#  'Leap017_20',
#  'Leap014_12',
#  'Leap033_3',
#  'Leap018_9',
#  'Leap020_3',
#  'Leap028_12',
#  'Leap094_9',
#  'Leap019_9',
#  'Leap053_4',
#  'Leap081_10',
#  'Leap031_4',
#  'Leap083_8',
#  'Leap078_4',
#  'Leap024_2',
#  'Leap029_1',
#  'Leap018_10',
#  'Leap070_10',
#  'Leap085_6',
#  'Leap012_21',
#  'Leap016_5',
#  'Leap085_2',
#  'Leap056_12',
#  'Leap013_4',
#  'Leap020_2',
#  'Leap052_3',
#  'Leap023_8',
#  'Leap053_3',
#  'Leap030_10',
#  'Leap034_6',
#  'Leap004_9',
#  'Leap068_8',
#  'Leap008_5',
#  'Leap053_8',
#  'Leap087_2',
#  'Leap061_7',
#  'Leap081_4',
#  'Leap005_9',
#  'Leap036_10',
#  'Leap058_4',
#  'Leap088_5',
#  'Leap052_13',
#  'Leap070_8',
#  'Leap004_1',
#  'Leap013_5',
#  'Leap016_6',
#  'Leap023_5',
#  'Leap038_8',
#  'Leap055_4',
#  'Leap081_19',
#  'Leap077_12',
#  'Leap018_11',
#  'Leap093_7',
#  'Leap037_14',
#  'Leap033_8',
#  'Leap017_16',
#  'Leap093_3',
#  'Leap041_11',
#  'Leap055_13',
#  'Leap089_2',
#  'Leap089_8',
#  'Leap010_12',
#  'Leap009_13',
#  'Leap083_9',
#  'Leap021_7',
#  'Leap002_3',
#  'Leap005_10',
#  'Leap039_7',
#  'Leap022_1',
#  'Leap082_4',
#  'Leap067_4',
#  'Leap094_12',
#  'Leap024_5',
#  'Leap081_6',
#  'Leap067_2',
#  'Leap031_8',
#  'Leap009_8',
#  'Leap065_2',
#  'Leap041_10',
#  'Leap057_1',
#  'Leap011_13',
#  'Leap087_13',
#  'Leap024_6',
#  'Leap070_1',
#  'Leap009_17',
#  'Leap092_8',
#  'Leap087_10',
#  'Leap003_11',
#  'Leap008_2',
#  'Leap023_2',
#  'Leap084_8',
#  'Leap061_10',
#  'Leap010_5',
#  'Leap093_2',
#  'Leap084_16',
#  'Leap018_17',
#  'Leap094_23',
#  'Leap079_5',
#  'Leap017_1',
#  'Leap080_2',
#  'Leap004_5',
#  'Leap021_1',
#  'Leap049_1',
#  'Leap038_2',
#  'Leap051_23',
#  'Leap021_8',
#  'Leap082_11',
#  'Leap094_17',
#  'Leap042_4',
#  'Leap093_6',
#  'Leap005_4',
#  'Leap056_5',
#  'Leap017_21',
#  'Leap085_4',
#  'Leap018_20',
#  'Leap037_12',
#  'Leap062_5',
#  'Leap059_2',
#  'Leap018_18',
#  'Leap017_2',
#  'Leap071_2',
#  'Leap041_15',
#  'Leap066_13',
#  'Leap055_1',
#  'Leap038_9',
#  'Leap094_4',
#  'Leap033_7',
#  'Leap038_5',
#  'Leap067_10',
#  'Leap050_7',
#  'Leap092_9',
#  'Leap053_9',
#  'Leap026_3',
#  'Leap018_8',
#  'Leap014_17',
#  'Leap014_11',
#  'Leap064_4',
#  'Leap055_10',
#  'Leap092_4',
#  'Leap051_16',
#  'Leap052_9',
#  'Leap083_7',
#  'Leap011_9',
#  'Leap079_4',
#  'Leap040_10',
#  'Leap030_11',
#  'Leap095_6',
#  'Leap049_3',
#  'Leap009_14',
#  'Leap024_4',
#  'Leap040_7',
#  'Leap074_4',
#  'Leap025_2',
#  'Leap082_7',
#  'Leap087_9',
#  'Leap077_5',
#  'Leap095_12',
#  'Leap088_1',
#  'Leap021_5',
#  'Leap062_8',
#  'Leap053_6',
#  'Leap057_4',
#  'Leap017_17',
#  'Leap076_2',
#  'Leap089_3',
#  'Leap082_6',
#  'Leap068_7',
#  'Leap067_8',
#  'Leap080_1',
#  'Leap010_6',
#  'Leap094_10',
#  'Leap036_9',
#  'Leap071_4',
#  'Leap061_1',
#  'Leap096_9',
#  'Leap034_1',
#  'Leap094_13',
#  'Leap084_2',
#  'Leap069_3',
#  'Leap011_5',
#  'Leap085_7',
#  'Leap003_16',
#  'Leap077_9',
#  'Leap094_2',
#  'Leap018_12',
#  'Leap053_11',
#  'Leap052_7',
#  'Leap094_1',
#  'Leap054_5',
#  'Leap054_13',
#  'Leap046_1',
#  'Leap070_3',
#  'Leap004_2_12',
#  'Leap035_14',
#  'Leap084_4',
#  'Leap018_14',
#  'Leap068_3',
#  'Leap051_19',
#  'Leap051_17',
#  'Leap085_5',
#  'Leap008_8',
#  'Leap018_1',
#  'Leap081_13',
#  'Leap041_7',
#  'Leap035_13',
#  'Leap073_8',
#  'Leap073_3',
#  'Leap048_7',
#  'Leap096_10',
#  'Leap064_6',
#  'Leap008_9',
#  'Leap029_2',
#  'Leap018_28',
#  'Leap054_4',
#  'Leap059_3',
#  'Leap058_7',
#  'Leap084_5',
#  'Leap081_18',
#  'Leap018_21',
#  'Leap034_13',
#  'Leap011_8',
#  'Leap067_13',
#  'Leap004_2',
#  'Leap004_2_15',
#  'Leap052_10',
#  'Leap004_2_14',
#  'Leap048_5',
#  'Leap062_3',
#  'Leap032_7',
#  'Leap087_1',
#  'Leap011_6',
#  'Leap038_3',
#  'Leap046_4',
#  'Leap043_3',
#  'Leap002_6',
#  'Leap068_13',
#  'Leap006_1',
#  'Leap038_10',
#  'Leap016_3',
#  'Leap067_7',
#  'Leap086_7',
#  'Leap065_6',
#  'Leap034_12',
#  'Leap057_9',
#  'Leap033_5',
#  'Leap080_3',
#  'Leap053_7',
#  'Leap057_5',
#  'Leap055_14',
#  'Leap080_5',
#  'Leap052_8',
#  'Leap064_7',
#  'Leap082_9',
#  'Leap090_3',
#  'Leap059_8',
#  'Leap089_1',
#  'Leap056_11',
#  'Leap040_8',
#  'Leap079_9',
#  'Leap022_3',
#  'Leap054_9',
#  'Leap094_18',
#  'Leap084_1',
#  'Leap033_6',
#  'Leap088_6',
#  'Leap040_13',
#  'Leap017_5',
#  'Leap035_12',
#  'Leap037_16',
#  'Leap081_21',
#  'Leap004_3',
#  'Leap071_1',
#  'Leap017_23',
#  'Leap079_6',
#  'Leap022_5',
#  'Leap013_7',
#  'Leap045_10',
#  'Leap052_4',
#  'Leap087_6',
#  'Leap036_2',
#  'Leap096_2',
#  'Leap073_2',
#  'Leap077_3',
#  'Leap040_2',
#  'Leap029_5',
#  'Leap065_3',
#  'Leap040_12',
#  'Leap023_7',
#  'Leap073_12',
#  'Leap011_16',
#  'Leap094_20',
#  'Leap020_6',
#  'Leap036_1',
#  'Leap042_1',
#  'Leap056_8',
#  'Leap017_11',
#  'Leap070_2',
#  'Leap035_2',
#  'Leap082_10',
#  'Leap059_6',
#  'Leap084_6',
#  'Leap088_4',
#  'Leap055_9',
#  'Leap017_29',
#  'Leap086_5',
#  'Leap086_6',
#  'Leap068_1',
#  'Leap018_23',
#  'Leap095_3',
#  'Leap030_12',
#  'Leap082_3',
#  'Leap066_7',
#  'Leap094_16',
#  'Leap013_9',
#  'Leap088_8',
#  'Leap095_4',
#  'Leap041_3',
#  'Leap084_12',
#  'Leap064_8',
#  'Leap006_2',
#  'Leap079_1',
#  'Leap039_2',
#  'Leap081_11',
#  'Leap032_8',
#  'Leap092_6',
#  'Leap064_2',
#  'Leap003_12',
#  'Leap076_5',
#  'Leap087_14',
#  'Leap048_8',
#  'Leap051_15',
#  'Leap045_14',
#  'Leap022_4',
#  'Leap054_8',
#  'Leap095_7',
#  'Leap011_15',
#  'Leap024_3',
#  'Leap088_3',
#  'Leap037_13',
#  'Leap017_28',
#  'Leap037_15',
#  'Leap029_8',
#  'Leap076_3',
#  'Leap061_4',
#  'Leap017_15',
#  'Leap004_2_11',
#  'Leap074_5',
#  'Leap081_16',
#  'Leap087_12',
#  'Leap084_13',
#  'Leap049_2',
#  'Leap069_1',
#  'Leap006_4',
#  'Leap002_5',
#  'Leap088_9',
#  'Leap043_2',
#  'Leap004_2_13',
#  'Leap009_15',
#  'Leap020_4',
#  'Leap073_9',
#  'Leap095_11',
#  'Leap095_13',
#  'Leap016_4',
#  'Leap073_6',
#  'Leap015_2',
#  'Leap052_2',
#  'Leap096_11',
#  'Leap084_21',
#  'Leap095_5',
#  'Leap089_7',
#  'Leap048_3',
#  'Leap010_11',
#  'Leap002_1',
#  'Leap089_10',
#  'Leap093_1',
#  'Leap022_2',
#  'Leap050_3',
#  'Leap043_1',
#  'Leap006_3',
#  'Leap041_12',
#  'Leap059_9',
#  'Leap043_5',
#  'Leap092_10',
#  'Leap005_13',
#  'Leap010_2',
#  'Leap014_19',
#  'Leap018_13',
#  'Leap055_6',
#  'Leap008_4',
#  'Leap017_7',
#  'Leap011_1',
#  'Leap008_6',
#  'Leap068_4',
#  'Leap066_8',
#  'Leap074_3',
#  'Leap036_5',
#  'Leap082_2',
#  'Leap057_7',
#  'Leap040_14',
#  'Leap057_11',
#  'Leap025_5',
#  'Leap040_11',
#  'Leap061_9',
#  'Leap058_5',
#  'Leap005_3',
#  'Leap034_3',
#  'Leap078_1',
#  'Leap083_2',
#  'Leap010_14',
#  'Leap057_8',
#  'Leap025_3',
#  'Leap094_6',
#  'Leap011_19',
#  'Leap086_3',
#  'Leap018_7',
#  'Leap096_4',
#  'Leap062_6',
#  'Leap003_14',
#  'Leap034_14',
#  'Leap085_1',
#  'Leap094_21',
#  'Leap081_12',
#  'Leap038_4',
#  'Leap045_7',
#  'Leap001_10',
#  'Leap078_3',
#  'Leap018_15',
#  'Leap075_1',
#  'Leap083_4',
#  'Leap050_1',
#  'Leap055_12',
#  'Leap069_2',
#  'Leap046_2',
#  'Leap011_12',
#  'Leap048_6',
#  'Leap034_8',
#  'Leap018_6',
#  'Leap056_7',
#  'Leap040_9',
#  'Leap070_9',
#  'Leap043_4',
#  'Leap037_18',
#  'Leap004_8',
#  'Leap094_7',
#  'Leap025_7',
#  'Leap005_8',
#  'Leap067_6',
#  'Leap004_4',
#  'Leap068_2',
#  'Leap038_7',
#  'Leap081_20',
#  'Leap009_18',
#  'Leap038_6',
#  'Leap035_3',
#  'Leap056_10',
#  'Leap001_9',
#  'Leap010_19',
#  'Leap035_5',
#  'Leap005_5',
#  'Leap041_6',
#  'Leap054_6',
#  'Leap034_2',
#  'Leap029_7',
#  'Leap025_1',
#  'Leap095_9',
#  'Leap077_14',
#  'Leap058_6',
#  'Leap071_3',
#  'Leap015_1',
#  'Leap040_3',
#  'Leap087_3',
#  'Leap035_10',
#  'Leap011_14',
#  'Leap066_5',
#  'Leap055_5',
#  'Leap017_10',
#  'Leap041_4',
#  'Leap035_8',
#  'Leap095_1',
#  'Leap009_2',
#  'Leap058_3',
#  'Leap048_1',
#  'Leap068_12',
#  'Leap066_3',
#  'Leap087_11',
#  'Leap081_14',
#  'Leap070_6',
#  'Leap034_7',
#  'Leap041_14',
#  'Leap010_9',
#  'Leap038_1',
#  'Leap093_9',
#  'Leap057_3',
#  'Leap009_10',
#  'Leap077_11',
#  'Leap018_4',
#  'Leap010_1',
#  'Leap029_4',
#  'Leap079_7',
#  'Leap083_6',
#  'Leap056_3',
#  'Leap012_25',
#  'Leap040_5',
#  'Leap013_8',
#  'Leap067_1',
#  'Leap005_11',
#  'Leap054_3',
#  'Leap094_14',
#  'Leap018_2',
#  'Leap010_16',
#  'Leap031_6',
#  'Leap067_12',
#  'Leap091_1',
#  'Leap081_2',
#  'Leap031_9',
#  'Leap008_11',
#  'Leap033_1',
#  'Leap021_6',
#  'Leap092_2',
#  'Leap004_7',
#  'Leap010_3',
#  'Leap081_9',
#  'Leap050_5',
#  'Leap018_24',
#  'Leap057_13',
#  'Leap056_2',
#  'Leap096_5',
#  'Leap055_8',
#  'Leap079_2',
#  'Leap089_6',
#  'Leap008_10',
#  'Leap019_8',
#  'Leap003_13',
#  'Leap093_4',
#  'Leap073_10',
#  'Leap025_6',
#  'Leap014_10',
#  'Leap088_2',
#  'Leap041_8',
#  'Leap031_1',
#  'Leap020_1',
#  'Leap094_24',
#  'Leap084_20',
#  'Leap010_7',
#  'Leap023_1',
#  'Leap013_2',
#  'Leap096_7',
#  'Leap062_7',
#  'Leap084_9',
#  'Leap017_18',
#  'Leap058_8',
#  'Leap042_3',
#  'Leap051_24',
#  'Leap015_3',
#  'Leap076_4',
#  'Leap010_13',
#  'Leap083_5',
#  'Leap010_18',
#  'Leap028_11',
#  'Leap033_10',
#  'Leap073_4',
#  'Leap075_4',
#  'Leap056_14',
#  'Leap039_4',
#  'Leap095_2',
#  'Leap090_6',
#  'Leap003_15',
#  'Leap084_7',
#  'Leap067_3',
#  'Leap041_13',
#  'Leap084_3',
#  'Leap090_5',
#  'Leap008_1',
#  'Leap077_10',
#  'Leap045_9',
#  'Leap033_2',
#  'Leap004_2_16',
#  'Leap087_5',
#  'Leap085_3',
#  'Leap028_9',
#  'Leap051_21',
#  'Leap096_6',
#  'Leap082_1',
#  'Leap008_7',
#  'Leap055_7',
#  'Leap026_2',
#  'Leap068_10',
#  'Leap073_11',
#  'Leap036_3',
#  'Leap010_4',
#  'Leap045_12',
#  'Leap090_7',
#  'Leap083_3',
#  'Leap081_8',
#  'Leap054_11',
#  'Leap084_14',
#  'Leap054_1',
#  'Leap035_4',
#  'Leap029_6',
#  'Leap073_13',
#  'Leap084_18']

# %%
# define the params dict
cell_clustering_params = {
    'fovs': fovs,
    'channels': channels,
    'tiff_dir': tiff_dir,
    'img_sub_folder': img_sub_folder,
    'segmentation_dir': segmentation_dir,
    'seg_suffix': seg_suffix,
    'pixel_data_dir': pixel_data_dir,
    'pc_chan_avg_som_cluster_name': pc_chan_avg_som_cluster_name,
    'pc_chan_avg_meta_cluster_name': pc_chan_avg_meta_cluster_name
}

# save the params dict
with open(os.path.join(base_dir, pixel_output_dir, 'cell_clustering_params.json'), 'w') as fh:
    json.dump(cell_clustering_params, fh)

# %%
print(pixel_output_dir)
# Out:
# pixie/all_pixel_output_dir

# %% [markdown]
# ### 5.1 Save images for Mantis Viewer
#
# Mantis Viewer is a visualization tool for multi-dimensional imaging in pathology. Learn more about Mantis Viewer in the [README](../README.md#mantis-viewer).

# %%
plot_utils.create_mantis_dir(
    fovs=subset_pixel_fovs,
    mantis_project_path=os.path.join(base_dir, pixel_output_dir, "mantis"),
    img_data_path=tiff_dir,
    mask_output_dir=os.path.join(base_dir, pixel_output_dir, "pixel_masks"),
    mapping = os.path.join(base_dir, pixel_meta_cluster_remap_name),
    seg_dir=pixie_seg_dir,
    mask_suffix="_pixel_mask",
    seg_suffix_name=seg_suffix,
    img_sub_folder=img_sub_folder
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plot_utils.create_mantis_dir(
#       2     fovs=subset_pixel_fovs,
#       3     mantis_project_path=os.path.join(base_dir, pixel_output_dir, "mantis"),
#       4     img_data_path=tiff_dir,
#       5     mask_output_dir=os.path.join(base_dir, pixel_output_dir, "pixel_masks"),
#       6     mapping = os.path.join(base_dir, pixel_meta_cluster_remap_name),
#       7     seg_dir=pixie_seg_dir,
#       8     mask_suffix="_pixel_mask",
#       9     seg_suffix_name=seg_suffix,
#      10     img_sub_folder=img_sub_folder
#      11 )
#
# File ~/anaconda3/envs/ark_env/lib/python3.11/site-packages/ark/utils/plot_utils.py:617, in create_mantis_dir(fovs, mantis_project_path, img_data_path, mask_output_dir, mapping, seg_dir, cluster_type, mask_suffix, seg_suffix_name, img_sub_folder)
#     614 # create a folder with image data, pixel masks, and segmentation mask
#     615 for fov, mn in zip(fovs, mask_names):
#     616     # set up paths
# --> 617     img_source_dir = os.path.join(img_data_path, fov, img_sub_folder)
#     618     output_dir = os.path.join(mantis_project_path, fov)
#     620     # copy image data if not already copied in from previous round of clustering
#
# File <frozen posixpath>:90, in join(a, *p)
#
# File <frozen genericpath>:152, in _check_arg_types(funcname, *args)
#
# TypeError: join() argument must be str, bytes, or os.PathLike object, not 'NoneType'

# %%
import numpy as np
np.arange(len(new_fovs))[np.array(new_fovs)=='Leap042_6']
# Out:
# array([189])
