# %%
import pandas as pd
import numpy as np
import warnings
import re
def unravel_response_df(response):     
    '''Transform the response Excel file to machine readable'''      
    def process_row(row):
        def check_keywords(input_text):
            keywords = ["bilateral", "same patient"]
            for keyword in keywords:
                if keyword.upper() in input_text.upper():
                    return True
            return False

        leap_id = row.LEAP_ID
        prefix = 'LEAP'
        num_part = leap_id.lstrip(prefix)
        parts = num_part.split('/')
        print(parts)
        if len(parts) > 1:
            #print(parts)
            #if comments distinguis between core/section
            if ('core'.upper() in row.COMMENTS.upper()) or ('resection'.upper() in row.COMMENTS.upper()):  
                if len(parts) == row.COMMENTS.count('='):
                    #the number of = characters  matches the number of split in the LEAP_ID column, that is the normal cases
                    #key is leap number, value is the corresponding comment (core or resection)
                    mapper = split_text(row.COMMENTS)#transform mapper to dict and make the key an integer to help indexing of the dictionary below
                elif (('core'.upper() in row.COMMENTS.upper()) ^('resection'.upper() in row.COMMENTS.upper())):
                    # we are in the case where we have more Leaps that information about CORE/RESECTION.
                    #If Comments column contains either CORE or Resection, but not both, this will be assigned to all leaps

                    if 'core' in row.COMMENTS:
                        name = 'core'
                    else:
                        name = 'resection'
                    mapper = {}
                    for part in parts:
                        ind = int(part)
                        mapper[ind] = name
                else:
                    raise ValueError('Multiple Leap ID do not correspond but not the same number of info in COMMENTS column.\n Failed to interpret the comment: ', row.COMMENTS)
                
            else:
                raise ValueError('Failed to interpret the comment: ', row.COMMENTS)
            try:
                new_rows= []
                for part in parts:
                    #split the row into two
                    new_row = row.copy()
                    new_row.LEAP_ID = prefix+part
                    ind = int(part)
                    print(ind)
                    new_row.COMMENTS = mapper[ind]
                    new_rows +=[new_row]
            except KeyError:
                raise KeyError('Failed to interpret the comment: ', row.COMMENTS)
            return new_rows
        else:
            return [row]

    transformed = []
    for _,el in response.iterrows():

        transformed+=[process_row(el)]
    return pd.DataFrame([b for el in transformed for b in el])

# %%
path0 = '../'
response = pd.read_excel(path0+"IMC_data//ExtraDocs/LEAP code response data 05122023.xlsx")
response.columns = response.columns.str.replace(' ','_')#use underscore rather than space
response.COMMENTS = response.COMMENTS.str.replace(',',' ')#the file mix space and , as seprators, using one for good
response = unravel_response_df(response)

biosamples =pd.read_excel(path0+'IMC_data/ExtraDocs/LEAP biobank samples.xlsx')
biosamples.columns = biosamples.columns.str.replace(' ','_')#use underscore rather than space
biosamples.drop('OUTCOME____(RESPONDER,_NON-RESPONDER)',inplace = True,axis = 1)# response status is in response
response = pd.read_excel(path0+"IMC_data//ExtraDocs/processed_response.xlsx")
response.columns = response.columns.str.replace(' ','_')#use underscore rather than space
metadata = biosamples.merge(response,on='LEAP_ID')
if ~np.all(metadata['SAMPLE_TYPE_(CORE/RESECTION)']==metadata['COMMENTS'].str.upper()):
    warnings.warn(metadata[['LEAP_ID','SAMPLE_TYPE_(CORE/RESECTION)']][metadata['SAMPLE_TYPE_(CORE/RESECTION)']!=metadata['COMMENTS'].str.upper()],+'not matching')
metadata.to_csv(path0+'IMC_data//ExtraDocs/processed_response.csv',index = False)
# Out:
# ['001', '2']
# 1
# 2
# ['003', '4']
# 3
# 4
# ['005', '6']
# 5
# 6
# ['007']
# ['008']
# ['009', '10']
# 9
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[249], line 5
#       3 response.columns = response.columns.str.replace(' ','_')#use underscore rather than space
#       4 response.COMMENTS = response.COMMENTS.str.replace(',',' ')#the file mix space and , as seprators, using one for good
# ----> 5 response = unravel_response_df(response)
#       7 biosamples =pd.read_excel(path0+'IMC_data/ExtraDocs/LEAP biobank samples.xlsx')
#       8 biosamples.columns = biosamples.columns.str.replace(' ','_')#use underscore rather than space
#
# Cell In[248], line 64, in unravel_response_df(response)
#      61 transformed = []
#      62 for _,el in response.iterrows():
# ---> 64     transformed+=[process_row(el)]
#      65 return pd.DataFrame([b for el in transformed for b in el])
#
# Cell In[248], line 53, in unravel_response_df.<locals>.process_row(row)
#      51         ind = int(part)
#      52         print(ind)
# ---> 53         new_row.COMMENTS = mapper[ind]
#      54         new_rows +=[new_row]
#      55 except KeyError:
#
# UnboundLocalError: local variable 'mapper' referenced before assignment

# %%
row = response.loc[1]
text = str(row)
regex = r'^\d{1,3}\s*=\s*core|resection' #r"(\d+)\s*=\s*(\S+)\s*(?:,|,\s+|$)"
mapper = re.findall(regex, text,flags=re.IGNORECASE)
text = row.COMMENTS
def split_text(text):
    '''
    Text is match at the beginning and the string is shortened repeatedely
    '''
    regex = r'^\d{1,3}\s*=\s*core|resection'
    data = {}
    while True:
        a = re.search(regex,text,flags=re.IGNORECASE)
        if a is None:
            break
        temp =  text[:a.end()].replace(' ','')#remove any space in the string
        key,value = temp.split('=')
        data[int(key)] = value
        text= text[a.end():]
    return data

# %%
split_text(text)
# Out:
# {'3': 'core', '4': 'resection'}

# %%
dict(['11','22'])
# Out:
# {'1': '1', '2': '2'}

# %%
[split_text(text) for text in response.COMMENTS]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 [split_text(text) for text in response.COMMENTS]
#
# Cell In[204], line 1, in <listcomp>(.0)
# ----> 1 [split_text(text) for text in response.COMMENTS]
#
# Cell In[200], line 17, in split_text(text)
#      15     break
#      16 temp =  text[:a.end()].replace(' ','')#remove any space in the string
# ---> 17 key,value = temp.split('=')
#      18 data[key] = value
#      19 text= text[a.end():]
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
response.loc[:50]
# Out:
#        LEAP_ID       Response                                     COMMENTS  \
# 0    LEAP001/2  Non-Responder                          1=core 2= resection
# 1    LEAP003/4  Non-Responder                           3=core 4=resection
# 2    LEAP005/6  Non-Responder                           5=core 6=resection
# 3      LEAP007            pCR                                         core
# 4      LEAP008            pCR                                         core
# 5   LEAP009/10            pCR  core (bilateral biopsies from same patient)
# 6      LEAP011  Non-Responder                                         core
# 7      LEAP012            pCR                                         core
# 8      LEAP013            pCR                                         core
# 9      LEAP014            pCR                                         core
# 10  LEAP015/16  Non-Responder                         15=core 16=resection
# 11  LEAP017/18  Non-Responder                         17=core 18=resection
# 12  LEAP019/20  Non-Responder                         19=core 20=resection
# 13     LEAP021            pCR                                         core
# 14     LEAP022            pCR                                         core
# 15     LEAP023  Non-Responder                                         core
# 16  LEAP024/25  Non-Responder                         24=core 25=resection
# 17  LEAP026/27  Non-Responder                         26=core 27=resection
# 18  LEAP028/29  Non-Responder                         28=core 29=resection
# 19  LEAP030/31  Non-Responder                         30=core 31=resection
# 20  LEAP032/33  Non-Responder                         32=core 33=resection
# 21  LEAP034/35  Non-Responder                         34=core 35=resection
# 22     LEAP036            pCR                                         core
# 23     LEAP037            pCR                                         core
# 24     LEAP038            pCR                                         core
# 25  LEAP039/40  Non-Responder                         39=core 40=resection
# 26     LEAP041            pCR                                         core
# 27     LEAP042            pCR                                         core
# 28     LEAP043            pCR                                         core
# 29  LEAP044/45  Non-Responder                         44=core 45=resection
# 30  LEAP046/47  Non-Responder                         46=core 47=resection
# 31  LEAP048/49  Non-Responder                         48=core 49=resection
# 32  LEAP050/51  Non-Responder                         50=core 51=resection
# 33     LEAP052  Non-Responder                                    resection
# 34     LEAP053  Non-Responder                                    resection
# 35     LEAP054  Non-Responder                                    resection
# 36     LEAP055  Non-Responder                                    resection
# 37     LEAP056      Responder                                    resection
# 38     LEAP057  Non-Responder                                    resection
# 39     LEAP058  Non-Responder                                    resection
# 40     LEAP059  Non-Responder                                    resection
# 41     LEAP060            pCR                                    resection
# 42     LEAP061  Non-Responder                                    resection
# 43     LEAP062  Non-Responder                                    resection
# 44     LEAP063  Non-Responder                                    resection
# 45  LEAP064/65  Non-Responder                         64=core 65=resection
# 46     LEAP066            pCR                                         core
# 47     LEAP067  Non-Responder                                         core
# 48     LEAP068  Non-Responder                                         core
# 49  LEAP069/70  Non-Responder                         69=core 70=resection
# 50  LEAP071/72  Non-Responder                         71=core 72=resection
#
#    FFPE/FRESH/frozen Extreme_non-responder_(death_within_2_years?)  FORCE
# 0               FFPE                                           NaN    NaN
# 1               FFPE                                           NaN    NaN
# 2               FFPE                                           NaN    NaN
# 3               FFPE                                           NaN  FORCE
# 4               FFPE                                             Y    NaN
# 5               FFPE                                           NaN    NaN
# 6               FFPE                                           NaN    NaN
# 7               FFPE                                           NaN    NaN
# 8               FFPE                                           NaN    NaN
# 9               FFPE                                           NaN    NaN
# 10              FFPE                                             Y    NaN
# 11              FFPE                                           NaN    NaN
# 12              FFPE                                           NaN    NaN
# 13              FFPE                                           NaN    NaN
# 14              FFPE                                           NaN    NaN
# 15              FFPE                                           NaN    NaN
# 16              FFPE                                             Y    NaN
# 17              FFPE                                           NaN    NaN
# 18              FFPE                                             Y    NaN
# 19              FFPE                                             Y    NaN
# 20              FFPE                                           NaN    NaN
# 21              FFPE                                             Y    NaN
# 22              FFPE                                           NaN    NaN
# 23              FFPE                                           NaN    NaN
# 24              FFPE                                           NaN    NaN
# 25              FFPE                                             Y    NaN
# 26              FFPE                                           NaN    NaN
# 27              FFPE                                           NaN    NaN
# 28              FFPE                                           NaN    NaN
# 29              FFPE                                           NaN    NaN
# 30              FFPE                                             Y    NaN
# 31              FFPE                                           NaN    NaN
# 32              FFPE                                           NaN    NaN
# 33            frozen                                             Y    NaN
# 34            frozen                                             Y    NaN
# 35            frozen                                           NaN    NaN
# 36            frozen                                             Y    NaN
# 37            frozen                                             Y    NaN
# 38            frozen                                           NaN    NaN
# 39            frozen                                             Y    NaN
# 40            frozen                                             Y    NaN
# 41            frozen                                           NaN    NaN
# 42            frozen                                             Y    NaN
# 43            frozen                                           NaN    NaN
# 44            frozen                                             Y    NaN
# 45              FFPE                                             Y    NaN
# 46              FFPE                                           NaN    NaN
# 47              FFPE                                           NaN    NaN
# 48              FFPE                                           NaN    NaN
# 49              FFPE                                           NaN    NaN
# 50              FFPE                                           NaN    NaN

# %%
def split_string(string_list):
    result = []
    for item in string_list:
        if '=' in item:
            pairs = re.split(r';|,\s', item)  # Split by spaces or commas
            key_value_pairs = [pair.split('=') for pair in pairs]
            result.extend(key_value_pairs)  # Add individual pairs to the result list
        else:
            result.append(item)  # Keep strings without '=' as-is
    return result
split_string(response.COMMENTS)
row = response.COMMENTS.loc[0]
print(row)
re.split(r';|,\s', row)
# Out:
# 1=core 2= resection
# ['1=core 2= resection']

# %%
response
response.COMMENTS.str.replace(',',' ')
# Out:
# 0                                1=core 2= resection
# 1                                 3=core 4=resection
# 2                                 5=core 6=resection
# 3                                               core
# 4                                               core
#                            ...
# 97                                          133=CORE
# 98                                          134=CORE
# 99                                          135=CORE
# 100                                         136=CORE
# 101    138=CORE 139=RESECTION 151=CORE 152=RESECTION
# Name: COMMENTS, Length: 102, dtype: object

# %%
help('a'.split)
# Out:
# Help on built-in function split:
#
# split(sep=None, maxsplit=-1) method of builtins.str instance
#     Return a list of the words in the string, using sep as the delimiter string.
#
#     sep
#       The delimiter according which to split the string.
#       None (the default value) means split according to any whitespace,
#       and discard empty strings from the result.
#     maxsplit
#       Maximum number of splits to do.
#       -1 (the default value) means no limit.

# %%
r"\d{1,3}\s*=\s*(core|resection)" == r"\d{1,3}\s*=\s*(core|resection)"
# Out:
# True

# %%
False^False
# Out:
# False
