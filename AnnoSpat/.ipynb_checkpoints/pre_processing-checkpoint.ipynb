# %% [markdown]
# this notebook reads the IMC files from different subfolders, it aggregates and uniforms the formatting

# %%
import numpy as np
import pandas as pd
from os import listdir
import re
from os.path import isfile, join
import os
import warnings

def strip_extension(self):
    '''strip the file extension from a pd.Series of file names'''
    return self.apply(lambda x: os.path.splitext(x)[0])

# Add the method to the Pandas Series class
pd.Series.strip_extension = strip_extension

# %% [markdown]
# # Formatting the intensities
#
# The aim of this section is to aggregate all the data into a unique csv file. I add the ROI as a column

# %%
path0 = '../../IMC_SegmentationResults/'
Leap_list = [name for name in next(os.walk(path0))[1] if name[:4]=='Leap']#list of Leap files
#path = path0+'all_data/'
directory = 'intensities/'
#file_names = [f for f in listdir(path+directory) if isfile(join(path+directory, f))]
#stripped_names = [re.sub(r'\.[^.]+$', '', name) for name in file_names]

# %%
#[x[0] for x in os.walk(path0)]
def filename_mapper():
    '''for every file in the intensity folder, put in a Leap format'''
    file_names = []
    for  name in Leap_list:
        path = path0+name+'/'+directory
        for f in listdir(path):
            if isfile(join(path, f)):#select only files,  not directories
                #if file is not in the format Leap***_***.csv, create the corresponding name
                pattern = r'^Leap\d{3}_\d{3}\.csv$'
                if re.match(pattern, f) is not None:
                    file_names+=[(f,f.split('.')[0])]#strip the extension from the mapper name
                else:
                    new_name = name+'_'+f.split('_')[-1].split('.')[0]# use the Leap name of the folder
                    file_names+=[(f,new_name)]
    #return file_names
    tb = pd.DataFrame(file_names,columns=['file_name','new_name'])
    tb['folder'] = tb['new_name'].str.split('_').str[0]
    tb['no_ext'] = tb.file_name.strip_extension()
    return tb
filenames = filename_mapper()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 21
#      19     tb['no_ext'] = tb.file_name.strip_extension()
#      20     return tb
# ---> 21 filenames = filename_mapper()
#
# Cell In[3], line 7, in filename_mapper()
#       5 for  name in Leap_list:
#       6     path = path0+name+'/'+directory
# ----> 7     for f in listdir(path):
#       8         if isfile(join(path, f)):#select only files,  not directories
#       9             #if file is not in the format Leap***_***.csv, create the corresponding name
#      10             pattern = r'^Leap\d{3}_\d{3}\.csv$'
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../IMC_SegmentationResults/Leap024/intensities/'

# %%
Leap_list
# Out:
# ['Leap008', 'Leap024', 'Leap003', 'Leap004_2', 'Leap002', 'Leap001', 'Leap004']

# %%
print(filenames.shape)
filenames.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(filenames.shape)
#       2 filenames.head()
#
# NameError: name 'filenames' is not defined

# %% [markdown]
# For every intensity file, I associate the appropriate ROI

# %%
all_images = pd.DataFrame()
for folder in filenames['folder']:
    images = pd.read_csv(path0+folder+'/images.csv') 
    images['ROI'] = images.acquisition_description.str.extract(r'(ROI_\d+)')#extract ROI from string
    images['ROI'] = images.ROI.str.split('_').str[1]
    all_images = pd.concat((all_images,images),ignore_index=True)
all_images['image_no_ext'] = all_images.image.strip_extension()
all_images.drop_duplicates(inplace=True)
merge = pd.merge(left = filenames,right=all_images,left_on='no_ext',right_on='image_no_ext',how = 'inner')
merge.drop('no_ext',axis =1,inplace=True)#remove one of the column used to merge
merge.shape
# Out:
# (46, 20)

# %%
merge.head()
# Out:
#                                   file_name     new_name   folder  \
# 0  S0743_COwczarek-Slide14_17036116_006.csv  Leap031_006  Leap031
# 1  S0743_COwczarek-Slide14_17036116_001.csv  Leap031_001  Leap031
# 2  S0743_COwczarek-Slide14_17036116_003.csv  Leap031_003  Leap031
# 3  S0743_COwczarek-Slide14_17036116_002.csv  Leap031_002  Leap031
# 4  S0743_COwczarek-Slide14_17036116_008.csv  Leap031_008  Leap031
#
#                                        image  width_px  height_px  \
# 0  S0743_COwczarek-Slide14_17036116_006.tiff      1010       1081
# 1  S0743_COwczarek-Slide14_17036116_001.tiff       999       1087
# 2  S0743_COwczarek-Slide14_17036116_003.tiff      1039       1064
# 3  S0743_COwczarek-Slide14_17036116_002.tiff       999       1087
# 4  S0743_COwczarek-Slide14_17036116_008.tiff      1010       1081
#
#    num_channels                           source_file  \
# 0            62  S0743_COwczarek-Slide14_17036116.mcd
# 1            62  S0743_COwczarek-Slide14_17036116.mcd
# 2            62  S0743_COwczarek-Slide14_17036116.mcd
# 3            62  S0743_COwczarek-Slide14_17036116.mcd
# 4            62  S0743_COwczarek-Slide14_17036116.mcd
#
#                                        recovery_file  recovered  \
# 0  S0743_COwczarek-Slide14_17036116_ROI_001_resec...      False
# 1  S0743_COwczarek-Slide14_17036116_ROI_001_resec...      False
# 2  S0743_COwczarek-Slide14_17036116_ROI_001_resec...      False
# 3  S0743_COwczarek-Slide14_17036116_ROI_002_resec...      False
# 4  S0743_COwczarek-Slide14_17036116_ROI_003_resec...      False
#
#    acquisition_id                         acquisition_description  \
# 0             6.0   ROI_001_resec_right_x26834_y14573_w1010_h1081
# 1             1.0     ROI_001_resec_left_x11726_y13231_w999_h1087
# 2             3.0  ROI_001_resec_middle_x22839_y14759_w1039_h1064
# 3             2.0      ROI_002_resec_left_x13312_y7120_w999_h1087
# 4             8.0   ROI_003_resec_right_x29820_y10669_w1010_h1081
#
#    acquisition_start_x_um  acquisition_start_y_um  acquisition_end_x_um  \
# 0                 26834.0                 14573.0               27844.0
# 1                 11726.0                 13231.0               12725.0
# 2                 22839.0                 14759.0               23878.0
# 3                 13312.0                  7120.0               14311.0
# 4                 29820.0                 10669.0               30830.0
#
#    acquisition_end_y_um  acquisition_width_um  acquisition_height_um  ROI  \
# 0               13492.0                1010.0                 1081.0  001
# 1               12144.0                 999.0                 1087.0  001
# 2               13695.0                1039.0                 1064.0  001
# 3                6033.0                 999.0                 1087.0  002
# 4                9588.0                1010.0                 1081.0  003
#
#                            image_no_ext
# 0  S0743_COwczarek-Slide14_17036116_006
# 1  S0743_COwczarek-Slide14_17036116_001
# 2  S0743_COwczarek-Slide14_17036116_003
# 3  S0743_COwczarek-Slide14_17036116_002
# 4  S0743_COwczarek-Slide14_17036116_008

# %% [markdown]
# For every cell, I add the a column indicating the slide identifier

# %%
merged_intensities = pd.DataFrame()
merged_regions = pd.DataFrame()
for _,row  in merge.iterrows():
    #concatente together the intensities files
    df = pd.read_csv(path0+'/'+row.folder+'/intensities/'+row.file_name)
    df = df[df.columns[df.columns.str.find('-')>0]]#select only columns related to antibody and filter out empty channels
    df.columns = df.columns.str.replace(r'^.*?-','',regex = True)#remove the metals
    df['slice_ID'] = row.new_name
    merged_intensities = pd.concat([merged_intensities,df],ignore_index=True)

    #Concatenate together the region files which contains the spatial information for every cell
    region_file = path0+'/'+row.folder+'/regionprops/'+row.file_name
    if os.path.isfile(region_file):
        df_regions = pd.read_csv(region_file)
        df_regions['slice_ID'] = row.new_name
        merged_regions = pd.concat([merged_regions,df_regions.iloc[:,1:]],ignore_index=True)#remove the object column
    else:
        warnings.warn('File '+region_file+'  does not exist')
print('shape of the dataframe:',merged_intensities.shape)
merged_intensities.head()
# Out:
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap031/regionprops/S0743_COwczarek-Slide14_17036116_006.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap031/regionprops/S0743_COwczarek-Slide14_17036116_001.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap031/regionprops/S0743_COwczarek-Slide14_17036116_003.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap031/regionprops/S0743_COwczarek-Slide14_17036116_002.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap031/regionprops/S0743_COwczarek-Slide14_17036116_008.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap031/regionprops/S0743_COwczarek-Slide14_17036116_009.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap031/regionprops/S0743_COwczarek-Slide14_17036116_004.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap031/regionprops/S0743_COwczarek-Slide14_17036116_007.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap031/regionprops/S0743_COwczarek-Slide14_17036116_005.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_016.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_002.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_005.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_006.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_008.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_013.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_017.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_001.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_019.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_014.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_010.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_011.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_009.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_003.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_015.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_007.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_004.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_012.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_018.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap008/regionprops/Leap008_020.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap010/regionprops/Leap010_ROI_003_19005860_x18533_y11816_w543_h553_3.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap010/regionprops/Leap010_ROI_002_19005860_x18590_y11112_w543_h553_2.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap010/regionprops/Leap010_ROI_005_19005860_x18819_y12800_w472_h460_5.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap010/regionprops/Leap010_ROI_001_19005860_x18397_y10558_w744_h999_1.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap010/regionprops/Leap010_ROI_004_19005860_x18762_y14057_w501_h1042_4.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap030/regionprops/S0743_COwczarek-Slide14_17035511_011.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap030/regionprops/S0743_COwczarek-Slide14_17035511_010.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap030/regionprops/S0743_COwczarek-Slide14_17035511_013.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# <ipython-input-7-42dab450ecd9>:18: UserWarning: File ../IMC_SegmentationResults//Leap030/regionprops/S0743_COwczarek-Slide14_17035511_012.csv  does not exist
#   warnings.warn('File '+region_file+'  does not exist')
# shape of the dataframe: (198520, 38)
#        CD38      EGFR       p53      CD14      Tbet      CD16     CD163  \
# 0  0.086607  0.035714  0.035714  0.080756  0.017857  0.057445  0.017857
# 1  0.175462  0.302845  0.238049  0.349944  0.111111  0.265496  0.227717
# 2  0.763631  0.181818  0.000000  0.931856  0.096269  0.996706  1.003603
# 3  0.123132  0.221118  0.195240  0.371842  0.082601  0.266941  1.133270
# 4  0.158077  0.210496  0.060787  0.350709  0.038462  0.133366  2.212801
#
#    Pan-keratin     CD11b     PD-L1  ...       CD3      CD27     PD-L2  \
# 0     0.000000  0.035714  0.064036  ...  0.000000  0.000000  0.017857
# 1     0.055556  0.275023  0.309092  ...  0.173632  0.055556  0.055556
# 2     0.131227  0.000000  0.000000  ...  0.198596  0.000000  0.000000
# 3     0.034856  0.202127  0.137550  ...  0.977854  0.055803  0.140183
# 4     0.131235  0.076923  0.103961  ...  0.076923  0.000000  0.124069
#
#      CD45RO  Alpha-SMA  Vimentin      CD31      DNA1      DNA2     slice_ID
# 0  0.055358   0.425580  0.193092  0.042434  0.536611  0.987804  Leap031_006
# 198518  1.207261    0.760741   15.218093  0.397587   4.858346   8.054574
# 198519  1.059165    0.898864    1.311309  0.614380   3.740265   5.400580
#
#            slice_ID
# 140489  Leap001_010
# 140490  Leap001_010
# 140491  Leap001_010
# 140492  Leap001_010
# 140493  Leap001_010
# ...             ...
# 198515  Leap002_003
# 198516  Leap002_003
# 198517  Leap002_003
# 198518  Leap002_003
# 198519  Leap002_003
#
# [58031 rows x 38 columns]

# %%
path2 = './pre_processed_files'
isExist = os.path.exists(path2)
if not isExist:

   # Create a new directory because it does not exist
   os.makedirs(path2)
cond = merged_intensities.slice_ID.str.split('_').str[0].isin(['Leap001','Leap002'])
merged_intensities = merged_intensities[cond]
    
merged_intensities.to_csv(path2+'/all_data_intensities.csv')

# %%
merged_regions.to_csv('./pre_processed_files/all_data_regions.csv',index=False)

# %% [markdown]
# # Creating the signature
# I format the signature file to work with AnnoSpat

# %%
#signature = pd.read_csv('../IMC_SegmentationResults/IMC_SegmentationResults/IMCCelltypeResults/cell_type_matrix.csv').set_index('Marker')
signature = pd.read_csv(path0+'/IMCCelltypeResults/cell_type_matrix.csv').set_index('Marker')
signature.head()
signature.drop(labels=['Proliferative cells?','Other cells','p53+ cells?'],axis='columns',inplace=True)# drop the proliferative cell class
signature.head()
# Out:
#         Cancer  CD163p_Mac [M2]  CD163n_Mac [M1]  Naive CD4 T cells  \
# Marker
# CD38       NaN              NaN              NaN                1.0
# EGFR       NaN              NaN              NaN                NaN
# p53        NaN              NaN              NaN                NaN
# CD14       NaN              NaN              NaN                NaN
# Tbet       NaN              NaN              NaN                NaN
#
#         Memory T cells  Regulatory T cells  Naive CD8 T cells  \
# Marker
# CD38               1.0                 1.0                1.0
# EGFR               NaN                 NaN                NaN
# p53                NaN                 NaN                NaN
# CD14               NaN                 NaN                NaN
# Tbet               NaN                 NaN                NaN
#
#         Memory CD8 T cells  Naive B cells  Memory B cells  NK and CD8 Tcell  \
# Marker
# CD38                   1.0            1.0             1.0               1.0
# EGFR                   NaN            NaN             NaN               NaN
# p53                    NaN            NaN             NaN               NaN
# CD14                   NaN            NaN             NaN               NaN
# Tbet                   NaN            NaN             NaN               NaN
#
#         CI_Monocyte  Int_Monocyte  nonCI_Monocyte  Endothelial  Fibroblasts  \
# Marker
# CD38            NaN           NaN             NaN          NaN          NaN
# EGFR            NaN           NaN             NaN          NaN          NaN
# p53             NaN           NaN             NaN          NaN          NaN
# CD14            1.0           1.0            -1.0         -1.0          NaN
# Tbet            NaN           NaN             NaN          NaN          NaN
#
#         B7H4+ cancer cells  Neutrophil&monocyte
# Marker
# CD38                   NaN                  NaN
# EGFR                   NaN                  NaN
# p53                    NaN                  NaN
# CD14                   NaN                 -1.0
# Tbet                   NaN                  NaN

# %%
new = {}
for column in signature.columns:
    protein_2_add = signature.index[~signature[column].isna()]#series of protein to use as markers
    order = np.argsort(signature[~signature[column].isna()][column])[::-1]
    protein_2_add = protein_2_add[order]
    a =signature[column][protein_2_add]
    new[column] = list(protein_2_add.where(a>0,protein_2_add.astype(str)+'-'))
signature =pd.DataFrame.from_dict(new,orient = 'index').T

# %%
signature.to_csv('pre_processed_files/signature.csv',index=False)

# %%
signature
# Out:
#           Cancer CD163p_Mac [M2] CD163n_Mac [M1] Naive CD4 T cells  \
# 0   Beta-Catenin            CD68            CD68              CD27
# 1     E-Cadherin           CD163    Pan-keratin-               CD3
# 2    Pan-keratin    Pan-keratin-          CD163-               CD4
# 3           None            None            None              CD45
# 4           None            None            None              CD38
# 5           None            None            None           CD45RO-
# 6           None            None            None             CD8a-
# 7           None            None            None             CD20-
# 8           None            None            None            FOXP3-
# 9           None            None            None             CD44-
# 10          None            None            None            CD11b-
#
#    Memory T cells Regulatory T cells Naive CD8 T cells Memory CD8 T cells  \
# 0          CD45RO             CD45RO               CD3             CD45RO
# 1            CD27               CD27              CD8a               CD27
# 2             CD3                CD3              CD45                CD3
# 3             CD4                CD4              CD38               CD8a
# 4            CD44              FOXP3           CD45RO-               CD44
# 5            CD45               CD44             CD27-               CD45
# 6            CD38               CD45             CD20-               CD38
# 7           CD8a-               CD38              CD4-              CD20-
# 8           CD20-              CD8a-            FOXP3-               CD4-
# 9          FOXP3-              CD20-             CD44-             FOXP3-
# 10         CD11b-             CD11b-            CD11b-             CD11b-
#
#    Naive B cells Memory B cells NK and CD8 Tcell   CI_Monocyte  Int_Monocyte  \
# 0           CD20           CD27       Granzyme-B          CD14          CD16
# 1           CD45           CD20           CD107a          CD3-          CD14
# 2           CD38           CD45             CD38         CD20-          CD3-
# 3          CD27-           CD38     Pan-keratin-         CD68-         CD20-
# 4           CD3-           CD3-             None  Pan-keratin-         CD68-
# 5         FOXP3-         FOXP3-             None         CD16-  Pan-keratin-
# 6         CD11b-         CD11b-             None          None          None
# 7           None           None             None          None          None
# 8           None           None             None          None          None
# 9           None           None             None          None          None
# 10          None           None             None          None          None
#
#    nonCI_Monocyte   Endothelial   Fibroblasts B7H4+ cancer cells  \
# 0            CD16          CD31      Vimentin              B7-H4
# 1            CD3-          CD3-     Alpha-SMA       Beta-Catenin
# 2           CD20-         CD20-         CD31-         E-Cadherin
# 3           CD68-         CD68-         CD45-        Pan-keratin
# 4    Pan-keratin-  Pan-keratin-  Pan-keratin-               None
# 5           CD14-         CD16-          None               None
# 6            None         CD14-          None               None
# 7            None          None          None               None
# 8            None          None          None               None
# 9            None          None          None               None
# 10           None          None          None               None
#
#    Neutrophil&monocyte
# 0                 CD45
# 1                CD11b
# 2                 CD16
# 3                CD14-
# 4                 None
# 5                 None
# 6                 None
# 7                 None
# 8                 None
# 9                 None
# 10                None

# %%
signature
# Out:
#           Cancer CD163p_Mac [M2] CD163n_Mac [M1] Naive CD4 T cells  \
# 0    Pan-keratin           CD163          CD163-              CD38
# 1     E-Cadherin    Pan-keratin-    Pan-keratin-            CD11b-
# 2   Beta-Catenin            CD68            CD68              CD45
# 3           None            None            None             CD44-
# 4           None            None            None            FOXP3-
# 5           None            None            None               CD4
# 6           None            None            None             CD20-
# 7           None            None            None             CD8a-
# 8           None            None            None               CD3
# 9           None            None            None              CD27
# 10          None            None            None           CD45RO-
#
#    Memory T cells Regulatory T cells Naive CD8 T cells Memory CD8 T cells  \
# 0            CD38               CD38              CD38               CD38
# 1          CD11b-             CD11b-            CD11b-             CD11b-
# 2            CD45               CD45              CD45               CD45
# 3            CD44               CD44             CD44-               CD44
# 4          FOXP3-              FOXP3            FOXP3-             FOXP3-
# 5             CD4                CD4              CD4-               CD4-
# 6           CD20-              CD20-             CD20-              CD20-
# 7           CD8a-              CD8a-              CD8a               CD8a
# 8             CD3                CD3               CD3                CD3
# 9            CD27               CD27             CD27-               CD27
# 10         CD45RO             CD45RO           CD45RO-             CD45RO
#
#    Naive B cells Memory B cells NK and CD8 Tcell   CI_Monocyte  Int_Monocyte  \
# 0           CD38           CD38             CD38          CD14          CD14
# 1         CD11b-         CD11b-     Pan-keratin-         CD16-          CD16
# 2           CD45           CD45           CD107a  Pan-keratin-  Pan-keratin-
# 3         FOXP3-         FOXP3-       Granzyme-B         CD68-         CD68-
# 4           CD20           CD20             None         CD20-         CD20-
# 5           CD3-           CD3-             None          CD3-          CD3-
# 6          CD27-           CD27             None          None          None
# 7           None           None             None          None          None
# 8           None           None             None          None          None
# 9           None           None             None          None          None
# 10          None           None             None          None          None
#
#    nonCI_Monocyte   Endothelial   Fibroblasts B7H4+ cancer cells  \
# 0           CD14-         CD14-  Pan-keratin-        Pan-keratin
# 1            CD16         CD16-         CD45-         E-Cadherin
# 2    Pan-keratin-  Pan-keratin-     Alpha-SMA       Beta-Catenin
# 3           CD68-         CD68-      Vimentin              B7-H4
# 4           CD20-         CD20-         CD31-               None
# 5            CD3-          CD3-          None               None
# 6            None          CD31          None               None
# 7            None          None          None               None
# 8            None          None          None               None
# 9            None          None          None               None
# 10           None          None          None               None
#
#    Neutrophil&monocyte
# 0                CD14-
# 1                 CD16
# 2                CD11b
# 3                 CD45
# 4                 None
# 5                 None
# 6                 None
# 7                 None
# 8                 None
# 9                 None
# 10                None

# %% [markdown]
# COde below run AnnoSpat to perform cell type annotation

# %%
# !python AnnoSpat_main/AnnoSpat/run.py -i pre_processed_files/all_data_intensities.csv  -m pre_processed_files/signature.csv  -o ./output -f CD38 -l DNA2 -r slice_ID -a '[99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5, 99.5,99.5]'
# Out:
# =====Function chosen: ANNOTATION=====
#
# Starting cell type annotation.....
#
# -----Estimating cell types using Semi supervised clustering-----
#
# -------------------------Done-------------------------
#
# Time taken: 0.019012804826100668seconds
#
# Estimating cell types...
# -----Estimating cell types using ELM-----
#
# -------------------------Done-------------------------
#
# Time taken: 0.10888853867848715seconds
#
# Saving Annotations in: /home/giuseppe/Downloads/Annospat_labelling/output/trte_labels_numericLabels_ELM_IMC_T1D_AnnoSpat.csv
# -------------------------Done-------------------------

# %%
pd.__version__
# Out:
# '2.0.3'
